# %% [markdown]
# ### The cards were taken from https://s3.amazonaws.com/cah/CAH_MainGame.pdf in a PDF form
#
# ### The family friendly cards were taken from https://www.cardsagainsthumanityfamilyedition.com/pdf/CAH_Family_SmallCards.pdf in PDF form

# %% [markdown]
# ### Then the PDF was converted into a text file using a package from the site https://pypi.org/project/pdfminer/ that was installed in the anaconda promt

# %% [markdown]
# `python pdf2txt.py -o CAH_MainGame.txt CAH_MainGame.pdf`
#
# `python pdf2txt.py -o CAH_Family_SmallCards`

# %%
def ReadInFile(FileName):
    """
    This function reads in the file and saves each line of the file into a list and returns that list
    """
    with open(FileName, "r", encoding="utf-8") as file: # opens the csv file as file
        lines = file.readlines() # saves each line of the file into the list lines
    return lines

# %%
def ReturnCards(StartLine, EndLine, lines):
    """
    this function goes through the list and recognises each card and saves them in a list and returns that list
    """
    # Initilasing variables
    cards = []
    card = ""
    # for loop that goes through the cards and saves them in a list
    for lineNum in range(StartLine, EndLine):
        # each card is seperated by a line, so this if checks if the line is a part of the old card or the start of a new one
        if lines[lineNum] != "\n":
            # adds the line to the variable card and adds a space to make the card look neater
            card += lines[lineNum].strip()
            card += " "
        else:
            cards.append(card.strip()) # adds the finished card to the list
            card = "" # the card is wiped after appending for the start of another card
    return cards

# %%
def GapReplace(Card):
    """
    This function replaces the gap of a card and returns the edited card and the number of gaps it has
    """
    LocationOfGap = 0 # variable that will hold the location of the start of the gap
    EndOfGap = 0 # location of the end of the gap
    NumOfGaps = 0 # variable that will contain the number of gaps, if any, of the card
    count = 0
    
    while "_" in Card: # a while loop that will loop until there are no more gaps in the string
        LocationOfGap = Card.find("_") # finds the location of the first gap
        while (LocationOfGap + count) < len(Card) and Card[LocationOfGap + count] == "_": # while loop that counts how many _ there are
            count += 1
        EndOfGap = count + LocationOfGap # calculates the location of the end of the gap
        Card = Card[:LocationOfGap] + "{}" + Card[(EndOfGap):] # replaces the gaps with {}
        count = 0
        NumOfGaps += 1 # adds to the number of gaps
        
    if NumOfGaps == 0: # an if statement to catch a card that has no gaps in itand adding a {} to the end
        Card += " {}" # adds {x} to the end of the card
        NumOfGaps = 1
        
    return Card, NumOfGaps

# %% [markdown]
# ### This is the part where the lines of the file are printed out and the functions are ran

# %%
CAHFileName = "CAH_MainGame.txt" # Run this if you want to play the X rated game

# %%
CAHFileName = "CAH_Family_SmallCards.txt" # Run this if you want to play the R rated game

# %%
# prints out the lines of the pdf in a format which has the line number first
lines = ReadInFile(CAHFileName) # reads in the file lines and puts them in a lsit
for i, line in enumerate(lines): # goes thorugh all the lines and makes i = line number and line = the line
    print(f"{i}: {line.strip()}") # prints put the line in the form "1: Line1"
# Out:
# 0: How to make
# 1: your own Cards
# 2: Against Humanity
# 3:
# 4: 1.  Download this PDF and take it to your local
# 5:
# 6: print shop.
# 7:
# 8: 2. Have the shop print out the game on heavy
# 9: white cardstock (usually 80-pound or
# 10: higher). Although the cards are black and
# 11: white, you’ll get a nicer result if you can
# 12: convince them to use a color printer.
# 13:
# 14: 3. For added fanciness, you can print black
# 15: on the back of the question cards to make
# 16: them easier to tell apart.
# 17:
# 18: 4. Cut the cards to size using a large paper
# 19:
# 20: cutter. The more precise you are, the easier
# 21: they’ll be to handle later.
# 22:
# 23: 5. When you’re done, we recommend
# 24:
# 25: purchasing a clear model 102C AMAC box
# 26: (there’s a great one for sale at the Container
# 27: Store) for storing your cards.
# 28:
# 29: Cards Against Humanity Rules
# 30:
# 31: Silence.
# 32:
# 33: The illusion of
# 34: choice in
# 35: a late-stage
# 36: capitalist society.
# 37:
# 38: Many bats.
# 39:
# 40: Famine.
# 41:
# 42: Basic Rules
# 43: To start the game, each player draws ten white cards.
# 44: The player who most recently pooped begins as the Card Czar
# 45: and draws a black card. If Hugh Jackman is playing, he goes first,
# 46: regardless of how recently he pooped.
# 47: The Card Czar reads the question or fill-in-the-blank phrase on the
# 48: black card out loud. Everyone else answers the question or fills in
# 49: the blank by passing one white card, face down, to the Card Czar.
# 50: The Card Czar then shuffles all the answers and reads each card
# 51: combination out loud to the group. The Card Czar should re-read
# 52: the black card before presenting each answer. Finally, the Card
# 53: Czar picks the funniest play, and whoever submitted it gets
# 54: one point.
# 55: After the round, a new player becomes the Card Czar and everyone
# 56: draws back up to ten white cards.
# 57:
# 58: Some black cards say “PICK 2” on the bottom. To answer these,
# 59: each player plays two white cards in combination. IMPORTANT:
# 60: Arrange them in the order that the Card Czar should read them—
# 61: play the first card face down, and then play the second card face
# 62: down on top of it.
# 63:
# 64: Gambling
# 65: If you have more than one white card that you think could win a
# 66: round, you can bet one of your points to play an extra white card.
# 67: If you win, you keep the point. If you lose, whoever wins gets the
# 68: point you wagered.
# 69:
# 70: House Rules
# 71: Cards Against Humanity is meant to be remixed. Here are some of
# 72: our favorite ways to pimp out the rules:
# 73: Rando Cardrissian: Every round, pick one random white card from
# 74: the pile and place it into play. This card belongs to an imaginary
# 75: player named Rando Cardrissian, and if he wins the game, all
# 76: players go home in a state of everlasting shame.
# 77: Happy Ending: When you’re ready to end the game, play the
# 78: “Make a haiku” black card. This is the official ceremonial ending of
# 79: a good game of Cards Against Humanity. Note: Haikus don’t need
# 80: to follow the 5-7-5 form. They just have to be read dramatically.
# 81: Never Have I Ever: At any time, players may discard cards that
# 82: they don’t understand, but they must confess their ignorance to the
# 83: group and suffer the resulting humiliation.
# 84:
# 85: House Rules (cont.)
# 86: Wheaton’s Law: Each round, the Card Czar draws two black
# 87: cards, chooses the one they’d prefer to play, and puts the other at
# 88: the bottom of the black card pile.
# 89: Rebooting the Universe: At any time, players may trade in a point
# 90: to return as many white cards as they’d like to the deck and draw
# 91: back to ten.
# 92: Packing Heat: For Pick 2s, all players draw an extra card before
# 93: playing the hand to open up more options.
# 94: Meritocracy: Instead of passing clockwise, the role of Card Czar
# 95: passes to the winner of the previous round.
# 96: Smooth Operator: If a player slips a card from their hand into
# 97: conversation without anyone noticing, they may trade it for one
# 98: point. If the player is called out, they lose a point. If this rule is
# 99: confusing, you’re taking this game too seriously.
# 100: Tie Breaker: If the Card Czar can’t decide between two white
# 101: cards, they may declare a Tie Breaker. In the event of a Tie Breaker,
# 102: the more conventionally attractive player wins.
# 103: Chubby Bunny: Players crumple up their winning cards and keep
# 104: them in their mouths as points.
# 105: Freaky Friday: Players play Cards Against Humanity while wearing
# 106: their mothers’ underpants.
# 107: Hard Mode: Play Cards Against Humanity while raising four kids,
# 108: dealing with chronic back pain, and waiting tables at Chili’s. Bonus!
# 109: For an added challenge, try being gay or black.
# 110: Russian Roulette: The Card Czar takes out a revolver. They place
# 111: one bullet at random in the cylinder, spin it, and close it. They then
# 112: hold the gun to their head and pull the trigger. If the Card Czar
# 113: survives, they defiantly place the gun in the center of the table
# 114: and eye the other players, challenging them to pick up the gun “if
# 115: they’re man enough.” The Card Czar wins a point.
# 116: Hail to the Chief: A player may earn a point at any time by
# 117: announcing candidacy for and successfully being elected President
# 118: of the United States of America.
# 119: Race to the Moon: All players begin masturbating immediately.
# 120: Then what happens?
# 121: Smoke Opium and Play Cards Against Humanity: Great idea!
# 122: Wait for Godot: At the start of the game, instead of drawing a
# 123: hand, players stare at the pile of white cards. After an indeterminate
# 124: amount of time, players move their gaze to the pile of black cards.
# 125: The game doesn’t begin. How can it begin? It has already ended.
# 126: In the gloom, players shift their cloudy gaze from pile to pile. Is it
# 127: a trick of the light, or do the black cards and white cards seem to
# 128: converge in an indistinguishable grayness? Mote by mote, dust
# 129: settles on the cards. Nobody accumulates points. Nobody wins.
# 130: Don’t play Cards Against Humanity: Walk to a park. Call your
# 131: mother. Live a little.
# 132:
# 133: Flesh-eating
# 134: bacteria.
# 135:
# 136: Flying sex snakes.
# 137:
# 138: Not giving a
# 139: shit about the
# 140: Third World.
# 141:
# 142: Magnets.
# 143:
# 144: Shapeshifters.
# 145:
# 146: Seeing what
# 147: happens when
# 148: you lock people
# 149: in a room with
# 150: hungry seagulls.
# 151:
# 152: A crucifixion.
# 153:
# 154: Jennifer
# 155: Lawrence.
# 156:
# 157: 72 virgins.
# 158:
# 159: A live studio
# 160: audience.
# 161:
# 162: A time travel
# 163: paradox.
# 164:
# 165: Authentic
# 166: Mexican cuisine.
# 167:
# 168: Doing crimes.
# 169:
# 170: Synergistic
# 171: management
# 172: solutions.
# 173:
# 174: Crippling debt.
# 175:
# 176: Daddy issues.
# 177:
# 178: Used panties.
# 179:
# 180: A fart so powerful
# 181: that it wakes the
# 182: giants from their
# 183: thousand-year
# 184: slumber.
# 185:
# 186: Former President
# 187: George W. Bush.
# 188:
# 189: Full frontal nudity.
# 190:
# 191: Soft, kissy
# 192: missionary sex.
# 193:
# 194: BATMAN!
# 195:
# 196: Agriculture.
# 197:
# 198: Barely making
# 199: $25,000 a year.
# 200:
# 201: Covering myself
# 202: with Parmesan
# 203: cheese and chili
# 204: flakes because
# 205: I am pizza.
# 206:
# 207: Having big
# 208: dreams but no
# 209: realistic way to
# 210: achieve them.
# 211:
# 212: Laying an egg.
# 213:
# 214: Getting naked
# 215: and watching
# 216: Nickelodeon.
# 217:
# 218: Pretending
# 219: to care.
# 220:
# 221: Natural selection.
# 222:
# 223: Coat hanger
# 224: abortions.
# 225:
# 226: Sex with
# 227: Patrick Stewart.
# 228:
# 229: Seeing Grandma
# 230: naked.
# 231:
# 232: Boogers.
# 233:
# 234: The inevitable
# 235: heat death of
# 236: the universe.
# 237:
# 238: Prescription
# 239: pain killers.
# 240:
# 241: Swooping.
# 242:
# 243: Mansplaining.
# 244:
# 245: My abusive
# 246: boyfriend who
# 247: really isn’t so bad
# 248: once you get to
# 249: know him.
# 250:
# 251: A homoerotic
# 252: volleyball
# 253: montage.
# 254:
# 255: The miracle
# 256: of childbirth.
# 257:
# 258: The Rapture.
# 259:
# 260: Whipping it out.
# 261:
# 262: White privilege.
# 263:
# 264: Alexandria
# 265: Ocasio-Cortez.
# 266:
# 267: Putting things
# 268: where they go.
# 269:
# 270: Fragile
# 271: masculinity.
# 272:
# 273: All-you-can-eat
# 274: shrimp for $8.99.
# 275:
# 276: Emerging from
# 277: the sea and
# 278: rampaging
# 279: through Tokyo.
# 280:
# 281: The Hamburglar.
# 282:
# 283: AXE Body Spray.
# 284:
# 285: The Blood
# 286: of Christ.
# 287:
# 288: An old guy who’s
# 289: almost dead.
# 290:
# 291: Kanye West.
# 292:
# 293: Hot cheese.
# 294:
# 295: Raptor attacks.
# 296:
# 297: Seven dead
# 298: and three in
# 299: critical condition.
# 300:
# 301: Smegma.
# 302:
# 303: Alcoholism.
# 304:
# 305: A middle-aged
# 306: man on roller
# 307: skates.
# 308:
# 309: The past.
# 310:
# 311: My genitals.
# 312:
# 313: An endless stream
# 314: of diarrhea.
# 315:
# 316: Science.
# 317:
# 318: Bingeing and
# 319: purging.
# 320:
# 321: An oversized
# 322: lollipop.
# 323:
# 324: Self-loathing.
# 325:
# 326: Not reciprocating
# 327: oral sex.
# 328:
# 329: Flightless birds.
# 330:
# 331: A good sniff.
# 332:
# 333: Looking in the
# 334: mirror, applying
# 335: lipstick, and
# 336: whispering “tonight,
# 337: you will have sex
# 338: with Tom Cruise.”
# 339:
# 340: Sitting on my face
# 341: and telling me
# 342: I’m garbage.
# 343:
# 344: Half-assed
# 345: foreplay.
# 346:
# 347: The Holy Bible.
# 348:
# 349: German
# 350: dungeon porn.
# 351:
# 352: A balanced
# 353: breakfast.
# 354:
# 355: Dead birds
# 356: everywhere.
# 357:
# 358: The arrival of
# 359: the pizza.
# 360:
# 361: 50,000 volts
# 362: straight to
# 363: the nipples.
# 364:
# 365: Permanent
# 366: Orgasm-Face
# 367: Disorder.
# 368:
# 369: Being on fire.
# 370:
# 371: Teenage
# 372: pregnancy.
# 373:
# 374: Gandhi.
# 375:
# 376: Your weird
# 377: brother.
# 378:
# 379: The cool,
# 380: refreshing taste
# 381: of Pepsi.®
# 382:
# 383: Chemical
# 384: weapons.
# 385:
# 386: Oprah.
# 387:
# 388: Wondering if it’s
# 389: possible to get
# 390: some of that
# 391: salsa to go.
# 392:
# 393: A Fleshlight.®
# 394:
# 395: A pyramid of
# 396: severed heads.
# 397:
# 398: An erection that
# 399: lasts longer than
# 400: four hours.
# 401:
# 402: A three-way
# 403: with my wife and
# 404: Shaquille O’Neal.
# 405:
# 406: Bananas.
# 407:
# 408: Passive
# 409: aggressive
# 410: Post-it notes.
# 411:
# 412: Hillary Clinton’s
# 413: emails.
# 414:
# 415: Switching
# 416: to Geico.®
# 417:
# 418: Peeing a little bit.
# 419:
# 420: Wet dreams.
# 421:
# 422: The Jews.
# 423:
# 424: My cheating
# 425: son-of-a-bitch
# 426: husband.
# 427:
# 428: Poverty.
# 429:
# 430: Kamikaze pilots.
# 431:
# 432: Committing
# 433: suicide.
# 434:
# 435: The homosexual
# 436: agenda.
# 437:
# 438: Powerful thighs.
# 439:
# 440: These hoes.
# 441:
# 442: The only gay
# 443: person in a
# 444: hundred miles.
# 445:
# 446: Having sex for
# 447: the first time.
# 448:
# 449: A Mexican.
# 450:
# 451: A falcon with a
# 452: cap on its head.
# 453:
# 454: Wizard music.
# 455:
# 456: The Kool-Aid Man.
# 457:
# 458: Donald J. Trump.
# 459:
# 460: Kissing grandma
# 461: on the forehead
# 462: and turning off
# 463: her life support.
# 464:
# 465: Sexual tension.
# 466:
# 467: An AR-15
# 468: assault rifle.
# 469:
# 470: Juuling.
# 471:
# 472: Free samples.
# 473:
# 474: Hurting those
# 475: closest to me.
# 476:
# 477: Doing the
# 478: right thing.
# 479:
# 480: My good bra.
# 481:
# 482: Punching a
# 483: congressman
# 484: in the face.
# 485:
# 486: Fancy Feast.®
# 487:
# 488: Being rich.
# 489:
# 490: The Three-Fifths
# 491: Compromise.
# 492:
# 493: Lactation.
# 494:
# 495: World peace.
# 496:
# 497: Shutting up
# 498: so I can watch
# 499: the game.
# 500:
# 501: Sweet, sweet
# 502: vengeance.
# 503:
# 504: Republicans.
# 505:
# 506: Sniffing and
# 507: kissing my feet.
# 508:
# 509: A much younger
# 510: woman.
# 511:
# 512: Eating a hard
# 513: boiled egg out
# 514: of my husband’s
# 515: asshole.
# 516:
# 517: RoboCop.
# 518:
# 519: One titty
# 520: hanging out.
# 521:
# 522: Justin Bieber.
# 523:
# 524: Oompa-Loompas.
# 525:
# 526: Inappropriate
# 527: yodeling.
# 528:
# 529: Puberty.
# 530:
# 531: Ghosts.
# 532:
# 533: Expecting a burp
# 534: and vomiting on
# 535: the floor.
# 536:
# 537: Adderall.®
# 538:
# 539: The Red Hot
# 540: Chili Peppers.
# 541:
# 542: Sideboob.
# 543:
# 544: 50 mg of Zoloft
# 545: daily.
# 546:
# 547: Fucking my sister.
# 548:
# 549: Braiding three
# 550: penises into
# 551: a Twizzler.
# 552:
# 553: Vigorous
# 554: jazz hands.
# 555:
# 556: An octopus giving
# 557: seven handjobs
# 558: and smoking
# 559: a cigarette.
# 560:
# 561: My neck,
# 562: my back,
# 563: my pussy,
# 564: and my crack.
# 565:
# 566: J.D. Power and
# 567: his associates.
# 568:
# 569: Mouth herpes.
# 570:
# 571: Getting fingered.
# 572:
# 573: My Uber driver,
# 574: Pavel.
# 575:
# 576: GoGurt.®
# 577:
# 578: Police brutality.
# 579:
# 580: Sperm whales.
# 581:
# 582: Women of color.
# 583:
# 584: Incest.
# 585:
# 586: Men discussing
# 587: their feelings in
# 588: an emotionally
# 589: healthy way.
# 590:
# 591: Filling my
# 592: briefcase with
# 593: business stuff.
# 594:
# 595: Preteens.
# 596:
# 597: My fat daughter.
# 598:
# 599: Rap music.
# 600:
# 601: Pac-Man
# 602: uncontrollably
# 603: guzzling cum.
# 604:
# 605: Casually
# 606: suggesting a
# 607: threesome.
# 608:
# 609: Running out of
# 610: semen.
# 611:
# 612: God.
# 613:
# 614: Fading away into
# 615: nothingness.
# 616:
# 617: Darth Vader.
# 618:
# 619: A sad handjob.
# 620:
# 621: Exactly what
# 622: you’d expect.
# 623:
# 624: The wonders of
# 625: the Orient.
# 626:
# 627: Sexual peeing.
# 628:
# 629: Emotions.
# 630:
# 631: Licking things to
# 632: claim them as
# 633: your own.
# 634:
# 635: Jobs.
# 636:
# 637: The placenta.
# 638:
# 639: Spontaneous
# 640: human
# 641: combustion.
# 642:
# 643: The Bachelorette
# 644: season finale.
# 645:
# 646: A tiny horse.
# 647:
# 648: William Shatner.
# 649:
# 650: Selling crack
# 651: to children.
# 652:
# 653: An M. Night
# 654: Shyamalan
# 655: plot twist.
# 656:
# 657: Throwing grapes
# 658: at a man until he
# 659: loses touch with
# 660: reality.
# 661:
# 662: Establishing
# 663: dominance.
# 664:
# 665: Finger painting.
# 666:
# 667: Old-people smell.
# 668:
# 669: Brown people.
# 670:
# 671: Mutually assured
# 672: destruction.
# 673:
# 674: Pedophiles.
# 675:
# 676: Yeast.
# 677:
# 678: Getting crushed
# 679: by a vending
# 680: machine.
# 681:
# 682: My inner demons.
# 683:
# 684: A Super Soaker™
# 685: full of cat pee.
# 686:
# 687: Aaron Burr.
# 688:
# 689: How bad my
# 690: daughter fucked
# 691: up her dance
# 692: recital.
# 693:
# 694: Rectangles.
# 695:
# 696: Catapults.
# 697:
# 698: Poor people.
# 699:
# 700: Cuddling.
# 701:
# 702: However much
# 703: weed $20 can buy.
# 704:
# 705: Battlefield
# 706: amputations.
# 707:
# 708: Spaghetti?
# 709: Again?
# 710:
# 711: Only dating
# 712: Asian women.
# 713:
# 714: The Hustle.
# 715:
# 716: The Force.
# 717:
# 718: How amazing
# 719: it is to be on
# 720: mushrooms.
# 721:
# 722: Ronald Reagan.
# 723:
# 724: A disappointing
# 725: birthday party.
# 726:
# 727: Nachos for
# 728: the table.
# 729:
# 730: Becoming a
# 731: blueberry.
# 732:
# 733: Judging
# 734: everyone.
# 735:
# 736: Kourtney, Kim,
# 737: Khloe, Kendall,
# 738: and Kylie.
# 739:
# 740: Getting married,
# 741: having a few kids,
# 742: buying some stuff,
# 743: retiring to Florida,
# 744: and dying.
# 745:
# 746: Some god damn
# 747: peace and quiet.
# 748:
# 749: AIDS.
# 750:
# 751: Pictures of boobs.
# 752:
# 753: Strong female
# 754: characters.
# 755:
# 756: Some foundation,
# 757: mascara, and
# 758: a touch of blush.
# 759:
# 760: Getting
# 761: cummed on.
# 762:
# 763: Pixelated
# 764: bukkake.
# 765:
# 766: A lifetime
# 767: of sadness.
# 768:
# 769: Going an entire
# 770: day without
# 771: masturbating.
# 772:
# 773: Hospice care.
# 774:
# 775: Getting really high.
# 776:
# 777: The opiod
# 778: epidemic.
# 779:
# 780: Penis envy.
# 781:
# 782: Dick pics.
# 783:
# 784: Racism.
# 785:
# 786: Menstrual rage.
# 787:
# 788: Sunshine and
# 789: rainbows.
# 790:
# 791: Gay conversion
# 792: therapy.
# 793:
# 794: Ruth Bader
# 795: Ginsburg brutally
# 796: gaveling your
# 797: penis.
# 798:
# 799: German
# 800: Chancellor
# 801: Angela Merkel.
# 802:
# 803: The KKK.
# 804:
# 805: Radical Islamic
# 806: terrorism.
# 807:
# 808: Huge biceps.
# 809:
# 810: My little boner.
# 811:
# 812: Dry heaving.
# 813:
# 814: Meth.
# 815:
# 816: Serfdom.
# 817:
# 818: A pangender
# 819: octopus who
# 820: roams the
# 821: cosmos in
# 822: search of love.
# 823:
# 824: Holding down a
# 825: child and farting
# 826: all over him.
# 827:
# 828: A gossamer
# 829: stream of jizz that
# 830: catches the light
# 831: as it arcs through
# 832: the morning air.
# 833:
# 834: Executing
# 835: a hostage
# 836: every hour.
# 837:
# 838: The rhythms
# 839: of Africa.
# 840:
# 841: Breaking out into
# 842: song and dance.
# 843:
# 844: A Bop It.™
# 845:
# 846: A whole thing
# 847: of butter.
# 848:
# 849: Still being
# 850: a virgin.
# 851:
# 852: Solving problems
# 853: with violence.
# 854:
# 855: Leprosy.
# 856:
# 857: Gloryholes.
# 858:
# 859: Nipple blades.
# 860:
# 861: The heart
# 862: of a child.
# 863:
# 864: Puppies!
# 865:
# 866: Fellowship in
# 867: Christ.
# 868:
# 869: Little boy penises. Waking up
# 870: half-naked
# 871: in a Denny’s
# 872: parking lot.
# 873:
# 874: The Pope.
# 875:
# 876: White people.
# 877:
# 878: Tentacle porn.
# 879:
# 880: My bright pink
# 881: fuckhole.
# 882:
# 883: An older woman
# 884: who knows her
# 885: way around
# 886: the penis.
# 887:
# 888: Getting drugs off
# 889: the street and
# 890: into my body.
# 891:
# 892: Daniel Radcliffe’s
# 893: delicious asshole.
# 894:
# 895: Active listening.
# 896:
# 897: How far I can get
# 898: my own penis
# 899: up my butt.
# 900:
# 901: Having anuses
# 902: for eyes.
# 903:
# 904: The penny whistle
# 905: solo from “My
# 906: Heart Will Go On.”
# 907:
# 908: Seppuku.
# 909:
# 910: Ethnic cleansing.
# 911:
# 912: Itchy pussy.
# 913:
# 914: Blowing my
# 915: boyfriend so
# 916: hard he shits.
# 917:
# 918: A fuck-ton of
# 919: almonds.
# 920:
# 921: Danny DeVito.
# 922:
# 923: The magic of
# 924: live theatre.
# 925:
# 926: Throwing a virgin
# 927: into a volcano.
# 928:
# 929: Dwayne
# 930: “The Rock”
# 931: Johnson.
# 932:
# 933: A salad for men
# 934: that’s made
# 935: of metal.
# 936:
# 937: Waiting till
# 938: marriage.
# 939:
# 940: Unfathomable
# 941: stupidity.
# 942:
# 943: Shiny objects.
# 944:
# 945: Accepting the
# 946: way things are.
# 947:
# 948: NBA superstar
# 949: LeBron James.
# 950:
# 951: Therapy.
# 952:
# 953: Listening to her
# 954: problems without
# 955: trying to solve
# 956: them.
# 957:
# 958: The Devil himself.
# 959:
# 960: Autocannibalism.
# 961:
# 962: Erectile
# 963: dysfunction.
# 964:
# 965: My collection
# 966: of Japanese
# 967: sex toys.
# 968:
# 969: Being fat and
# 970: stupid.
# 971:
# 972: Pooping back and
# 973: forth. Forever.
# 974:
# 975: Tearing that
# 976: ass up like
# 977: wrapping paper
# 978: on Christmas
# 979: morning.
# 980:
# 981: More elephant
# 982: cock than I
# 983: bargained for.
# 984:
# 985: A salty surprise.
# 986:
# 987: The South.
# 988:
# 989: The violation of
# 990: our most basic
# 991: human rights.
# 992:
# 993: Tap dancing
# 994: like there’s no
# 995: tomorrow.
# 996:
# 997: A bowl of
# 998: mayonnaise and
# 999: human teeth.
# 1000:
# 1001: Fiery poops.
# 1002:
# 1003: Saying
# 1004: “I love you.”
# 1005:
# 1006: Inserting a Mason
# 1007: jar into my anus.
# 1008:
# 1009: Consensual sex.
# 1010:
# 1011: Telling a shitty
# 1012: story that goes
# 1013: nowhere.
# 1014:
# 1015: A good,
# 1016: strong gorilla.
# 1017:
# 1018: Seeing my
# 1019: father cry.
# 1020:
# 1021: The true meaning
# 1022: of Christmas.
# 1023:
# 1024: Some of the best
# 1025: rappers in
# 1026: the game.
# 1027:
# 1028: Owning and
# 1029: operating a
# 1030: Chili’s franchise.
# 1031:
# 1032: Estrogen.
# 1033:
# 1034: Necrophilia.
# 1035:
# 1036: Being a woman.
# 1037:
# 1038: Getting into a
# 1039: pretty bad
# 1040: car accident.
# 1041:
# 1042: Bill Nye the
# 1043: Science Guy.
# 1044:
# 1045: Girls.
# 1046:
# 1047: The Russians.
# 1048:
# 1049: A bleached
# 1050: asshole.
# 1051:
# 1052: Fucking the
# 1053: weatherman on
# 1054: live television.
# 1055:
# 1056: Black people.
# 1057:
# 1058: The Boy Scouts
# 1059: of America.
# 1060:
# 1061: Lunchables.™
# 1062:
# 1063: Bitches.
# 1064:
# 1065: PTSD.
# 1066:
# 1067: Dark and
# 1068: mysterious forces
# 1069: beyond our
# 1070: control.
# 1071:
# 1072: Smallpox
# 1073: blankets.
# 1074:
# 1075: Masturbating.
# 1076:
# 1077: Some punk kid
# 1078: who stole my
# 1079: turkey sandwich.
# 1080:
# 1081: Heartwarming
# 1082: orphans.
# 1083:
# 1084: Spirit Airlines.
# 1085:
# 1086: Bubble butt
# 1087: bottom boys.
# 1088:
# 1089: Hobos.
# 1090:
# 1091: Queefing.
# 1092:
# 1093: The guys from
# 1094: Queer Eye.
# 1095:
# 1096: Cardi B.
# 1097:
# 1098: Viagra.®
# 1099:
# 1100: Soup that is
# 1101: too hot.
# 1102:
# 1103: Muhammad
# 1104: (Peace Be
# 1105: Upon Him).
# 1106:
# 1107: Explaining how
# 1108: vaginas work.
# 1109:
# 1110: Doin’ it in
# 1111: the butt.
# 1112:
# 1113: My ex-wife.
# 1114:
# 1115: Teaching a robot
# 1116: to love.
# 1117:
# 1118: Touching a pug
# 1119: right on his penis.
# 1120:
# 1121: Academy
# 1122: Award winner
# 1123: Meryl Streep.
# 1124:
# 1125: Drinking alone.
# 1126:
# 1127: Dick fingers.
# 1128:
# 1129: Multiple stab
# 1130: wounds.
# 1131:
# 1132: A windmill full
# 1133: of corpses.
# 1134:
# 1135: Count Chocula.
# 1136:
# 1137: Vladimir Putin.
# 1138:
# 1139: The Patriarchy.
# 1140:
# 1141: Poopy diapers.
# 1142:
# 1143: Child abuse.
# 1144:
# 1145: Anal beads.
# 1146:
# 1147: Slaughtering
# 1148: innocent civilians.
# 1149:
# 1150: The glass ceiling.
# 1151:
# 1152: Vomiting seafood
# 1153: and bleeding
# 1154: anally.
# 1155:
# 1156: The American
# 1157: Dream.
# 1158:
# 1159: Not wearing
# 1160: pants.
# 1161:
# 1162: Pulling out.
# 1163:
# 1164: Being able to talk
# 1165: to elephants.
# 1166:
# 1167: Horse meat.
# 1168:
# 1169: A really cool hat.
# 1170:
# 1171: My balls on
# 1172: your face.
# 1173:
# 1174: Pooping in
# 1175: a laptop and
# 1176: closing it.
# 1177:
# 1178: Dead babies.
# 1179:
# 1180: Foreskin.
# 1181:
# 1182: Stalin.
# 1183:
# 1184: A stray pube.
# 1185:
# 1186: Worshipping
# 1187: that pussy.
# 1188:
# 1189: Completely
# 1190: unwarranted
# 1191: confidence.
# 1192:
# 1193: A saxophone solo.
# 1194:
# 1195: Italians.
# 1196:
# 1197: A fetus.
# 1198:
# 1199: Firing a rifle into
# 1200: the air while
# 1201: balls deep in a
# 1202: squealing hog.
# 1203:
# 1204: Mike Pence.
# 1205:
# 1206: 10,000 Syrian
# 1207: refugees.
# 1208:
# 1209: Forced
# 1210: sterilization.
# 1211:
# 1212: My relationship
# 1213: status.
# 1214:
# 1215: Nicolas Cage.
# 1216:
# 1217: Child beauty
# 1218: pageants.
# 1219:
# 1220: Explosions.
# 1221:
# 1222: Not vaccinating
# 1223: my children
# 1224: because I
# 1225: am stupid.
# 1226:
# 1227: An unwanted
# 1228: pregnancy.
# 1229:
# 1230: Diversity.
# 1231:
# 1232: A white
# 1233: ethnostate.
# 1234:
# 1235: Bees?
# 1236:
# 1237: Lena Dunham.
# 1238:
# 1239: Huffing spray
# 1240: paint.
# 1241:
# 1242: A man on the
# 1243: brink of orgasm.
# 1244:
# 1245: Repression.
# 1246:
# 1247: Harry Potter
# 1248: erotica.
# 1249:
# 1250: Giving birth to
# 1251: the Antichrist.
# 1252:
# 1253: Three dicks at
# 1254: the same time.
# 1255:
# 1256: Nazis.
# 1257:
# 1258: Invading Poland.
# 1259:
# 1260: My vagina.
# 1261:
# 1262: Assless chaps.
# 1263:
# 1264: Murder.
# 1265:
# 1266: 8 oz. of sweet
# 1267: Mexican black-tar
# 1268: heroin.
# 1269:
# 1270: What that
# 1271: mouth do.
# 1272:
# 1273: Dead parents.
# 1274:
# 1275: Object
# 1276: permanence.
# 1277:
# 1278: Giving 110%.
# 1279:
# 1280: Her Majesty,
# 1281: Queen Elizabeth II.
# 1282:
# 1283: The Trail of Tears.
# 1284:
# 1285: Memes.
# 1286:
# 1287: Opposable
# 1288: thumbs.
# 1289:
# 1290: Racially-biased
# 1291: SAT questions.
# 1292:
# 1293: The Great
# 1294: Depression.
# 1295:
# 1296: Chainsaws
# 1297: for hands.
# 1298:
# 1299: Sex with animals.
# 1300:
# 1301: Being
# 1302: marginalized.
# 1303:
# 1304: Goblins.
# 1305:
# 1306: Hope.
# 1307:
# 1308: Liberals.
# 1309:
# 1310: A micropenis.
# 1311:
# 1312: My soul.
# 1313:
# 1314: A ball of earwax,
# 1315: semen, and
# 1316: toenail clippings.
# 1317:
# 1318: Illegal
# 1319: immigrants.
# 1320:
# 1321: Elderly
# 1322: Japanese men.
# 1323:
# 1324: The female
# 1325: orgasm.
# 1326:
# 1327: Heteronormativity.
# 1328:
# 1329: A horde
# 1330: of Vikings.
# 1331:
# 1332: Hot people.
# 1333:
# 1334: Seething with
# 1335: quiet resentment.
# 1336:
# 1337: An Oedipus
# 1338: complex.
# 1339:
# 1340: Crumbs all over
# 1341: the god damn
# 1342: carpet.
# 1343:
# 1344: Arnold
# 1345: Schwarzenegger.
# 1346:
# 1347: The wifi
# 1348: password.
# 1349:
# 1350: Spectacular abs.
# 1351:
# 1352: Geese.
# 1353:
# 1354: Extremely tight
# 1355: pants.
# 1356:
# 1357: Fox News.
# 1358:
# 1359: A little boy who
# 1360: won’t shut the
# 1361: fuck up about
# 1362: dinosaurs.
# 1363:
# 1364: A bird that shits
# 1365: human turds.
# 1366:
# 1367: A mopey zoo lion.
# 1368:
# 1369: A bag of
# 1370: magic beans.
# 1371:
# 1372: Poor life choices.
# 1373:
# 1374: Making a pouty
# 1375: face.
# 1376:
# 1377: Vehicular
# 1378: manslaughter.
# 1379:
# 1380: Women’s
# 1381: suffrage.
# 1382:
# 1383: Some guy.
# 1384:
# 1385: My sex life.
# 1386:
# 1387: Auschwitz.
# 1388:
# 1389: A snapping turtle
# 1390: biting the tip of
# 1391: your penis.
# 1392:
# 1393: All the dudes
# 1394: I’ve fucked.
# 1395:
# 1396: Judge Judy.
# 1397:
# 1398: African children.
# 1399:
# 1400: This month’s
# 1401: mass shooting.
# 1402:
# 1403: Barack Obama.
# 1404:
# 1405: The clitoris.
# 1406:
# 1407: The Big Bang.
# 1408:
# 1409: Land mines.
# 1410:
# 1411: The entire Mormon
# 1412: Tabernacle Choir.
# 1413:
# 1414: A micropig
# 1415: wearing a tiny
# 1416: raincoat and
# 1417: booties.
# 1418:
# 1419: Penis breath.
# 1420:
# 1421: Jerking off into a
# 1422: pool of children’s
# 1423: tears.
# 1424:
# 1425: Man meat.
# 1426:
# 1427: Farting and
# 1428: walking away.
# 1429:
# 1430: Being a dick
# 1431: to children.
# 1432:
# 1433: One trillion
# 1434: dollars.
# 1435:
# 1436: Drowning the kids
# 1437: in the bathtub.
# 1438:
# 1439: Me time.
# 1440:
# 1441: The Underground
# 1442: Railroad.
# 1443:
# 1444: Poorly-timed
# 1445: Holocaust jokes.
# 1446:
# 1447: A sea of troubles.
# 1448:
# 1449: Dying.
# 1450:
# 1451: Drinking out of
# 1452: the toilet and
# 1453: eating garbage.
# 1454:
# 1455: The gays.
# 1456:
# 1457: The screams...
# 1458: the terrible
# 1459: screams.
# 1460:
# 1461: Lumberjack
# 1462: fantasies.
# 1463:
# 1464: Morgan
# 1465: Freeman’s voice.
# 1466:
# 1467: Women in yogurt
# 1468: commercials.
# 1469:
# 1470: Natural male
# 1471: enhancement.
# 1472:
# 1473: Men.
# 1474:
# 1475: The bombing of
# 1476: Nagasaki.
# 1477:
# 1478: Fake tits.
# 1479:
# 1480: The Amish.
# 1481:
# 1482: Being a
# 1483: motherfucking
# 1484: sorcerer.
# 1485:
# 1486: My black ass.
# 1487:
# 1488: Genuine human
# 1489: connection.
# 1490:
# 1491: Announcing that
# 1492: I am about to cum.
# 1493:
# 1494: David Bowie
# 1495: flying in on a tiger
# 1496: made of lightning.
# 1497:
# 1498: My ugly face and
# 1499: bad personality.
# 1500:
# 1501: A bitch slap.
# 1502:
# 1503: A brain tumor.
# 1504:
# 1505: Balls.
# 1506:
# 1507: Grandma.
# 1508:
# 1509: Friction.
# 1510:
# 1511: Chunks of
# 1512: dead hitchhiker.
# 1513:
# 1514: Fear itself.
# 1515:
# 1516: Jews, gypsies,
# 1517: and homosexuals.
# 1518:
# 1519: The milkman.
# 1520:
# 1521: Cards Against
# 1522: Humanity.
# 1523:
# 1524: Hey Reddit! I’m
# 1525: __________________.
# 1526: Ask me anything.
# 1527:
# 1528: Introducing
# 1529: X-treme Baseball!
# 1530: It’s like baseball,
# 1531: but with __________!
# 1532:
# 1533: What is Batman’s
# 1534: guilty pleasure.
# 1535:
# 1536: TSA guidelines
# 1537: now prohibit
# 1538: __________________
# 1539: on airplanes.
# 1540:
# 1541: When Pharaoh
# 1542: remained unmoved,
# 1543: Moses called
# 1544: down a Plague of
# 1545: __________________.
# 1546:
# 1547: Just once, I’d
# 1548: like to hear you
# 1549: say “Thanks,
# 1550: Mom. Thanks for
# 1551: _________________.”
# 1552:
# 1553: Daddy, why is
# 1554: mommy crying?
# 1555:
# 1556: When I was
# 1557: tripping on acid,
# 1558: __________________
# 1559: turned into
# 1560: _________________.
# 1561:
# 1562: Next from
# 1563: J.K. Rowling:
# 1564: Harry Potter and
# 1565: the Chamber of
# 1566: __________________.
# 1567:
# 1568: That’s right, I killed
# 1569: _________________.
# 1570: How, you ask?
# 1571: _________________.
# 1572:
# 1573: I’m sorry,
# 1574: Professor, but I
# 1575: couldn’t complete
# 1576: my homework
# 1577: because of
# 1578: __________.
# 1579:
# 1580: And the Academy
# 1581: Award for
# 1582: __________________
# 1583: goes to __________.
# 1584:
# 1585: 50% of all
# 1586: marriages end in
# 1587: __________________.
# 1588:
# 1589: My fellow
# 1590: Americans: Before
# 1591: this decade is
# 1592: out, we will have
# 1593: __________________
# 1594: on the moon!
# 1595:
# 1596: This season at
# 1597: Steppenwolf,
# 1598: Samuel Beckett’s
# 1599: classic existential
# 1600: play: Waiting for
# 1601: __________________.
# 1602:
# 1603: Instead of coal,
# 1604: Santa now gives
# 1605: the bad children
# 1606: __________________.
# 1607:
# 1608: Dude, do not go
# 1609: in that bathroom.
# 1610: There’s __________
# 1611: in there.
# 1612:
# 1613: How did I lose
# 1614: my virginity?
# 1615:
# 1616: It’s a pity that kids
# 1617: these days are all
# 1618: getting involved
# 1619: with _____________.
# 1620:
# 1621: Step 1: __________.
# 1622: Step 2: __________.
# 1623: Step 3: Profit.
# 1624:
# 1625: _________________.
# 1626: Betcha can’t have
# 1627: just one!
# 1628:
# 1629: Kids, I don’t need
# 1630: drugs to get
# 1631: high. I’m high on
# 1632: __________.
# 1633:
# 1634: For my next trick, I
# 1635: will pull __________
# 1636: out of ___________.
# 1637:
# 1638: What’s my
# 1639: secret power?
# 1640:
# 1641: In the Disney
# 1642: Channel Original
# 1643: Movie, Hannah
# 1644: Montana struggles
# 1645: with _____________
# 1646: for the first time.
# 1647:
# 1648: I’m going on
# 1649: a cleanse this
# 1650: week. Nothing
# 1651: but kale juice and
# 1652: __________________.
# 1653:
# 1654: While the United
# 1655: States raced the Soviet
# 1656: Union to the moon, the
# 1657: Mexican government
# 1658: funneled millions of
# 1659: pesos into research on
# 1660: _____________________.
# 1661:
# 1662: ________ + ________
# 1663: = ________________.
# 1664:
# 1665: Life for American
# 1666: Indians was forever
# 1667: changed when
# 1668: the White Man
# 1669: introduced them to
# 1670: __________________.
# 1671:
# 1672: What’s Teach For
# 1673: America using
# 1674: to inspire inner
# 1675: city students to
# 1676: succeed?
# 1677:
# 1678: Mabe she’s
# 1679: born with it.
# 1680: Maybe it’s
# 1681: __________________.
# 1682:
# 1683: What is
# 1684: George W. Bush
# 1685: thinking about
# 1686: right now?
# 1687:
# 1688: White people like
# 1689: __________________.
# 1690:
# 1691: __________________
# 1692: is a slippery slope
# 1693: that leads to
# 1694: _________________.
# 1695:
# 1696: Why do I hurt
# 1697: all over?
# 1698:
# 1699: A romantic,
# 1700: candlelit dinner
# 1701: would be
# 1702: incomplete without
# 1703: __________________.
# 1704:
# 1705: Just saw this
# 1706: upsetting video!
# 1707: Please retweet!!
# 1708: #stop_____________
# 1709:
# 1710: Fun tip! When your
# 1711: man asks you to go
# 1712: down on him, try
# 1713: surprising him with
# 1714: __________________
# 1715: instead.
# 1716:
# 1717: The class field trip
# 1718: was completely
# 1719: ruined by
# 1720: __________________.
# 1721:
# 1722: What’s a girl’s
# 1723: best friend?
# 1724:
# 1725: Dear Abby,
# 1726: I’m having
# 1727: some trouble with
# 1728: __________________
# 1729: and would like
# 1730: your advice.
# 1731:
# 1732: In M. Night
# 1733: Shyamalan’s new
# 1734: movie, Bruce Willis
# 1735: discovers that
# 1736: __________had really
# 1737: been _______________
# 1738: all along.
# 1739:
# 1740: When I am
# 1741: President,
# 1742: I will create the
# 1743: Department of
# 1744: __________________.
# 1745:
# 1746: What are my
# 1747: parents hiding
# 1748: from me?
# 1749:
# 1750: What never fails to
# 1751: liven up the party?
# 1752:
# 1753: IF you like
# 1754: __________________,
# 1755: YOU MIGHT BE
# 1756: A REDNECK.
# 1757:
# 1758: Make a haiku.
# 1759:
# 1760: What made my first
# 1761: kiss so awkward?
# 1762:
# 1763: I got 99 problems
# 1764: but _______________
# 1765: ain’t one.
# 1766:
# 1767: __________________.
# 1768: It’s a trap!
# 1769:
# 1770: Bravo’s new reality
# 1771: show features
# 1772: eight washed-up
# 1773: celebrities living
# 1774: with _____________.
# 1775:
# 1776: I’m no doctor
# 1777: but I’m pretty
# 1778: sure what you’re
# 1779: suffering from is
# 1780: called “__________.”
# 1781:
# 1782: They said we were
# 1783: crazy. They said
# 1784: we couldn’t put
# 1785: __________________
# 1786: inside of _________.
# 1787: They were wrong.
# 1788:
# 1789: What’s that smell?
# 1790:
# 1791: What’s there a
# 1792: ton of in heaven?
# 1793:
# 1794: What will always
# 1795: get you laid?
# 1796:
# 1797: After four platinum
# 1798: albums and three
# 1799: Grammys, it’s time to
# 1800: get back to my roots,
# 1801: to what inspired me
# 1802: to make music in the
# 1803: first place: __________.
# 1804:
# 1805: Lifetime® presents
# 1806: “_________________:
# 1807: the Story of
# 1808: _________________.”
# 1809:
# 1810: __________________:
# 1811: kid-tested,
# 1812: mother-approved.
# 1813:
# 1814: Why can’t I sleep
# 1815: at night?
# 1816:
# 1817: After eight years in
# 1818: the White House,
# 1819: how is Obama
# 1820: finally letting
# 1821: loose?
# 1822:
# 1823: This is the way the
# 1824: world ends This is
# 1825: the way the world
# 1826: ends Not with
# 1827: a bang but with
# 1828: __________________.
# 1829:
# 1830: Coming
# 1831: to Broadway
# 1832: this season,
# 1833: __________________:
# 1834: The Musical.
# 1835:
# 1836: Hey guys,
# 1837: welcome to Chili’s!
# 1838: Would you like
# 1839: to start the night
# 1840: off right with
# 1841: _________________?
# 1842:
# 1843: What would
# 1844: grandma find
# 1845: disturbing, yet
# 1846: oddly charming?
# 1847:
# 1848: __________________.
# 1849: That was so metal.
# 1850:
# 1851: I never truly
# 1852: understood
# 1853: __________________
# 1854: until I encountered
# 1855: _________________.
# 1856:
# 1857: During sex, I like
# 1858: to think about
# 1859: __________________.
# 1860:
# 1861: Here is the church
# 1862: Here is the steeple
# 1863: Open the doors
# 1864: And there is
# 1865: __________________.
# 1866:
# 1867: But before I kill
# 1868: you, Mr. Bond,
# 1869: I must show you
# 1870: __________________.
# 1871:
# 1872: A recent laboratory
# 1873: study shows that
# 1874: undergraduates have
# 1875: 50% less sex after
# 1876: being exposed to
# 1877: ___________________.
# 1878:
# 1879: Introducing
# 1880: the amazing
# 1881: superhero/sidekick
# 1882: duo! It’s __________
# 1883: and _____________!
# 1884:
# 1885: What ended my
# 1886: last relationship?
# 1887:
# 1888: What’s that sound?
# 1889:
# 1890: Uh, hey guys,
# 1891: I know this was my
# 1892: idea, but I’m having
# 1893: serious doubts
# 1894: about ____________.
# 1895:
# 1896: Why am I sticky?
# 1897:
# 1898: Next on ESPN2:
# 1899: The World Series of
# 1900: __________________.
# 1901:
# 1902: When I am a
# 1903: billionaire, I shall
# 1904: erect a 50-foot
# 1905: statue to
# 1906: commemorate
# 1907: __________________.
# 1908:
# 1909: Military historians
# 1910: remember Alexander
# 1911: the Great for his
# 1912: brilliant use of
# 1913: ____________________
# 1914: against the Persians.
# 1915:
# 1916: War!
# 1917: What is it good for?
# 1918:
# 1919: Terms of Use
# 1920:
# 1921: Thanks for downloading this all over your computer.
# 1922:
# 1923: Cards Against Humanity is free to use under the Creative Commons
# 1924: BY-NC-SA 2.0 License. You can read more about the license at
# 1925: http://creativecommons.org/licenses/by-nc-sa/2.0/.
# 1926:
# 1927: These are the terms of the copyright:
# 1928:
# 1929: Attribution: If you distribute our game, give us credit for the content.
# 1930:
# 1931: Noncommercial: You can’t sell our game or any derivative of our
# 1932: game for money or sexual favors.
# 1933:
# 1934: Share Alike: If you modify and/or distribute our game, you must use
# 1935: the Creative Commons BY-NC-SA 2.0 License.
# 1936:
# 1937: You must also comply with the Laws of Man and Nature. Don’t use
# 1938: any form of this game for nefarious purposes like libel, slander, diarrhea,
# 1939: copyright infringement, harassment, or death. If you break the law and get in
# 1940: trouble for it, Cards Against Humanity is free of all liability.
# 1941:
# 1942:

# %%
if CAHFileName == "CAH_MainGame.txt":
    # Inititalising variables
    AnswerLineStart = 133 # the line number in which the answer cards start
    AnswerLineEnd = 1524 # the line number in which the end of the last answer card is located
    QuestionLineStart = 1524 # the line number in which the question cards start
    QuestionLineEnd = 1919 # the line number in which the end of the last question card is located
elif CAHFileName == "CAH_Family_SmallCards.txt":
    # Inititalising variables
    AnswerLineStart = 551 # the line number in which the answer cards start
    AnswerLineEnd = 1877 # the line number in which the end of the last answer card is located
    QuestionLineStart = 65 # the line number in which the question cards start
    QuestionLineEnd = 551 # the line number in which the end of the last question card is located

# %%
import string # imports tring to be able to access the constant punctuation to be able to strip the answer cards

FinishedQCards = []

# calling functions
ListOfLines = ReadInFile(CAHFileName) # makes ListOfLines equal a list of all the lines of the file
AnswerCards = ReturnCards(AnswerLineStart, AnswerLineEnd, ListOfLines) # makes the AnswerCards equal a list of all the answer cards
QuestionCards = ReturnCards(QuestionLineStart, QuestionLineEnd, ListOfLines) # makes the QuestionCards equal a list of all the question cards

# for loop to go thorugh all the cards and strip all the punctuation such as ? , . ! at the end of the of each card
for index in range(len(AnswerCards) - 1):
    AnswerCards[index] = AnswerCards[index].strip(string.punctuation)
    AnswerCards[index] = AnswerCards[index].strip()

# a for loop to go through all the question cards and change them
for index in range(len(QuestionCards) - 1):
    QCard, NumOfGaps = GapReplace(QuestionCards[index])
    # saves all the cards and number of gaps in a tuples inside the list
    FinishedQCards.append((QCard, NumOfGaps))

# %%
FinishedQCards # prints out the question cards
# Out:
# [('Hey Reddit! I’m {}. Ask me anything.', 1),
#  ('Introducing X-treme Baseball! It’s like baseball, but with {}!', 1),
#  ('What is Batman’s guilty pleasure. {}', 1),
#  ('TSA guidelines now prohibit {} on airplanes.', 1),
#  ('When Pharaoh remained unmoved, Moses called down a Plague of {}.', 1),
#  ('Just once, I’d like to hear you say “Thanks, Mom. Thanks for {}.”', 1),
#  ('Daddy, why is mommy crying? {}', 1),
#  ('When I was tripping on acid, {} turned into {}.', 2),
#  ('Next from J.K. Rowling: Harry Potter and the Chamber of {}.', 1),
#  ('That’s right, I killed {}. How, you ask? {}.', 2),
#  ('I’m sorry, Professor, but I couldn’t complete my homework because of {}.',
#   1),
#  ('And the Academy Award for {} goes to {}.', 2),
#  ('50% of all marriages end in {}.', 1),
#  ('My fellow Americans: Before this decade is out, we will have {} on the moon!',
#   1),
#  ('This season at Steppenwolf, Samuel Beckett’s classic existential play: Waiting for {}.',
#   1),
#  ('Instead of coal, Santa now gives the bad children {}.', 1),
#  ('Dude, do not go in that bathroom. There’s {} in there.', 1),
#  ('How did I lose my virginity? {}', 1),
#  ('It’s a pity that kids these days are all getting involved with {}.', 1),
#  ('Step 1: {}. Step 2: {}. Step 3: Profit.', 2),
#  ('{}. Betcha can’t have just one!', 1),
#  ('Kids, I don’t need drugs to get high. I’m high on {}.', 1),
#  ('For my next trick, I will pull {} out of {}.', 2),
#  ('What’s my secret power? {}', 1),
#  ('In the Disney Channel Original Movie, Hannah Montana struggles with {} for the first time.',
#   1),
#  ('I’m going on a cleanse this week. Nothing but kale juice and {}.', 1),
#  ('While the United States raced the Soviet Union to the moon, the Mexican government funneled millions of pesos into research on {}.',
#   1),
#  ('{} + {} = {}.', 3),
#  ('Life for American Indians was forever changed when the White Man introduced them to {}.',
#   1),
#  ('What’s Teach For America using to inspire inner city students to succeed? {}',
#   1),
#  ('Mabe she’s born with it. Maybe it’s {}.', 1),
#  ('What is George W. Bush thinking about right now? {}', 1),
#  ('White people like {}.', 1),
#  ('{} is a slippery slope that leads to {}.', 2),
#  ('Why do I hurt all over? {}', 1),
#  ('A romantic, candlelit dinner would be incomplete without {}.', 1),
#  ('Just saw this upsetting video! Please retweet!! #stop{}', 1),
#  ('Fun tip! When your man asks you to go down on him, try surprising him with {} instead.',
#   1),
#  ('The class field trip was completely ruined by {}.', 1),
#  ('What’s a girl’s best friend? {}', 1),
#  ('Dear Abby, I’m having some trouble with {} and would like your advice.', 1),
#  ('In M. Night Shyamalan’s new movie, Bruce Willis discovers that {}had really been {} all along.',
#   2),
#  ('When I am President, I will create the Department of {}.', 1),
#  ('What are my parents hiding from me? {}', 1),
#  ('What never fails to liven up the party? {}', 1),
#  ('IF you like {}, YOU MIGHT BE A REDNECK.', 1),
#  ('Make a haiku. {}', 1),
#  ('What made my first kiss so awkward? {}', 1),
#  ('I got 99 problems but {} ain’t one.', 1),
#  ('{}. It’s a trap!', 1),
#  ('Bravo’s new reality show features eight washed-up celebrities living with {}.',
#   1),
#  ('I’m no doctor but I’m pretty sure what you’re suffering from is called “{}.”',
#   1),
#  ('They said we were crazy. They said we couldn’t put {} inside of {}. They were wrong.',
#   2),
#  ('What’s that smell? {}', 1),
#  ('What’s there a ton of in heaven? {}', 1),
#  ('What will always get you laid? {}', 1),
#  ('After four platinum albums and three Grammys, it’s time to get back to my roots, to what inspired me to make music in the first place: {}.',
#   1),
#  ('Lifetime® presents “{}: the Story of {}.”', 2),
#  ('{}: kid-tested, mother-approved.', 1),
#  ('Why can’t I sleep at night? {}', 1),
#  ('After eight years in the White House, how is Obama finally letting loose? {}',
#   1),
#  ('This is the way the world ends This is the way the world ends Not with a bang but with {}.',
#   1),
#  ('Coming to Broadway this season, {}: The Musical.', 1),
#  ('Hey guys, welcome to Chili’s! Would you like to start the night off right with {}?',
#   1),
#  ('What would grandma find disturbing, yet oddly charming? {}', 1),
#  ('{}. That was so metal.', 1),
#  ('I never truly understood {} until I encountered {}.', 2),
#  ('During sex, I like to think about {}.', 1),
#  ('Here is the church Here is the steeple Open the doors And there is {}.', 1),
#  ('But before I kill you, Mr. Bond, I must show you {}.', 1),
#  ('A recent laboratory study shows that undergraduates have 50% less sex after being exposed to {}.',
#   1),
#  ('Introducing the amazing superhero/sidekick duo! It’s {} and {}!', 2),
#  ('What ended my last relationship? {}', 1),
#  ('What’s that sound? {}', 1),
#  ('Uh, hey guys, I know this was my idea, but I’m having serious doubts about {}.',
#   1),
#  ('Why am I sticky? {}', 1),
#  ('Next on ESPN2: The World Series of {}.', 1),
#  ('When I am a billionaire, I shall erect a 50-foot statue to commemorate {}.',
#   1),
#  ('Military historians remember Alexander the Great for his brilliant use of {} against the Persians.',
#   1)]

# %%
AnswerCards # prints out the answer cards
# Out:
# ['Flesh-eating bacteria',
#  'Flying sex snakes',
#  'Not giving a shit about the Third World',
#  'Magnets',
#  'Shapeshifters',
#  'Seeing what happens when you lock people in a room with hungry seagulls',
#  'A crucifixion',
#  'Jennifer Lawrence',
#  '72 virgins',
#  'A live studio audience',
#  'A time travel paradox',
#  'Authentic Mexican cuisine',
#  'Doing crimes',
#  'Synergistic management solutions',
#  'Crippling debt',
#  'Daddy issues',
#  'Used panties',
#  'A fart so powerful that it wakes the giants from their thousand-year slumber',
#  'Former President George W. Bush',
#  'Full frontal nudity',
#  'Soft, kissy missionary sex',
#  'BATMAN',
#  'Agriculture',
#  'Barely making $25,000 a year',
#  'Covering myself with Parmesan cheese and chili flakes because I am pizza',
#  'Having big dreams but no realistic way to achieve them',
#  'Laying an egg',
#  'Getting naked and watching Nickelodeon',
#  'Pretending to care',
#  'Natural selection',
#  'Coat hanger abortions',
#  'Sex with Patrick Stewart',
#  'Seeing Grandma naked',
#  'Boogers',
#  'The inevitable heat death of the universe',
#  'Prescription pain killers',
#  'Swooping',
#  'Mansplaining',
#  'My abusive boyfriend who really isn’t so bad once you get to know him',
#  'A homoerotic volleyball montage',
#  'The miracle of childbirth',
#  'The Rapture',
#  'Whipping it out',
#  'White privilege',
#  'Alexandria Ocasio-Cortez',
#  'Putting things where they go',
#  'Fragile masculinity',
#  'All-you-can-eat shrimp for $8.99',
#  'Emerging from the sea and rampaging through Tokyo',
#  'The Hamburglar',
#  'AXE Body Spray',
#  'The Blood of Christ',
#  'An old guy who’s almost dead',
#  'Kanye West',
#  'Hot cheese',
#  'Raptor attacks',
#  'Seven dead and three in critical condition',
#  'Smegma',
#  'Alcoholism',
#  'A middle-aged man on roller skates',
#  'The past',
#  'My genitals',
#  'An endless stream of diarrhea',
#  'Science',
#  'Bingeing and purging',
#  'An oversized lollipop',
#  'Self-loathing',
#  'Not reciprocating oral sex',
#  'Flightless birds',
#  'A good sniff',
#  'Looking in the mirror, applying lipstick, and whispering “tonight, you will have sex with Tom Cruise.”',
#  'Sitting on my face and telling me I’m garbage',
#  'Half-assed foreplay',
#  'The Holy Bible',
#  'German dungeon porn',
#  'A balanced breakfast',
#  'Dead birds everywhere',
#  'The arrival of the pizza',
#  '50,000 volts straight to the nipples',
#  'Permanent Orgasm-Face Disorder',
#  'Being on fire',
#  'Teenage pregnancy',
#  'Gandhi',
#  'Your weird brother',
#  'The cool, refreshing taste of Pepsi.®',
#  'Chemical weapons',
#  'Oprah',
#  'Wondering if it’s possible to get some of that salsa to go',
#  'A Fleshlight.®',
#  'A pyramid of severed heads',
#  'An erection that lasts longer than four hours',
#  'A three-way with my wife and Shaquille O’Neal',
#  'Bananas',
#  'Passive aggressive Post-it notes',
#  'Hillary Clinton’s emails',
#  'Switching to Geico.®',
#  'Peeing a little bit',
#  'Wet dreams',
#  'The Jews',
#  'My cheating son-of-a-bitch husband',
#  'Poverty',
#  'Kamikaze pilots',
#  'Committing suicide',
#  'The homosexual agenda',
#  'Powerful thighs',
#  'These hoes',
#  'The only gay person in a hundred miles',
#  'Having sex for the first time',
#  'A Mexican',
#  'A falcon with a cap on its head',
#  'Wizard music',
#  'The Kool-Aid Man',
#  'Donald J. Trump',
#  'Kissing grandma on the forehead and turning off her life support',
#  'Sexual tension',
#  'An AR-15 assault rifle',
#  'Juuling',
#  'Free samples',
#  'Hurting those closest to me',
#  'Doing the right thing',
#  'My good bra',
#  'Punching a congressman in the face',
#  'Fancy Feast.®',
#  'Being rich',
#  'The Three-Fifths Compromise',
#  'Lactation',
#  'World peace',
#  'Shutting up so I can watch the game',
#  'Sweet, sweet vengeance',
#  'Republicans',
#  'Sniffing and kissing my feet',
#  'A much younger woman',
#  'Eating a hard boiled egg out of my husband’s asshole',
#  'RoboCop',
#  'One titty hanging out',
#  'Justin Bieber',
#  'Oompa-Loompas',
#  'Inappropriate yodeling',
#  'Puberty',
#  'Ghosts',
#  'Expecting a burp and vomiting on the floor',
#  'Adderall.®',
#  'The Red Hot Chili Peppers',
#  'Sideboob',
#  '50 mg of Zoloft daily',
#  'Fucking my sister',
#  'Braiding three penises into a Twizzler',
#  'Vigorous jazz hands',
#  'An octopus giving seven handjobs and smoking a cigarette',
#  'My neck, my back, my pussy, and my crack',
#  'J.D. Power and his associates',
#  'Mouth herpes',
#  'Getting fingered',
#  'My Uber driver, Pavel',
#  'GoGurt.®',
#  'Police brutality',
#  'Sperm whales',
#  'Women of color',
#  'Incest',
#  'Men discussing their feelings in an emotionally healthy way',
#  'Filling my briefcase with business stuff',
#  'Preteens',
#  'My fat daughter',
#  'Rap music',
#  'Pac-Man uncontrollably guzzling cum',
#  'Casually suggesting a threesome',
#  'Running out of semen',
#  'God',
#  'Fading away into nothingness',
#  'Darth Vader',
#  'A sad handjob',
#  'Exactly what you’d expect',
#  'The wonders of the Orient',
#  'Sexual peeing',
#  'Emotions',
#  'Licking things to claim them as your own',
#  'Jobs',
#  'The placenta',
#  'Spontaneous human combustion',
#  'The Bachelorette season finale',
#  'A tiny horse',
#  'William Shatner',
#  'Selling crack to children',
#  'An M. Night Shyamalan plot twist',
#  'Throwing grapes at a man until he loses touch with reality',
#  'Establishing dominance',
#  'Finger painting',
#  'Old-people smell',
#  'Brown people',
#  'Mutually assured destruction',
#  'Pedophiles',
#  'Yeast',
#  'Getting crushed by a vending machine',
#  'My inner demons',
#  'A Super Soaker™ full of cat pee',
#  'Aaron Burr',
#  'How bad my daughter fucked up her dance recital',
#  'Rectangles',
#  'Catapults',
#  'Poor people',
#  'Cuddling',
#  'However much weed $20 can buy',
#  'Battlefield amputations',
#  'Spaghetti? Again',
#  'Only dating Asian women',
#  'The Hustle',
#  'The Force',
#  'How amazing it is to be on mushrooms',
#  'Ronald Reagan',
#  'A disappointing birthday party',
#  'Nachos for the table',
#  'Becoming a blueberry',
#  'Judging everyone',
#  'Kourtney, Kim, Khloe, Kendall, and Kylie',
#  'Getting married, having a few kids, buying some stuff, retiring to Florida, and dying',
#  'Some god damn peace and quiet',
#  'AIDS',
#  'Pictures of boobs',
#  'Strong female characters',
#  'Some foundation, mascara, and a touch of blush',
#  'Getting cummed on',
#  'Pixelated bukkake',
#  'A lifetime of sadness',
#  'Going an entire day without masturbating',
#  'Hospice care',
#  'Getting really high',
#  'The opiod epidemic',
#  'Penis envy',
#  'Dick pics',
#  'Racism',
#  'Menstrual rage',
#  'Sunshine and rainbows',
#  'Gay conversion therapy',
#  'Ruth Bader Ginsburg brutally gaveling your penis',
#  'German Chancellor Angela Merkel',
#  'The KKK',
#  'Radical Islamic terrorism',
#  'Huge biceps',
#  'My little boner',
#  'Dry heaving',
#  'Meth',
#  'Serfdom',
#  'A pangender octopus who roams the cosmos in search of love',
#  'Holding down a child and farting all over him',
#  'A gossamer stream of jizz that catches the light as it arcs through the morning air',
#  'Executing a hostage every hour',
#  'The rhythms of Africa',
#  'Breaking out into song and dance',
#  'A Bop It.™',
#  'A whole thing of butter',
#  'Still being a virgin',
#  'Solving problems with violence',
#  'Leprosy',
#  'Gloryholes',
#  'Nipple blades',
#  'The heart of a child',
#  'Puppies',
#  'Fellowship in Christ',
#  'Little boy penises. Waking up half-naked in a Denny’s parking lot',
#  'The Pope',
#  'White people',
#  'Tentacle porn',
#  'My bright pink fuckhole',
#  'An older woman who knows her way around the penis',
#  'Getting drugs off the street and into my body',
#  'Daniel Radcliffe’s delicious asshole',
#  'Active listening',
#  'How far I can get my own penis up my butt',
#  'Having anuses for eyes',
#  'The penny whistle solo from “My Heart Will Go On.”',
#  'Seppuku',
#  'Ethnic cleansing',
#  'Itchy pussy',
#  'Blowing my boyfriend so hard he shits',
#  'A fuck-ton of almonds',
#  'Danny DeVito',
#  'The magic of live theatre',
#  'Throwing a virgin into a volcano',
#  'Dwayne “The Rock” Johnson',
#  'A salad for men that’s made of metal',
#  'Waiting till marriage',
#  'Unfathomable stupidity',
#  'Shiny objects',
#  'Accepting the way things are',
#  'NBA superstar LeBron James',
#  'Therapy',
#  'Listening to her problems without trying to solve them',
#  'The Devil himself',
#  'Autocannibalism',
#  'Erectile dysfunction',
#  'My collection of Japanese sex toys',
#  'Being fat and stupid',
#  'Pooping back and forth. Forever',
#  'Tearing that ass up like wrapping paper on Christmas morning',
#  'More elephant cock than I bargained for',
#  'A salty surprise',
#  'The South',
#  'The violation of our most basic human rights',
#  'Tap dancing like there’s no tomorrow',
#  'A bowl of mayonnaise and human teeth',
#  'Fiery poops',
#  'Saying “I love you.”',
#  'Inserting a Mason jar into my anus',
#  'Consensual sex',
#  'Telling a shitty story that goes nowhere',
#  'A good, strong gorilla',
#  'Seeing my father cry',
#  'The true meaning of Christmas',
#  'Some of the best rappers in the game',
#  'Owning and operating a Chili’s franchise',
#  'Estrogen',
#  'Necrophilia',
#  'Being a woman',
#  'Getting into a pretty bad car accident',
#  'Bill Nye the Science Guy',
#  'Girls',
#  'The Russians',
#  'A bleached asshole',
#  'Fucking the weatherman on live television',
#  'Black people',
#  'The Boy Scouts of America',
#  'Lunchables.™',
#  'Bitches',
#  'PTSD',
#  'Dark and mysterious forces beyond our control',
#  'Smallpox blankets',
#  'Masturbating',
#  'Some punk kid who stole my turkey sandwich',
#  'Heartwarming orphans',
#  'Spirit Airlines',
#  'Bubble butt bottom boys',
#  'Hobos',
#  'Queefing',
#  'The guys from Queer Eye',
#  'Cardi B',
#  'Viagra.®',
#  'Soup that is too hot',
#  'Muhammad (Peace Be Upon Him',
#  'Explaining how vaginas work',
#  'Doin’ it in the butt',
#  'My ex-wife',
#  'Teaching a robot to love',
#  'Touching a pug right on his penis',
#  'Academy Award winner Meryl Streep',
#  'Drinking alone',
#  'Dick fingers',
#  'Multiple stab wounds',
#  'A windmill full of corpses',
#  'Count Chocula',
#  'Vladimir Putin',
#  'The Patriarchy',
#  'Poopy diapers',
#  'Child abuse',
#  'Anal beads',
#  'Slaughtering innocent civilians',
#  'The glass ceiling',
#  'Vomiting seafood and bleeding anally',
#  'The American Dream',
#  'Not wearing pants',
#  'Pulling out',
#  'Being able to talk to elephants',
#  'Horse meat',
#  'A really cool hat',
#  'My balls on your face',
#  'Pooping in a laptop and closing it',
#  'Dead babies',
#  'Foreskin',
#  'Stalin',
#  'A stray pube',
#  'Worshipping that pussy',
#  'Completely unwarranted confidence',
#  'A saxophone solo',
#  'Italians',
#  'A fetus',
#  'Firing a rifle into the air while balls deep in a squealing hog',
#  'Mike Pence',
#  '10,000 Syrian refugees',
#  'Forced sterilization',
#  'My relationship status',
#  'Nicolas Cage',
#  'Child beauty pageants',
#  'Explosions',
#  'Not vaccinating my children because I am stupid',
#  'An unwanted pregnancy',
#  'Diversity',
#  'A white ethnostate',
#  'Bees',
#  'Lena Dunham',
#  'Huffing spray paint',
#  'A man on the brink of orgasm',
#  'Repression',
#  'Harry Potter erotica',
#  'Giving birth to the Antichrist',
#  'Three dicks at the same time',
#  'Nazis',
#  'Invading Poland',
#  'My vagina',
#  'Assless chaps',
#  'Murder',
#  '8 oz. of sweet Mexican black-tar heroin',
#  'What that mouth do',
#  'Dead parents',
#  'Object permanence',
#  'Giving 110',
#  'Her Majesty, Queen Elizabeth II',
#  'The Trail of Tears',
#  'Memes',
#  'Opposable thumbs',
#  'Racially-biased SAT questions',
#  'The Great Depression',
#  'Chainsaws for hands',
#  'Sex with animals',
#  'Being marginalized',
#  'Goblins',
#  'Hope',
#  'Liberals',
#  'A micropenis',
#  'My soul',
#  'A ball of earwax, semen, and toenail clippings',
#  'Illegal immigrants',
#  'Elderly Japanese men',
#  'The female orgasm',
#  'Heteronormativity',
#  'A horde of Vikings',
#  'Hot people',
#  'Seething with quiet resentment',
#  'An Oedipus complex',
#  'Crumbs all over the god damn carpet',
#  'Arnold Schwarzenegger',
#  'The wifi password',
#  'Spectacular abs',
#  'Geese',
#  'Extremely tight pants',
#  'Fox News',
#  'A little boy who won’t shut the fuck up about dinosaurs',
#  'A bird that shits human turds',
#  'A mopey zoo lion',
#  'A bag of magic beans',
#  'Poor life choices',
#  'Making a pouty face',
#  'Vehicular manslaughter',
#  'Women’s suffrage',
#  'Some guy',
#  'My sex life',
#  'Auschwitz',
#  'A snapping turtle biting the tip of your penis',
#  'All the dudes I’ve fucked',
#  'Judge Judy',
#  'African children',
#  'This month’s mass shooting',
#  'Barack Obama',
#  'The clitoris',
#  'The Big Bang',
#  'Land mines',
#  'The entire Mormon Tabernacle Choir',
#  'A micropig wearing a tiny raincoat and booties',
#  'Penis breath',
#  'Jerking off into a pool of children’s tears',
#  'Man meat',
#  'Farting and walking away',
#  'Being a dick to children',
#  'One trillion dollars',
#  'Drowning the kids in the bathtub',
#  'Me time',
#  'The Underground Railroad',
#  'Poorly-timed Holocaust jokes',
#  'A sea of troubles',
#  'Dying',
#  'Drinking out of the toilet and eating garbage',
#  'The gays',
#  'The screams... the terrible screams',
#  'Lumberjack fantasies',
#  'Morgan Freeman’s voice',
#  'Women in yogurt commercials',
#  'Natural male enhancement',
#  'Men',
#  'The bombing of Nagasaki',
#  'Fake tits',
#  'The Amish',
#  'Being a motherfucking sorcerer',
#  'My black ass',
#  'Genuine human connection',
#  'Announcing that I am about to cum',
#  'David Bowie flying in on a tiger made of lightning',
#  'My ugly face and bad personality',
#  'A bitch slap',
#  'A brain tumor',
#  'Balls',
#  'Grandma',
#  'Friction',
#  'Chunks of dead hitchhiker',
#  'Fear itself',
#  'Jews, gypsies, and homosexuals',
#  'The milkman',
#  'Cards Against Humanity.']

# %% [markdown]
# ### example of how an answered question card is going to look like

# %%
import random

RandomAnsCards = []

RandomQCard = FinishedQCards[random.randint(0, (len(FinishedQCards)-1))]
for index in range(RandomQCard[1]):
    RandomAnsCards.append(AnswerCards[random.randint(0, (len(AnswerCards) - 1))])
RandomQCard[0].format(*RandomAnsCards)
# Out:
# 'Fucking my sister. Betcha can’t have just one!'

# %% [markdown]
# ### Testing the function GapReplace as it was the hardest to code

# %%
s = "i like _____ and ____ because it is good"
GapReplace(s) # should return ('i like {} and {} because it is good', 2)
# Out:
# ('i like {} and {} because it is good', 2)

# %%
s = "how many years was I here?"
GapReplace(s) # should return ('how many years was I here? {}', 1)
# Out:
# ('how many years was I here? {}', 1)

# %%
s = "i like ___ because it is good"
GapReplace(s) # should return ('i like {} because it is good', 1)
# Out:
# ('i like {} because it is good', 1)

# %%
s = "______ + __ = ________"
GapReplace(s) # should return ('{} + {} = {}', 3)
# Out:
# ('{} + {} = {}', 3)

# %% [markdown]
# ### Saves the cards in the database

# %%
import sqlite3

con = sqlite3.connect('CAH.db') # connects to the database
cur = con.cursor() # creates a cursor

# %%
# checks to see if there is already a table called AnswerCards or QuestionCards and if there is it deletes it
try:
    cur.execute("DROP TABLE AnswerCards")
    cur.execute("DROP TABLE QuestionCards")
except:
    pass

# creates the table AnswerCards for the Answer cards with the properties: id, card(the actual card)
cur.execute("""CREATE TABLE AnswerCards 
                (id INTEGER PRIMARY KEY AUTOINCREMENT,
                card text)""")

# creates the table QuestionCards for the Question cards with the properties: id, card(the actual card), NumGaps (the number of gaps in the card)
cur.execute("""CREATE TABLE QuestionCards 
                (id INTEGER PRIMARY KEY AUTOINCREMENT,
                card text,
                NumGaps int)""")

# loops through all the question cards and saves them in the table with an id added to it
for index in range(len(FinishedQCards) - 1):
    cur.execute(f"""INSERT INTO QuestionCards (card, NumGaps) VALUES ("{FinishedQCards[index][0]}", {FinishedQCards[index][1]})""")

# loops through all the answer cards and saves them in the table with an id added to it
for index in range(len(AnswerCards) - 1):
    cur.execute(f"""INSERT INTO AnswerCards (card) VALUES 
                    ("{AnswerCards[index]}")""")
    
# commits the table into the database
con.commit()

# %%
# prints out the whole table
for card in cur.execute("SELECT * FROM QuestionCards"):
    print(card)

# prints out the whole table
for card in cur.execute("SELECT * FROM AnswerCards"):
    print(card)
# Out:
# (1, 'Hey Reddit! I’m {}. Ask me anything.', 1)
# (2, 'Introducing X-treme Baseball! It’s like baseball, but with {}!', 1)
# (3, 'What is Batman’s guilty pleasure. {}', 1)
# (4, 'TSA guidelines now prohibit {} on airplanes.', 1)
# (5, 'When Pharaoh remained unmoved, Moses called down a Plague of {}.', 1)
# (6, 'Just once, I’d like to hear you say “Thanks, Mom. Thanks for {}.”', 1)
# (7, 'Daddy, why is mommy crying? {}', 1)
# (8, 'When I was tripping on acid, {} turned into {}.', 2)
# (9, 'Next from J.K. Rowling: Harry Potter and the Chamber of {}.', 1)
# (10, 'That’s right, I killed {}. How, you ask? {}.', 2)
# (11, 'I’m sorry, Professor, but I couldn’t complete my homework because of {}.', 1)
# (12, 'And the Academy Award for {} goes to {}.', 2)
# (13, '50% of all marriages end in {}.', 1)
# (14, 'My fellow Americans: Before this decade is out, we will have {} on the moon!', 1)
# (15, 'This season at Steppenwolf, Samuel Beckett’s classic existential play: Waiting for {}.', 1)
# (16, 'Instead of coal, Santa now gives the bad children {}.', 1)
# (17, 'Dude, do not go in that bathroom. There’s {} in there.', 1)
# (18, 'How did I lose my virginity? {}', 1)
# (19, 'It’s a pity that kids these days are all getting involved with {}.', 1)
# (20, 'Step 1: {}. Step 2: {}. Step 3: Profit.', 2)
# (21, '{}. Betcha can’t have just one!', 1)
# (22, 'Kids, I don’t need drugs to get high. I’m high on {}.', 1)
# (23, 'For my next trick, I will pull {} out of {}.', 2)
# (24, 'What’s my secret power? {}', 1)
# (25, 'In the Disney Channel Original Movie, Hannah Montana struggles with {} for the first time.', 1)
# (26, 'I’m going on a cleanse this week. Nothing but kale juice and {}.', 1)
# (27, 'While the United States raced the Soviet Union to the moon, the Mexican government funneled millions of pesos into research on {}.', 1)
# (28, '{} + {} = {}.', 3)
# (29, 'Life for American Indians was forever changed when the White Man introduced them to {}.', 1)
# (30, 'What’s Teach For America using to inspire inner city students to succeed? {}', 1)
# (31, 'Mabe she’s born with it. Maybe it’s {}.', 1)
# (32, 'What is George W. Bush thinking about right now? {}', 1)
# (33, 'White people like {}.', 1)
# (34, '{} is a slippery slope that leads to {}.', 2)
# (35, 'Why do I hurt all over? {}', 1)
# (36, 'A romantic, candlelit dinner would be incomplete without {}.', 1)
# (37, 'Just saw this upsetting video! Please retweet!! #stop{}', 1)
# (38, 'Fun tip! When your man asks you to go down on him, try surprising him with {} instead.', 1)
# (39, 'The class field trip was completely ruined by {}.', 1)
# (40, 'What’s a girl’s best friend? {}', 1)
# (41, 'Dear Abby, I’m having some trouble with {} and would like your advice.', 1)
# (42, 'In M. Night Shyamalan’s new movie, Bruce Willis discovers that {}had really been {} all along.', 2)
# (43, 'When I am President, I will create the Department of {}.', 1)
# (44, 'What are my parents hiding from me? {}', 1)
# (45, 'What never fails to liven up the party? {}', 1)
# (46, 'IF you like {}, YOU MIGHT BE A REDNECK.', 1)
# (47, 'Make a haiku. {}', 1)
# (48, 'What made my first kiss so awkward? {}', 1)
# (49, 'I got 99 problems but {} ain’t one.', 1)
# (50, '{}. It’s a trap!', 1)
# (51, 'Bravo’s new reality show features eight washed-up celebrities living with {}.', 1)
# (52, 'I’m no doctor but I’m pretty sure what you’re suffering from is called “{}.”', 1)
# (53, 'They said we were crazy. They said we couldn’t put {} inside of {}. They were wrong.', 2)
# (54, 'What’s that smell? {}', 1)
# (55, 'What’s there a ton of in heaven? {}', 1)
# (56, 'What will always get you laid? {}', 1)
# (57, 'After four platinum albums and three Grammys, it’s time to get back to my roots, to what inspired me to make music in the first place: {}.', 1)
# (58, 'Lifetime® presents “{}: the Story of {}.”', 2)
# (59, '{}: kid-tested, mother-approved.', 1)
# (60, 'Why can’t I sleep at night? {}', 1)
# (61, 'After eight years in the White House, how is Obama finally letting loose? {}', 1)
# (62, 'This is the way the world ends This is the way the world ends Not with a bang but with {}.', 1)
# (63, 'Coming to Broadway this season, {}: The Musical.', 1)
# (64, 'Hey guys, welcome to Chili’s! Would you like to start the night off right with {}?', 1)
# (65, 'What would grandma find disturbing, yet oddly charming? {}', 1)
# (66, '{}. That was so metal.', 1)
# (67, 'I never truly understood {} until I encountered {}.', 2)
# (68, 'During sex, I like to think about {}.', 1)
# (69, 'Here is the church Here is the steeple Open the doors And there is {}.', 1)
# (70, 'But before I kill you, Mr. Bond, I must show you {}.', 1)
# (71, 'A recent laboratory study shows that undergraduates have 50% less sex after being exposed to {}.', 1)
# (72, 'Introducing the amazing superhero/sidekick duo! It’s {} and {}!', 2)
# (73, 'What ended my last relationship? {}', 1)
# (74, 'What’s that sound? {}', 1)
# (75, 'Uh, hey guys, I know this was my idea, but I’m having serious doubts about {}.', 1)
# (76, 'Why am I sticky? {}', 1)
# (77, 'Next on ESPN2: The World Series of {}.', 1)
# (78, 'When I am a billionaire, I shall erect a 50-foot statue to commemorate {}.', 1)
# (1, 'Flesh-eating bacteria')
# (2, 'Flying sex snakes')
# (3, 'Not giving a shit about the Third World')
# (4, 'Magnets')
# (5, 'Shapeshifters')
# (6, 'Seeing what happens when you lock people in a room with hungry seagulls')
# (7, 'A crucifixion')
# (8, 'Jennifer Lawrence')
# (9, '72 virgins')
# (10, 'A live studio audience')
# (11, 'A time travel paradox')
# (12, 'Authentic Mexican cuisine')
# (13, 'Doing crimes')
# (14, 'Synergistic management solutions')
# (15, 'Crippling debt')
# (16, 'Daddy issues')
# (17, 'Used panties')
# (18, 'A fart so powerful that it wakes the giants from their thousand-year slumber')
# (19, 'Former President George W. Bush')
# (20, 'Full frontal nudity')
# (21, 'Soft, kissy missionary sex')
# (22, 'BATMAN')
# (23, 'Agriculture')
# (24, 'Barely making $25,000 a year')
# (25, 'Covering myself with Parmesan cheese and chili flakes because I am pizza')
# (26, 'Having big dreams but no realistic way to achieve them')
# (27, 'Laying an egg')
# (28, 'Getting naked and watching Nickelodeon')
# (29, 'Pretending to care')
# (30, 'Natural selection')
# (31, 'Coat hanger abortions')
# (32, 'Sex with Patrick Stewart')
# (33, 'Seeing Grandma naked')
# (34, 'Boogers')
# (35, 'The inevitable heat death of the universe')
# (36, 'Prescription pain killers')
# (37, 'Swooping')
# (38, 'Mansplaining')
# (39, 'My abusive boyfriend who really isn’t so bad once you get to know him')
# (40, 'A homoerotic volleyball montage')
# (41, 'The miracle of childbirth')
# (42, 'The Rapture')
# (43, 'Whipping it out')
# (44, 'White privilege')
# (45, 'Alexandria Ocasio-Cortez')
# (46, 'Putting things where they go')
# (47, 'Fragile masculinity')
# (48, 'All-you-can-eat shrimp for $8.99')
# (49, 'Emerging from the sea and rampaging through Tokyo')
# (50, 'The Hamburglar')
# (51, 'AXE Body Spray')
# (52, 'The Blood of Christ')
# (53, 'An old guy who’s almost dead')
# (54, 'Kanye West')
# (55, 'Hot cheese')
# (56, 'Raptor attacks')
# (57, 'Seven dead and three in critical condition')
# (58, 'Smegma')
# (59, 'Alcoholism')
# (60, 'A middle-aged man on roller skates')
# (61, 'The past')
# (62, 'My genitals')
# (63, 'An endless stream of diarrhea')
# (64, 'Science')
# (65, 'Bingeing and purging')
# (66, 'An oversized lollipop')
# (67, 'Self-loathing')
# (68, 'Not reciprocating oral sex')
# (69, 'Flightless birds')
# (70, 'A good sniff')
# (71, 'Looking in the mirror, applying lipstick, and whispering “tonight, you will have sex with Tom Cruise.”')
# (72, 'Sitting on my face and telling me I’m garbage')
# (73, 'Half-assed foreplay')
# (74, 'The Holy Bible')
# (75, 'German dungeon porn')
# (76, 'A balanced breakfast')
# (77, 'Dead birds everywhere')
# (78, 'The arrival of the pizza')
# (79, '50,000 volts straight to the nipples')
# (80, 'Permanent Orgasm-Face Disorder')
# (81, 'Being on fire')
# (82, 'Teenage pregnancy')
# (83, 'Gandhi')
# (84, 'Your weird brother')
# (85, 'The cool, refreshing taste of Pepsi.®')
# (86, 'Chemical weapons')
# (87, 'Oprah')
# (88, 'Wondering if it’s possible to get some of that salsa to go')
# (89, 'A Fleshlight.®')
# (90, 'A pyramid of severed heads')
# (91, 'An erection that lasts longer than four hours')
# (92, 'A three-way with my wife and Shaquille O’Neal')
# (93, 'Bananas')
# (94, 'Passive aggressive Post-it notes')
# (95, 'Hillary Clinton’s emails')
# (96, 'Switching to Geico.®')
# (97, 'Peeing a little bit')
# (98, 'Wet dreams')
# (99, 'The Jews')
# (100, 'My cheating son-of-a-bitch husband')
# (101, 'Poverty')
# (102, 'Kamikaze pilots')
# (103, 'Committing suicide')
# (104, 'The homosexual agenda')
# (105, 'Powerful thighs')
# (106, 'These hoes')
# (107, 'The only gay person in a hundred miles')
# (108, 'Having sex for the first time')
# (109, 'A Mexican')
# (110, 'A falcon with a cap on its head')
# (111, 'Wizard music')
# (112, 'The Kool-Aid Man')
# (113, 'Donald J. Trump')
# (114, 'Kissing grandma on the forehead and turning off her life support')
# (115, 'Sexual tension')
# (116, 'An AR-15 assault rifle')
# (117, 'Juuling')
# (118, 'Free samples')
# (119, 'Hurting those closest to me')
# (120, 'Doing the right thing')
# (121, 'My good bra')
# (122, 'Punching a congressman in the face')
# (123, 'Fancy Feast.®')
# (124, 'Being rich')
# (125, 'The Three-Fifths Compromise')
# (126, 'Lactation')
# (127, 'World peace')
# (128, 'Shutting up so I can watch the game')
# (129, 'Sweet, sweet vengeance')
# (130, 'Republicans')
# (131, 'Sniffing and kissing my feet')
# (132, 'A much younger woman')
# (133, 'Eating a hard boiled egg out of my husband’s asshole')
# (134, 'RoboCop')
# (135, 'One titty hanging out')
# (136, 'Justin Bieber')
# (137, 'Oompa-Loompas')
# (138, 'Inappropriate yodeling')
# (139, 'Puberty')
# (140, 'Ghosts')
# (141, 'Expecting a burp and vomiting on the floor')
# (142, 'Adderall.®')
# (143, 'The Red Hot Chili Peppers')
# (144, 'Sideboob')
# (145, '50 mg of Zoloft daily')
# (146, 'Fucking my sister')
# (147, 'Braiding three penises into a Twizzler')
# (148, 'Vigorous jazz hands')
# (149, 'An octopus giving seven handjobs and smoking a cigarette')
# (150, 'My neck, my back, my pussy, and my crack')
# (151, 'J.D. Power and his associates')
# (152, 'Mouth herpes')
# (153, 'Getting fingered')
# (154, 'My Uber driver, Pavel')
# (155, 'GoGurt.®')
# (156, 'Police brutality')
# (157, 'Sperm whales')
# (158, 'Women of color')
# (159, 'Incest')
# (160, 'Men discussing their feelings in an emotionally healthy way')
# (161, 'Filling my briefcase with business stuff')
# (162, 'Preteens')
# (163, 'My fat daughter')
# (164, 'Rap music')
# (165, 'Pac-Man uncontrollably guzzling cum')
# (166, 'Casually suggesting a threesome')
# (167, 'Running out of semen')
# (168, 'God')
# (169, 'Fading away into nothingness')
# (170, 'Darth Vader')
# (171, 'A sad handjob')
# (172, 'Exactly what you’d expect')
# (173, 'The wonders of the Orient')
# (174, 'Sexual peeing')
# (175, 'Emotions')
# (176, 'Licking things to claim them as your own')
# (177, 'Jobs')
# (178, 'The placenta')
# (179, 'Spontaneous human combustion')
# (180, 'The Bachelorette season finale')
# (181, 'A tiny horse')
# (182, 'William Shatner')
# (183, 'Selling crack to children')
# (184, 'An M. Night Shyamalan plot twist')
# (185, 'Throwing grapes at a man until he loses touch with reality')
# (186, 'Establishing dominance')
# (187, 'Finger painting')
# (188, 'Old-people smell')
# (189, 'Brown people')
# (190, 'Mutually assured destruction')
# (191, 'Pedophiles')
# (192, 'Yeast')
# (193, 'Getting crushed by a vending machine')
# (194, 'My inner demons')
# (195, 'A Super Soaker™ full of cat pee')
# (196, 'Aaron Burr')
# (197, 'How bad my daughter fucked up her dance recital')
# (198, 'Rectangles')
# (199, 'Catapults')
# (200, 'Poor people')
# (201, 'Cuddling')
# (202, 'However much weed $20 can buy')
# (203, 'Battlefield amputations')
# (204, 'Spaghetti? Again')
# (205, 'Only dating Asian women')
# (206, 'The Hustle')
# (207, 'The Force')
# (208, 'How amazing it is to be on mushrooms')
# (209, 'Ronald Reagan')
# (210, 'A disappointing birthday party')
# (211, 'Nachos for the table')
# (212, 'Becoming a blueberry')
# (213, 'Judging everyone')
# (214, 'Kourtney, Kim, Khloe, Kendall, and Kylie')
# (215, 'Getting married, having a few kids, buying some stuff, retiring to Florida, and dying')
# (216, 'Some god damn peace and quiet')
# (217, 'AIDS')
# (218, 'Pictures of boobs')
# (219, 'Strong female characters')
# (220, 'Some foundation, mascara, and a touch of blush')
# (221, 'Getting cummed on')
# (222, 'Pixelated bukkake')
# (223, 'A lifetime of sadness')
# (224, 'Going an entire day without masturbating')
# (225, 'Hospice care')
# (226, 'Getting really high')
# (227, 'The opiod epidemic')
# (228, 'Penis envy')
# (229, 'Dick pics')
# (230, 'Racism')
# (231, 'Menstrual rage')
# (232, 'Sunshine and rainbows')
# (233, 'Gay conversion therapy')
# (234, 'Ruth Bader Ginsburg brutally gaveling your penis')
# (235, 'German Chancellor Angela Merkel')
# (236, 'The KKK')
# (237, 'Radical Islamic terrorism')
# (238, 'Huge biceps')
# (239, 'My little boner')
# (240, 'Dry heaving')
# (241, 'Meth')
# (242, 'Serfdom')
# (243, 'A pangender octopus who roams the cosmos in search of love')
# (244, 'Holding down a child and farting all over him')
# (245, 'A gossamer stream of jizz that catches the light as it arcs through the morning air')
# (246, 'Executing a hostage every hour')
# (247, 'The rhythms of Africa')
# (248, 'Breaking out into song and dance')
# (249, 'A Bop It.™')
# (250, 'A whole thing of butter')
# (251, 'Still being a virgin')
# (252, 'Solving problems with violence')
# (253, 'Leprosy')
# (254, 'Gloryholes')
# (255, 'Nipple blades')
# (256, 'The heart of a child')
# (257, 'Puppies')
# (258, 'Fellowship in Christ')
# (259, 'Little boy penises. Waking up half-naked in a Denny’s parking lot')
# (260, 'The Pope')
# (261, 'White people')
# (262, 'Tentacle porn')
# (263, 'My bright pink fuckhole')
# (264, 'An older woman who knows her way around the penis')
# (265, 'Getting drugs off the street and into my body')
# (266, 'Daniel Radcliffe’s delicious asshole')
# (267, 'Active listening')
# (268, 'How far I can get my own penis up my butt')
# (269, 'Having anuses for eyes')
# (270, 'The penny whistle solo from “My Heart Will Go On.”')
# (271, 'Seppuku')
# (272, 'Ethnic cleansing')
# (273, 'Itchy pussy')
# (274, 'Blowing my boyfriend so hard he shits')
# (275, 'A fuck-ton of almonds')
# (276, 'Danny DeVito')
# (277, 'The magic of live theatre')
# (278, 'Throwing a virgin into a volcano')
# (279, 'Dwayne “The Rock” Johnson')
# (280, 'A salad for men that’s made of metal')
# (281, 'Waiting till marriage')
# (282, 'Unfathomable stupidity')
# (283, 'Shiny objects')
# (284, 'Accepting the way things are')
# (285, 'NBA superstar LeBron James')
# (286, 'Therapy')
# (287, 'Listening to her problems without trying to solve them')
# (288, 'The Devil himself')
# (289, 'Autocannibalism')
# (290, 'Erectile dysfunction')
# (291, 'My collection of Japanese sex toys')
# (292, 'Being fat and stupid')
# (293, 'Pooping back and forth. Forever')
# (294, 'Tearing that ass up like wrapping paper on Christmas morning')
# (295, 'More elephant cock than I bargained for')
# (296, 'A salty surprise')
# (297, 'The South')
# (298, 'The violation of our most basic human rights')
# (299, 'Tap dancing like there’s no tomorrow')
# (300, 'A bowl of mayonnaise and human teeth')
# (301, 'Fiery poops')
# (302, 'Saying “I love you.”')
# (303, 'Inserting a Mason jar into my anus')
# (304, 'Consensual sex')
# (305, 'Telling a shitty story that goes nowhere')
# (306, 'A good, strong gorilla')
# (307, 'Seeing my father cry')
# (308, 'The true meaning of Christmas')
# (309, 'Some of the best rappers in the game')
# (310, 'Owning and operating a Chili’s franchise')
# (311, 'Estrogen')
# (312, 'Necrophilia')
# (313, 'Being a woman')
# (314, 'Getting into a pretty bad car accident')
# (315, 'Bill Nye the Science Guy')
# (316, 'Girls')
# (317, 'The Russians')
# (318, 'A bleached asshole')
# (319, 'Fucking the weatherman on live television')
# (320, 'Black people')
# (321, 'The Boy Scouts of America')
# (322, 'Lunchables.™')
# (323, 'Bitches')
# (324, 'PTSD')
# (325, 'Dark and mysterious forces beyond our control')
# (326, 'Smallpox blankets')
# (327, 'Masturbating')
# (328, 'Some punk kid who stole my turkey sandwich')
# (329, 'Heartwarming orphans')
# (330, 'Spirit Airlines')
# (331, 'Bubble butt bottom boys')
# (332, 'Hobos')
# (333, 'Queefing')
# (334, 'The guys from Queer Eye')
# (335, 'Cardi B')
# (336, 'Viagra.®')
# (337, 'Soup that is too hot')
# (338, 'Muhammad (Peace Be Upon Him')
# (339, 'Explaining how vaginas work')
# (340, 'Doin’ it in the butt')
# (341, 'My ex-wife')
# (342, 'Teaching a robot to love')
# (343, 'Touching a pug right on his penis')
# (344, 'Academy Award winner Meryl Streep')
# (345, 'Drinking alone')
# (346, 'Dick fingers')
# (347, 'Multiple stab wounds')
# (348, 'A windmill full of corpses')
# (349, 'Count Chocula')
# (350, 'Vladimir Putin')
# (351, 'The Patriarchy')
# (352, 'Poopy diapers')
# (353, 'Child abuse')
# (354, 'Anal beads')
# (355, 'Slaughtering innocent civilians')
# (356, 'The glass ceiling')
# (357, 'Vomiting seafood and bleeding anally')
# (358, 'The American Dream')
# (359, 'Not wearing pants')
# (360, 'Pulling out')
# (361, 'Being able to talk to elephants')
# (362, 'Horse meat')
# (363, 'A really cool hat')
# (364, 'My balls on your face')
# (365, 'Pooping in a laptop and closing it')
# (366, 'Dead babies')
# (367, 'Foreskin')
# (368, 'Stalin')
# (369, 'A stray pube')
# (370, 'Worshipping that pussy')
# (371, 'Completely unwarranted confidence')
# (372, 'A saxophone solo')
# (373, 'Italians')
# (374, 'A fetus')
# (375, 'Firing a rifle into the air while balls deep in a squealing hog')
# (376, 'Mike Pence')
# (377, '10,000 Syrian refugees')
# (378, 'Forced sterilization')
# (379, 'My relationship status')
# (380, 'Nicolas Cage')
# (381, 'Child beauty pageants')
# (382, 'Explosions')
# (383, 'Not vaccinating my children because I am stupid')
# (384, 'An unwanted pregnancy')
# (385, 'Diversity')
# (386, 'A white ethnostate')
# (387, 'Bees')
# (388, 'Lena Dunham')
# (389, 'Huffing spray paint')
# (390, 'A man on the brink of orgasm')
# (391, 'Repression')
# (392, 'Harry Potter erotica')
# (393, 'Giving birth to the Antichrist')
# (394, 'Three dicks at the same time')
# (395, 'Nazis')
# (396, 'Invading Poland')
# (397, 'My vagina')
# (398, 'Assless chaps')
# (399, 'Murder')
# (400, '8 oz. of sweet Mexican black-tar heroin')
# (401, 'What that mouth do')
# (402, 'Dead parents')
# (403, 'Object permanence')
# (404, 'Giving 110')
# (405, 'Her Majesty, Queen Elizabeth II')
# (406, 'The Trail of Tears')
# (407, 'Memes')
# (408, 'Opposable thumbs')
# (409, 'Racially-biased SAT questions')
# (410, 'The Great Depression')
# (411, 'Chainsaws for hands')
# (412, 'Sex with animals')
# (413, 'Being marginalized')
# (414, 'Goblins')
# (415, 'Hope')
# (416, 'Liberals')
# (417, 'A micropenis')
# (418, 'My soul')
# (419, 'A ball of earwax, semen, and toenail clippings')
# (420, 'Illegal immigrants')
# (421, 'Elderly Japanese men')
# (422, 'The female orgasm')
# (423, 'Heteronormativity')
# (424, 'A horde of Vikings')
# (425, 'Hot people')
# (426, 'Seething with quiet resentment')
# (427, 'An Oedipus complex')
# (428, 'Crumbs all over the god damn carpet')
# (429, 'Arnold Schwarzenegger')
# (430, 'The wifi password')
# (431, 'Spectacular abs')
# (432, 'Geese')
# (433, 'Extremely tight pants')
# (434, 'Fox News')
# (435, 'A little boy who won’t shut the fuck up about dinosaurs')
# (436, 'A bird that shits human turds')
# (437, 'A mopey zoo lion')
# (438, 'A bag of magic beans')
# (439, 'Poor life choices')
# (440, 'Making a pouty face')
# (441, 'Vehicular manslaughter')
# (442, 'Women’s suffrage')
# (443, 'Some guy')
# (444, 'My sex life')
# (445, 'Auschwitz')
# (446, 'A snapping turtle biting the tip of your penis')
# (447, 'All the dudes I’ve fucked')
# (448, 'Judge Judy')
# (449, 'African children')
# (450, 'This month’s mass shooting')
# (451, 'Barack Obama')
# (452, 'The clitoris')
# (453, 'The Big Bang')
# (454, 'Land mines')
# (455, 'The entire Mormon Tabernacle Choir')
# (456, 'A micropig wearing a tiny raincoat and booties')
# (457, 'Penis breath')
# (458, 'Jerking off into a pool of children’s tears')
# (459, 'Man meat')
# (460, 'Farting and walking away')
# (461, 'Being a dick to children')
# (462, 'One trillion dollars')
# (463, 'Drowning the kids in the bathtub')
# (464, 'Me time')
# (465, 'The Underground Railroad')
# (466, 'Poorly-timed Holocaust jokes')
# (467, 'A sea of troubles')
# (468, 'Dying')
# (469, 'Drinking out of the toilet and eating garbage')
# (470, 'The gays')
# (471, 'The screams... the terrible screams')
# (472, 'Lumberjack fantasies')
# (473, 'Morgan Freeman’s voice')
# (474, 'Women in yogurt commercials')
# (475, 'Natural male enhancement')
# (476, 'Men')
# (477, 'The bombing of Nagasaki')
# (478, 'Fake tits')
# (479, 'The Amish')
# (480, 'Being a motherfucking sorcerer')
# (481, 'My black ass')
# (482, 'Genuine human connection')
# (483, 'Announcing that I am about to cum')
# (484, 'David Bowie flying in on a tiger made of lightning')
# (485, 'My ugly face and bad personality')
# (486, 'A bitch slap')
# (487, 'A brain tumor')
# (488, 'Balls')
# (489, 'Grandma')
# (490, 'Friction')
# (491, 'Chunks of dead hitchhiker')
# (492, 'Fear itself')
# (493, 'Jews, gypsies, and homosexuals')
# (494, 'The milkman')

# %%
con.close() # closes the database and saves it

# %% [markdown]
# ### TO DO LIST:

# %% [markdown]
# 1. Check and see if the num of ans and quest cards are correct. if not check and see if all the cards are correct
#
# 2. Different table for the different type of games (family friendly or x rated)
