# %% [markdown]
# ### The cards were taken from https://s3.amazonaws.com/cah/CAH_MainGame.pdf in a PDF form
#
# ### The family friendly cards were taken from https://www.cardsagainsthumanityfamilyedition.com/pdf/CAH_Family_SmallCards.pdf in PDF form

# %% [markdown]
# ### Then the PDF was converted into a text file using a package from the site https://pypi.org/project/pdfminer/ that was installed in the anaconda promt

# %% [markdown]
# `python pdf2txt.py -o CAH_MainGame.txt CAH_MainGame.pdf`
#
# `python pdf2txt.py -o CAH_Family_SmallCards`

# %%
def ReadInFile(FileName):
    """
    This function reads in the file and saves each line of the file into a list and returns that list
    """
    with open(FileName, "r", encoding="utf-8") as file: # opens the csv file as file
        lines = file.readlines() # saves each line of the file into the list lines
    return lines

# %%
def ReturnCards(StartLine, EndLine, lines):
    """
    this function goes through the list and recognises each card and saves them in a list and returns that list
    """
    # Initilasing variables
    cards = []
    card = ""
    # for loop that goes through the cards and saves them in a list
    for lineNum in range(StartLine, EndLine):
        # each card is seperated by a line, so this if checks if the line is a part of the old card or the start of a new one
        if lines[lineNum] != "\n":
            # adds the line to the variable card and adds a space to make the card look neater
            card += lines[lineNum].strip()
            card += " "
        else:
            cards.append(card.strip()) # adds the finished card to the list
            card = "" # the card is wiped after appending for the start of another card
    return cards

# %%
def GapReplace(Card):
    """
    This function replaces the gap of a card and returns the edited card and the number of gaps it has
    """
    LocationOfGap = 0 # variable that will hold the location of the start of the gap
    EndOfGap = 0 # location of the end of the gap
    NumOfGaps = 0 # variable that will contain the number of gaps, if any, of the card
    count = 0
    
    while "_" in Card: # a while loop that will loop until there are no more gaps in the string
        LocationOfGap = Card.find("_") # finds the location of the first gap
        while (LocationOfGap + count) < len(Card) and Card[LocationOfGap + count] == "_": # while loop that counts how many _ there are
            count += 1
        EndOfGap = count + LocationOfGap # calculates the location of the end of the gap
        Card = Card[:LocationOfGap] + "{" + str(NumOfGaps) + "}" + Card[(EndOfGap):] # replaces the gaps with {x}
        count = 0
        NumOfGaps += 1 # adds to the number of gaps
        
    if NumOfGaps == 0: # an if statement to catch a card that has no gaps in itand adding a {} to the end
        Card += " {" + str(NumOfGaps) + "}" # adds {x} to the end of the card
        NumOfGaps = 1
        
    return Card, NumOfGaps

# %% [markdown]
# ### This is the part where the lines of the file are printed out and the functions are ran

# %%
CAHFileName = "CAH_MainGame.txt" # Run this if you want to play the X rated game

# %%
CAHFileName = "CAH_Family_SmallCards.txt" # Run this if you want to play the R rated game

# %%
# prints out the lines of the pdf in a format which has the line number first
lines = ReadInFile(CAHFileName) # reads in the file lines and puts them in a lsit
for i, line in enumerate(lines): # goes thorugh all the lines and makes i = line number and line = the line
    print(f"{i}: {line.strip()}") # prints put the line in the form "1: Line1"
# Out:
# 0: How to make your own
# 1: Cards Against Humanity:
# 2: Family Edition
# 3:
# 4: Download this PDF and print it at home. You can
# 5: use regular white paper, or heavy white cardstock
# 6: if you have any.
# 7:
# 8: The cards are black and white, so don’t worry if
# 9: you don’t have a color printer.
# 10:
# 11: Cut the cards along the lines using scissors or an
# 12: ancient katana. The more precisely you cut the
# 13: cards, the easier they’ll be to handle later. If you
# 14: use a katana, we recommend the traditional
# 15: jōge-suburi overhead strike.
# 16:
# 17: You're done!
# 18:
# 19: Cards Against Humanity:
# 20: Family Edition Rules
# 21:
# 22: Cards Against Humanity: Family Edition is a fill-in-the-blank party game. Each round,
# 23: one player asks the group a question from a black card, and then everyone answers it
# 24: with their funniest white card.
# 25:
# 26: To start the game, everyone should wash their hands with soap for 20 seconds and
# 27: then take ten white cards. The player who most recently pooped begins as the Card
# 28: Czar and draws a black card.
# 29:
# 30: The Card Czar reads the black card out loud. Everyone else then answers the
# 31: question (or fills in the blank) by passing one white card, face down, to the Card Czar.
# 32:
# 33: I don’t really
# 34: know what my
# 35: mom’s job is,
# 36: but I think it has
# 37: something to do
# 38: with ___________.
# 39:
# 40: The beautiful
# 41: potato.
# 42:
# 43: Unleashing a
# 44: hell demon that
# 45: will destroy our
# 46: world.
# 47:
# 48: Climbing into a
# 49: cow’s butt.
# 50:
# 51: Literally ruining
# 52: my life.
# 53:
# 54: The Card Czar then shuffles all the white cards and re-reads the black card out loud
# 55: with each one. Finally, the Card Czar picks the funniest combination, and whoever
# 56: played it gets one point.
# 57:
# 58: After the round, a new player becomes the Card Czar, and everyone draws a new
# 59: white card to replace the one they just played.
# 60:
# 61: When you’re done playing, tell your parents how much you loved Cards Against
# 62: Humanity: Family Edition — available this fall at participating Target locations for the
# 63: unbeatable price of $25!
# 64:
# 65: Papa, come
# 66: quickly! There,
# 67: in the garden!
# 68: Do you see _____?
# 69: Tell me you see it,
# 70: Papa!
# 71:
# 72: Attention students!
# 73: Principal Butthead is
# 74: at home recovering
# 75: from _____________.
# 76: We hope he’ll
# 77: be back soon.
# 78:
# 79: I’m sorry, Jordan,
# 80: but that’s not
# 81: an acceptable
# 82: Science Fair
# 83: project.
# 84: That’s just _______.
# 85:
# 86: The warm August
# 87: air was filled with
# 88: change. Things
# 89: were different,
# 90: for Kayla was now
# 91: ________________.
# 92:
# 93: This is gonna be
# 94: the best sleepover
# 95: ever. Once Mom
# 96: goes to bed, it’s
# 97: time for _________!
# 98:
# 99: Coming soon!
# 100: Batman vs.
# 101: ________________.
# 102:
# 103: Class, pay close
# 104: attention. I will
# 105: now demonstrate
# 106: the physics of
# 107: ________________.
# 108:
# 109: Hey Riley, I’ll give
# 110: you five bucks if
# 111: you try _________.
# 112:
# 113: Time to put on
# 114: my favorite t-shirt,
# 115: the one that says
# 116: “I heart ________.”
# 117:
# 118: My dad and I enjoy
# 119: _________________
# 120: together.
# 121:
# 122: Hey, kids.
# 123: I’m Sensei Todd.
# 124: Today, I’m gonna
# 125: teach you how to
# 126: defend yourself
# 127: against _________.
# 128:
# 129: MY NAME
# 130: CHUNGO.
# 131:
# 132: CHUNGO LOVE
# 133: ________________.
# 134:
# 135: Never fear,
# 136: Captain _________
# 137: is here!
# 138:
# 139: Kids, Dad is
# 140: trying something
# 141: new this week.
# 142: It’s called “_____.”
# 143:
# 144: Oh, no thank
# 145: you, Mrs. Lee.
# 146: I’ve had plenty of
# 147: _________________
# 148: for now.
# 149:
# 150: There’s nothing
# 151: better than a
# 152: peanut butter
# 153: and _____________
# 154: sandwich.
# 155:
# 156: And over here is
# 157: Picasso’s most
# 158: famous painting,
# 159: “Portrait of _____.”
# 160:
# 161: The aliens are here.
# 162: They want ______.
# 163:
# 164: They call me
# 165: “Mr. ___________.”
# 166:
# 167: CHUNGO
# 168: FEEL SICK.
# 169:
# 170: CHUNGO NO LIKE
# 171: _________________
# 172: ANYMORE.
# 173:
# 174: Mom!?
# 175: You have to come
# 176: pick me up!
# 177: There’s __________
# 178: at this party!
# 179:
# 180: CNN breaking
# 181: news! Over half
# 182: of Americans are
# 183: now ____________.
# 184:
# 185: On the next
# 186: episode of
# 187: Dora the Explorer,
# 188: Dora explores
# 189: ________________.
# 190:
# 191: Alright, which one
# 192: of you little turds
# 193: is responsible for
# 194: _______________?!
# 195:
# 196: Ladies and
# 197: gentlemen,
# 198: I have discovered
# 199: something amazing.
# 200: I have discovered
# 201: ________________.
# 202:
# 203: And in the blue
# 204: corner, weighing
# 205: in at 280 pounds,
# 206: it’s Tommy “_____”
# 207: Takahashi!
# 208:
# 209: Outback
# 210: Steakhouse:
# 211: No rules.
# 212: Just ____________.
# 213:
# 214: Ew. Grandpa
# 215: smells like ______.
# 216:
# 217: My name is Peter
# 218: Parker. I was bitten
# 219: by a radioactive
# 220: spider, and now
# 221: I’m _____________.
# 222:
# 223: Put on your
# 224: helmet, strap
# 225: on your goggles,
# 226: and get ready
# 227: for _____________!
# 228:
# 229: Attention students!
# 230: This is Principal
# 231: Butthead reminding
# 232: you that we do not
# 233: allow _____________
# 234: in the hallway.
# 235: Thank you.
# 236:
# 237: What’s about to
# 238: take this school
# 239: dance to the
# 240: next level?
# 241:
# 242: Little Miss Muffet
# 243: Sat on a tuffet
# 244: Eating her curds
# 245: and ____________.
# 246:
# 247: All I want for
# 248: Christmas is
# 249: ________________.
# 250:
# 251: Me and my friends
# 252: don’t play with
# 253: dolls anymore.
# 254: We’re into _______
# 255: now.
# 256:
# 257: We’re not
# 258: supposed to
# 259: go in the attic.
# 260: My parents keep
# 261: _________________
# 262: in there.
# 263:
# 264: Police!
# 265: Arrest this man!
# 266: He’s ____________.
# 267:
# 268: My favorite
# 269: dinosaur is
# 270: “_______asaurus.”
# 271:
# 272: When I pooped,
# 273: what came out
# 274: of my butt?
# 275:
# 276: I’m not like the
# 277: other children.
# 278: Toys bore me,
# 279: and I don’t care
# 280: for sweets.
# 281: I prefer _________.
# 282:
# 283: I’m sorry,
# 284: Mrs. Sanchez,
# 285: but I couldn’t finish
# 286: my homework
# 287: because of
# 288: ________________.
# 289:
# 290: Oh Dark Lord,
# 291: we show our
# 292: devotion with a
# 293: humble offering
# 294: of ______________!
# 295:
# 296: Thanks for
# 297: watching! If you
# 298: want to see more
# 299: vids of __________,
# 300: smash that
# 301: subscribe.
# 302:
# 303: We’re off to see
# 304: the wizard, the
# 305: wonderful wizard
# 306: of ______________!
# 307:
# 308: What’s all fun
# 309: and games
# 310: until somebody
# 311: gets hurt?
# 312:
# 313: Young lady,
# 314: we do not allow
# 315: _________________
# 316: at the dinner table.
# 317:
# 318: Welcome! We’re
# 319: glad you’re here.
# 320: Now sit back,
# 321: relax, and enjoy
# 322: ________________.
# 323:
# 324: My favorite book is
# 325: The Amazing
# 326: Adventures of
# 327: ________________.
# 328:
# 329: Well, look what
# 330: we have here!
# 331: A big fancy man
# 332: walkin’ in like he’s
# 333: ________________.
# 334:
# 335: ENOUGH!
# 336: I will not let
# 337: _________________
# 338: tear this family
# 339: apart!
# 340:
# 341: Rub a dub dub,
# 342: _________________
# 343: in a tub!
# 344:
# 345: Madam President,
# 346: we’ve run out of
# 347: time. The only
# 348: option is ________.
# 349:
# 350: I have invented a
# 351: new sport. I call it
# 352: “___________ ball.”
# 353:
# 354: Hey, check out my
# 355: band! We’re called
# 356: “Rage Against
# 357: _______________.”
# 358:
# 359: Moms love ______. Where do babies
# 360:
# 361: come from?
# 362:
# 363: CHUNGO ANGRY.
# 364:
# 365: CHUNGO
# 366: DESTROY _______.
# 367:
# 368: At school, I’m just
# 369: Mandy. But at
# 370: summer camp,
# 371: I’m “_____ Mandy.”
# 372:
# 373: James Bond
# 374: will return in
# 375: “No Time for
# 376: _______________.”
# 377:
# 378: It’s BIG.
# 379: It’s SCARY.
# 380: It’s _____________!
# 381:
# 382: Disney proudly
# 383: presents:
# 384: “_________ on Ice.”
# 385:
# 386: What really killed
# 387: the dinosaurs?
# 388:
# 389: Beep beep!
# 390: _________________
# 391: coming through!
# 392:
# 393: Now in bookstores:
# 394: Nancy Drew and
# 395: the Mystery of
# 396: ________________.
# 397:
# 398: You don’t love
# 399: me, Sam. All you
# 400: care about is
# 401: ________________.
# 402:
# 403: Did you know
# 404: that Benjamin
# 405: Franklin invented
# 406: ________________?
# 407:
# 408: One nation,
# 409: under God,
# 410: indivisible,
# 411: with liberty and
# 412: _________________
# 413: for all.
# 414:
# 415: The easiest way
# 416: to tell me and my
# 417: twin apart is that
# 418: I have a freckle
# 419: on my cheek and
# 420: she’s ___________.
# 421:
# 422: Hey guys. I just
# 423: want to tell all my
# 424: followers who are
# 425: struggling with
# 426: ________________:
# 427: it DOES get better.
# 428:
# 429: I lost my arm in a
# 430: ________ accident.
# 431:
# 432: Whoa there,
# 433: partner! Looks like
# 434: _________________
# 435: spooked my horse.
# 436:
# 437: Princess Marigold,
# 438: the kingdom
# 439: is in danger!
# 440: You must stop
# 441: ________________.
# 442:
# 443: Shut up, Becky!
# 444: At least I’m not
# 445: ________________.
# 446:
# 447: Isn’t this great,
# 448: honey? Just you,
# 449: me, the kids,
# 450: and ____________.
# 451:
# 452: Foolish child!
# 453: Did you think you
# 454: could escape from
# 455: ________________?
# 456:
# 457: Girls just wanna
# 458: have ___________.
# 459:
# 460: Run, run, as fast
# 461: as you can.
# 462: You can’t catch me,
# 463: I’m _____________!
# 464:
# 465: New from Mattel,
# 466: it’s _______ Barbie!
# 467:
# 468: No fair! How
# 469: come Chloe gets
# 470: her own phone,
# 471: and all I get is
# 472: ________________?
# 473:
# 474: Bow before me,
# 475: for I am the Queen
# 476: of ______________!
# 477:
# 478: New from Hasbro!
# 479: It’s BUNGO: The
# 480: Game of ________.
# 481:
# 482: What killed
# 483: Old Jim?
# 484:
# 485: I don’t really
# 486: know what my
# 487: mom’s job is, but
# 488: I think it has
# 489: something to do
# 490: with ____________.
# 491:
# 492: Next from
# 493: J.K. Rowling:
# 494: Harry Potter and
# 495: the Chamber of
# 496: ________________.
# 497:
# 498: Our day at the
# 499: water park was
# 500: totally ruined
# 501: by _____________.
# 502:
# 503: Charmander has
# 504: evolved into
# 505: ________________!
# 506:
# 507: What’s keeping
# 508: Dad so busy
# 509: in the garage?
# 510:
# 511: Boys? No.
# 512: ____________? Yes!
# 513:
# 514: ME HUNGRY.
# 515: ME WANT ______.
# 516:
# 517: Oh, that’s my
# 518: mom’s friend Carl.
# 519: He comes over
# 520: and helps her
# 521: with ____________.
# 522:
# 523: Guys, stop it!
# 524: There’s nothing
# 525: funny about
# 526: ________________.
# 527:
# 528: Huddle up, Wildcats!
# 529: They may be bigger.
# 530: They may be faster.
# 531: But we’ve got a
# 532: secret weapon:
# 533: ________________.
# 534:
# 535: Coming to theaters
# 536: this holiday season,
# 537: “Star Wars: The
# 538: Rise of _________.”
# 539:
# 540: I do not fight
# 541: for wealth.
# 542: I do not fight
# 543: for glory.
# 544: I fight for _______!
# 545:
# 546: Come on, Danny.
# 547: All the cool kids
# 548: are doin’ it. Wanna
# 549: try _____________?
# 550:
# 551: A big wet kiss from
# 552: Great Aunt Sharon.
# 553:
# 554: A cloud that
# 555: rains diarrhea.
# 556:
# 557: A pirate with
# 558: two peg arms,
# 559: two peg legs,
# 560: and a peg head.
# 561:
# 562: Athena,
# 563: Goddess of
# 564: Wisdom.
# 565:
# 566: Baby boomers.
# 567:
# 568: Beautiful Grandma.
# 569:
# 570: Defecating on the
# 571: neighbor’s lawn.
# 572:
# 573: Eight hours of
# 574: video games.
# 575:
# 576: Going night-night.
# 577:
# 578: Hanging out
# 579: with Zendaya.
# 580:
# 581: Kissing Mom
# 582: on the lips.
# 583:
# 584: Me, your dad.
# 585:
# 586: Playing trumpet
# 587: for the Mayor.
# 588:
# 589: Ratzilla.
# 590:
# 591: Teeny tiny turds.
# 592:
# 593: That there
# 594: tarantula.
# 595:
# 596: The way Grandpa
# 597: smells.
# 598:
# 599: Three glasses
# 600: of red wine.
# 601:
# 602: Whatever Dad
# 603: does at work.
# 604:
# 605: Getting shot out
# 606: of a cannon.
# 607:
# 608: Jesus.
# 609:
# 610: Eating pasta out
# 611: of my pants.
# 612:
# 613: A burrito smoothie.
# 614:
# 615: A bear.
# 616:
# 617: Old people.
# 618:
# 619: My sister’s
# 620: stupid boyfriend.
# 621:
# 622: Stuffing my
# 623: underwear
# 624: with pancakes.
# 625:
# 626: Stinky Martha,
# 627: the superhero that
# 628: nobody likes.
# 629:
# 630: My chainsaw.
# 631:
# 632: Diarrhea.
# 633:
# 634: Boogers.
# 635:
# 636: The police.
# 637:
# 638: Sniffing a dog’s
# 639: butt.
# 640:
# 641: Horrible allergies.
# 642:
# 643: Your face.
# 644:
# 645: A gerbil named
# 646: “Gerbil.”
# 647:
# 648: Fartus Magnimus,
# 649: God of Beans.
# 650:
# 651: Rated-R stuff.
# 652:
# 653: Blowing up
# 654: the Moon.
# 655:
# 656: Getting launched
# 657: into space.
# 658:
# 659: Likes.
# 660:
# 661: A bird pooping
# 662: on the president’s
# 663: head.
# 664:
# 665: Chungo, the
# 666: talking gorilla.
# 667:
# 668: The way I feel
# 669: when I see Kyle.
# 670:
# 671: Hot gossip.
# 672:
# 673: Forgetting to put
# 674: on underwear.
# 675:
# 676: Running full speed
# 677: into a wall.
# 678:
# 679: The Russians.
# 680:
# 681: A black hole.
# 682:
# 683: Putting my butt
# 684: on stuff.
# 685:
# 686: Racism, sexism,
# 687: and homophobia.
# 688:
# 689: Making the
# 690: bees angry.
# 691:
# 692: My strong,
# 693: terrifying daughter.
# 694:
# 695: A Democrat.
# 696:
# 697: TikTok.
# 698:
# 699: Cheeto fingers.
# 700:
# 701: A huge honkin’
# 702: carrot.
# 703:
# 704: The country
# 705: of Bolivia.
# 706:
# 707: My parents.
# 708:
# 709: Idiots.
# 710:
# 711: Filling my butt
# 712: with spaghetti.
# 713:
# 714: Putting an apple in
# 715: a little boy’s mouth
# 716: and roasting him
# 717: for dinner.
# 718:
# 719: Thousands
# 720: of lasagna.
# 721:
# 722: Climbing into a
# 723: cow’s butt.
# 724:
# 725: War with Canada.
# 726:
# 727: Mashing a
# 728: banana into your
# 729: belly button.
# 730:
# 731: China.
# 732:
# 733: Shrek.
# 734:
# 735: Cavities.
# 736:
# 737: Eating people.
# 738:
# 739: Butts of all shapes
# 740: and sizes.
# 741:
# 742: A 40-piece
# 743: Chicken
# 744: McNuggets.
# 745:
# 746: Climate change.
# 747:
# 748: Barf.
# 749:
# 750: A poop as big
# 751: as Mom.
# 752:
# 753: A couch that
# 754: eats children.
# 755:
# 756: Going to Hell.
# 757:
# 758: The loose skin
# 759: at the joint of the
# 760: elbow known as
# 761: “the weenus.”
# 762:
# 763: A horse with
# 764: no legs.
# 765:
# 766: Fat stacks of cash.
# 767:
# 768: Dora the Explorer.
# 769:
# 770: Illegal drugs.
# 771:
# 772: BULBASAUR.
# 773:
# 774: Dad’s meatloaf.
# 775:
# 776: Extra-warm Pepsi.
# 777:
# 778: Calling 9-1-1.
# 779:
# 780: The old man
# 781: with the rake
# 782: who lives down
# 783: the dark and
# 784: winding road.
# 785:
# 786: Toe jam.
# 787:
# 788: Hot lava.
# 789:
# 790: Butt surgery.
# 791:
# 792: Spending
# 793: my parents’
# 794: hard-earned
# 795: money.
# 796:
# 797: Freeing all
# 798: the animals
# 799: from the zoo.
# 800:
# 801: A bountiful harvest
# 802: of squashes and
# 803: corns.
# 804:
# 805: Bombs.
# 806:
# 807: Boobies.
# 808:
# 809: Respecting
# 810: personal
# 811: boundaries.
# 812:
# 813: Having no idea
# 814: what’s going on.
# 815:
# 816: John Wilkes Booth.
# 817:
# 818: Getting married.
# 819:
# 820: Politics.
# 821:
# 822: Garbage.
# 823:
# 824: Naked people.
# 825:
# 826: This stupid game.
# 827:
# 828: Biting a rich person.
# 829:
# 830: Screaming at birds.
# 831:
# 832: Getting stuck
# 833: in the toilet.
# 834:
# 835: Getting crushed
# 836: by a piano.
# 837:
# 838: Huge pants.
# 839:
# 840: Mom’s spaghetti.
# 841:
# 842: An old, dirty cat
# 843: with bad breath.
# 844:
# 845: A corn dog.
# 846:
# 847: My followers.
# 848:
# 849: Principal Butthead.
# 850:
# 851: A statue of
# 852: a naked guy.
# 853:
# 854: A tiny detective
# 855: who solves
# 856: tiny crimes.
# 857:
# 858: Joining the army.
# 859:
# 860: Witchcraft.
# 861:
# 862: Taking out
# 863: my eyeballs.
# 864:
# 865: Sacrificing
# 866: Uncle Tim.
# 867:
# 868: Moving to Ohio.
# 869:
# 870: A hundred
# 871: screaming
# 872: monkeys.
# 873:
# 874: A wise old woman
# 875: with no teeth
# 876: and cloudy eyes.
# 877:
# 878: Emotions.
# 879:
# 880: Ham.
# 881:
# 882: Clams.
# 883:
# 884: Spider-Man.
# 885:
# 886: Drinking out of
# 887: the toilet and
# 888: eating garbage.
# 889:
# 890: Trying to catch
# 891: that dang raccoon.
# 892:
# 893: Slapping my
# 894: huge belly.
# 895:
# 896: The doll that
# 897: watches me sleep.
# 898:
# 899: Money.
# 900:
# 901: LeBron James.
# 902:
# 903: Father’s forbidden
# 904: chocolates.
# 905:
# 906: Me.
# 907:
# 908: Salmon.
# 909:
# 910: Screaming the
# 911: F-word.
# 912:
# 913: A whole thing of
# 914: cottage cheese.
# 915:
# 916: Crab-walking
# 917: from the toilet
# 918: to get more
# 919: toilet paper.
# 920:
# 921: Mayonnaise.
# 922:
# 923: Total world
# 924: domination.
# 925:
# 926: Failure.
# 927:
# 928: JoJo Siwa.
# 929:
# 930: Getting kicked
# 931: in the nuts.
# 932:
# 933: Farting and
# 934: walking away.
# 935:
# 936: Sharks with legs.
# 937:
# 938: Triangles.
# 939:
# 940: Ninjas.
# 941:
# 942: The floor.
# 943:
# 944: The whole family.
# 945:
# 946: Bench pressing
# 947: a horse.
# 948:
# 949: Spiders.
# 950:
# 951: Uranus.
# 952:
# 953: A Republican.
# 954:
# 955: Giving wedgies
# 956: to my haters.
# 957:
# 958: 14 cheeseburgers,
# 959: 6 large fries, and
# 960: a medium Sprite.
# 961:
# 962: Big Randy.
# 963:
# 964: Blasting my
# 965: math teacher
# 966: into the sun.
# 967:
# 968: Dreaming
# 969: about boys.
# 970:
# 971: Taking a dump
# 972: in the pool.
# 973:
# 974: Crying in the
# 975: bathroom.
# 976:
# 977: Happiness.
# 978:
# 979: Poison.
# 980:
# 981: My sister’s hair
# 982: all over the place.
# 983:
# 984: A scoop of tuna.
# 985:
# 986: Doing karate.
# 987:
# 988: Hades,
# 989: God of the
# 990: Underworld.
# 991:
# 992: Lil Nas X.
# 993:
# 994: Dad’s famous
# 995: poops.
# 996:
# 997: Squirty cheese.
# 998:
# 999: My girlfriend,
# 1000: who goes to
# 1001: another school.
# 1002:
# 1003: Mowing the
# 1004: stupid lawn.
# 1005:
# 1006: Slapping that butt.
# 1007:
# 1008: Questioning
# 1009: authority.
# 1010:
# 1011: Chugging a
# 1012: gallon of milk and
# 1013: then vomiting a
# 1014: gallon of milk.
# 1015:
# 1016: Farting a lot today.
# 1017:
# 1018: Going bald.
# 1019:
# 1020: Germs.
# 1021:
# 1022: Nuclear war.
# 1023:
# 1024: Barfing into a
# 1025: popcorn bucket.
# 1026:
# 1027: A cursed llama
# 1028: with no eyes.
# 1029:
# 1030: The wettest fart
# 1031: you ever heard.
# 1032:
# 1033: Shaving
# 1034: Dad’s back.
# 1035:
# 1036: Overthrowing the
# 1037: government.
# 1038:
# 1039: Murdering.
# 1040:
# 1041: Exploding.
# 1042:
# 1043: Bleeding.
# 1044:
# 1045: The oppressive
# 1046: system of
# 1047: capitalism.
# 1048:
# 1049: Supreme
# 1050: Court Justice
# 1051: Ruth Bader
# 1052: Ginsburg.
# 1053:
# 1054: A long, hot pee.
# 1055:
# 1056: Throwing up
# 1057: double peace signs
# 1058: with my besties
# 1059: at Starbucks.
# 1060:
# 1061: A balloon filled
# 1062: with chili.
# 1063:
# 1064: The dishes.
# 1065:
# 1066: The freedom
# 1067: of speech.
# 1068:
# 1069: Egg salad.
# 1070:
# 1071: Mom’s friend,
# 1072: Donna.
# 1073:
# 1074: Rich people.
# 1075:
# 1076: Pirate music.
# 1077:
# 1078: Being a dinosaur.
# 1079:
# 1080: A fake kid made
# 1081: out of wood.
# 1082:
# 1083: Homework.
# 1084:
# 1085: Batman.
# 1086:
# 1087: A dead body.
# 1088:
# 1089: Drinking a whole
# 1090: bottle of ranch.
# 1091:
# 1092: Destroying
# 1093: the planet.
# 1094:
# 1095: Living in a
# 1096: pineapple
# 1097: under the sea.
# 1098:
# 1099: Pizza.
# 1100:
# 1101: This pumpkin.
# 1102:
# 1103: Extremely tight
# 1104: underpants.
# 1105:
# 1106: A nice, warm glass
# 1107: of pee.
# 1108:
# 1109: Poseidon,
# 1110: Lord of the Sea.
# 1111:
# 1112: Complaining.
# 1113:
# 1114: Bursting into
# 1115: flames.
# 1116:
# 1117: Spawning sheep.
# 1118:
# 1119: My whole
# 1120: body getting
# 1121: big and strong
# 1122: and beautiful.
# 1123:
# 1124: Big, juicy pimples.
# 1125:
# 1126: The humble
# 1127: earthworm.
# 1128:
# 1129: The garbage man.
# 1130:
# 1131: A big, and I mean
# 1132: BIG turtle.
# 1133:
# 1134: Your mom!
# 1135:
# 1136: The octopus
# 1137: stuck to my face.
# 1138:
# 1139: Dying of old age.
# 1140:
# 1141: Smashing the
# 1142: patriarchy.
# 1143:
# 1144: Screaming into a
# 1145: can of Pringles.
# 1146:
# 1147: Grandpa.
# 1148:
# 1149: Shutting up.
# 1150:
# 1151: Silence.
# 1152:
# 1153: My annoying
# 1154: brother.
# 1155:
# 1156: My future husband.
# 1157:
# 1158: A hot air balloon
# 1159: powered by
# 1160: fart gas.
# 1161:
# 1162: Sitting on the toilet
# 1163: and going poop.
# 1164:
# 1165: A screaming
# 1166: soccer dad.
# 1167:
# 1168: Cocktail weenies.
# 1169:
# 1170: The British.
# 1171:
# 1172: Voldemort.
# 1173:
# 1174: Science.
# 1175:
# 1176: Picking my nose
# 1177: and eating it.
# 1178:
# 1179: Having a
# 1180: really big head.
# 1181:
# 1182: A dead whale.
# 1183:
# 1184: Fortnite.
# 1185:
# 1186: The power of
# 1187: the Dark Side.
# 1188:
# 1189: Big butt cheeks
# 1190: filled with poop.
# 1191:
# 1192: My friend Steve.
# 1193:
# 1194: Violence.
# 1195:
# 1196: Magic:
# 1197: The Gathering.
# 1198:
# 1199: Eating toenail
# 1200: clippings.
# 1201:
# 1202: Using balloons
# 1203: as boobies.
# 1204:
# 1205: My dang kids.
# 1206:
# 1207: Squeezing a lemon
# 1208: into my eye.
# 1209:
# 1210: Tombus, the
# 1211: talking rhombus.
# 1212:
# 1213: Greta Thunberg.
# 1214:
# 1215: Ellen.
# 1216:
# 1217: Uncle Bob.
# 1218:
# 1219: Outback
# 1220: Steakhouse.
# 1221:
# 1222: Dwayne
# 1223: “The Rock”
# 1224: Johnson.
# 1225:
# 1226: A baby with
# 1227: a full mustache.
# 1228:
# 1229: Getting hit
# 1230: in the face with
# 1231: a soccer ball.
# 1232:
# 1233: Eating a whole roll
# 1234: of toilet paper.
# 1235:
# 1236: The bacon.
# 1237:
# 1238: The first female
# 1239: president of the
# 1240: United States.
# 1241:
# 1242: Falling off
# 1243: a mountain.
# 1244:
# 1245: Person milk.
# 1246:
# 1247: Pink eye.
# 1248:
# 1249: Pork.
# 1250:
# 1251: The government.
# 1252:
# 1253: Nunchucks.
# 1254:
# 1255: Nothing.
# 1256:
# 1257: GOOOAAALLLL!!!
# 1258:
# 1259: Mom’s new haircut.
# 1260:
# 1261: Happy daddies with
# 1262: happy sandals.
# 1263:
# 1264: Giggling and
# 1265: farting and
# 1266: slurping
# 1267: milkshakes.
# 1268:
# 1269: Ice pee.
# 1270:
# 1271: Obama.
# 1272:
# 1273: Twerking.
# 1274:
# 1275: Reading my sister’s
# 1276: diary.
# 1277:
# 1278: The ice cream man.
# 1279:
# 1280: Love.
# 1281:
# 1282: Stank breath.
# 1283:
# 1284: Living in the
# 1285: dumpster.
# 1286:
# 1287: Having a baby.
# 1288:
# 1289: Shoplifting.
# 1290:
# 1291: My father,
# 1292: who is a walrus.
# 1293:
# 1294: The dentist.
# 1295:
# 1296: Aunt Linda.
# 1297:
# 1298: One tough mama.
# 1299:
# 1300: Releasing
# 1301: the falcons!
# 1302:
# 1303: Literally ruining
# 1304: my life.
# 1305:
# 1306: Flushing myself
# 1307: down the toilet.
# 1308:
# 1309: Fire farts.
# 1310:
# 1311: Lice.
# 1312:
# 1313: A killer clown.
# 1314:
# 1315: Blossoming into
# 1316: a beautiful
# 1317: young man.
# 1318:
# 1319: Wiping my butt.
# 1320:
# 1321: Saying mean stuff
# 1322: and making people
# 1323: feel bad.
# 1324:
# 1325: Beyoncé.
# 1326:
# 1327: A truck.
# 1328:
# 1329: Only beans.
# 1330:
# 1331: The beautiful
# 1332: potato.
# 1333:
# 1334: Legs.
# 1335:
# 1336: The woman I’m
# 1337: going to marry
# 1338: one day.
# 1339:
# 1340: Unleashing a
# 1341: hell demon that will
# 1342: destroy our world.
# 1343:
# 1344: Feminism.
# 1345:
# 1346: Lighting stuff
# 1347: on fire.
# 1348:
# 1349: Turning 40.
# 1350:
# 1351: Getting a
# 1352: skull tattoo.
# 1353:
# 1354: An invisible giant
# 1355: who takes giant,
# 1356: visible poops.
# 1357:
# 1358: A cowboy who is
# 1359: half boy, half cow.
# 1360:
# 1361: The longest tongue
# 1362: in the world.
# 1363:
# 1364: Josh.
# 1365:
# 1366: Locking Mother
# 1367: in the pantry.
# 1368:
# 1369: Ariana Grande.
# 1370:
# 1371: Puberty.
# 1372:
# 1373: A glorious beard.
# 1374:
# 1375: All of my teeth
# 1376: falling out.
# 1377:
# 1378: Floating through
# 1379: the void of space
# 1380: and time.
# 1381:
# 1382: Farting, barfing,
# 1383: and passing out.
# 1384:
# 1385: Flamin’ Hot
# 1386: Cheetos.
# 1387:
# 1388: Snakes.
# 1389:
# 1390: Free ice cream, yo.
# 1391:
# 1392: Screaming and
# 1393: screaming and
# 1394: never waking up.
# 1395:
# 1396: Running away
# 1397: from home.
# 1398:
# 1399: Using my butt
# 1400: as a microwave.
# 1401:
# 1402: Glen’s fabulous
# 1403: body.
# 1404:
# 1405: Gluten.
# 1406:
# 1407: Wakanda.
# 1408:
# 1409: Many wolves.
# 1410:
# 1411: One long hair
# 1412: growing out of
# 1413: a mole.
# 1414:
# 1415: A butt that eats
# 1416: underwear.
# 1417:
# 1418: Poo-poo.
# 1419:
# 1420: Mooing.
# 1421:
# 1422: Robbing a bank.
# 1423:
# 1424: Punching
# 1425: everyone.
# 1426:
# 1427: How much wood
# 1428: a woodchuck
# 1429: would chuck
# 1430: if a woodchuck
# 1431: could chuck wood.
# 1432:
# 1433: Swords.
# 1434:
# 1435: Kevin’s mom.
# 1436:
# 1437: Getting scalded
# 1438: in the face with
# 1439: hot beans.
# 1440:
# 1441: Chest hair.
# 1442:
# 1443: My annoying sister.
# 1444:
# 1445: Getting slapped
# 1446: with a fish.
# 1447:
# 1448: Harry Potter.
# 1449:
# 1450: Peeing sand.
# 1451:
# 1452: Being French,
# 1453: hoh-hoh-hoh!
# 1454:
# 1455: Guacamole.
# 1456:
# 1457: Getting naked.
# 1458:
# 1459: A super angry cat
# 1460: I found outside.
# 1461:
# 1462: Slappy Spatchy,
# 1463: the game where
# 1464: you slap each other
# 1465: with spatulas.
# 1466: Learn more at
# 1467: www.SlappySpatchy.com.
# 1468:
# 1469: A pregnant person.
# 1470:
# 1471: A bunch of
# 1472: dead squirrels
# 1473: on a trampoline.
# 1474:
# 1475: Grandma panties.
# 1476:
# 1477: Thick, nasty burps.
# 1478:
# 1479: Having no bones.
# 1480:
# 1481: Famous peanut
# 1482: scientist George
# 1483: Washington
# 1484: Carver.
# 1485:
# 1486: Saving up my
# 1487: boogers for
# 1488: ten years and then
# 1489: building the world’s
# 1490: largest booger.
# 1491:
# 1492: The president.
# 1493:
# 1494: A hug.
# 1495:
# 1496: The Dark Lord.
# 1497:
# 1498: Being super serious
# 1499: right now.
# 1500:
# 1501: Freeing a fart from
# 1502: its butt prison.
# 1503:
# 1504: An order of
# 1505: mozzarella sticks.
# 1506:
# 1507: Fake news.
# 1508:
# 1509: The baby.
# 1510:
# 1511: Like a million
# 1512: alligators.
# 1513:
# 1514: Big, slappy hands.
# 1515:
# 1516: Beer.
# 1517:
# 1518: Spit.
# 1519:
# 1520: The fifth graders.
# 1521:
# 1522: Licking a goat.
# 1523:
# 1524: A flamethrower.
# 1525:
# 1526: Drama!
# 1527:
# 1528: Old Jim’s
# 1529: Steamy Butt Sauce.
# 1530:
# 1531: Going to the
# 1532: emergency room.
# 1533:
# 1534: Sitting atop a pile
# 1535: of tuna, like some
# 1536: kind of tuna queen.
# 1537:
# 1538: Girls.
# 1539:
# 1540: A Pringle.
# 1541:
# 1542: Never showering.
# 1543:
# 1544: Naptime.
# 1545:
# 1546: The gym teacher.
# 1547:
# 1548: Coming back
# 1549: from the dead.
# 1550:
# 1551: Burning books.
# 1552:
# 1553: Falling in love.
# 1554:
# 1555: Tossed salads and
# 1556: scrambled eggs.
# 1557:
# 1558: Building a ladder
# 1559: of hot dogs
# 1560: to the moon.
# 1561:
# 1562: Practicing kissing.
# 1563:
# 1564: Eating a lightning
# 1565: bug to gain its
# 1566: lightning powers.
# 1567:
# 1568: Slowly turning
# 1569: into cheese.
# 1570:
# 1571: Ear wax.
# 1572:
# 1573: Knives.
# 1574:
# 1575: Stuff.
# 1576:
# 1577: Whispering
# 1578: secrets to my
# 1579: best friend,
# 1580: Turkey.
# 1581:
# 1582: Taking a selfie.
# 1583:
# 1584: Dancing with
# 1585: my son.
# 1586:
# 1587: Punching a guy
# 1588: through a wall.
# 1589:
# 1590: Nipples.
# 1591:
# 1592: Cat pee.
# 1593:
# 1594: Dump cake.
# 1595:
# 1596: Billie Eilish.
# 1597:
# 1598: Steven Universe.
# 1599:
# 1600: Elegant party hats.
# 1601:
# 1602: Santa Claus.
# 1603:
# 1604: The gluteus
# 1605: maximus.
# 1606:
# 1607: Baby Yoda.
# 1608:
# 1609: Peeing in the cat’s
# 1610: litter box.
# 1611:
# 1612: A big sad dragon
# 1613: with no friends.
# 1614:
# 1615: A big whiny
# 1616: cry-baby.
# 1617:
# 1618: Seymour Butts.
# 1619:
# 1620: The bus driver.
# 1621:
# 1622: Getting run over
# 1623: by a train.
# 1624:
# 1625: Spinning and
# 1626: barfing.
# 1627:
# 1628: Some freakin’
# 1629: privacy.
# 1630:
# 1631: Butt hair.
# 1632:
# 1633: Having many
# 1634: husbands.
# 1635:
# 1636: Making the
# 1637: bathroom smell.
# 1638:
# 1639: Coffee.
# 1640:
# 1641: Anime.
# 1642:
# 1643: The sweet honking
# 1644: of Karen’s bassoon.
# 1645:
# 1646: Pooping in a bag
# 1647: and lighting it
# 1648: on fire.
# 1649:
# 1650: Space lasers.
# 1651:
# 1652: Being dead.
# 1653:
# 1654: Pooping barf
# 1655: forever.
# 1656:
# 1657: FOOOOD
# 1658: FIIIIIIIIIIIIIIIIIGHT!!!
# 1659:
# 1660: Wearing
# 1661: high heels.
# 1662:
# 1663: A long, long snake.
# 1664:
# 1665: Getting trampled
# 1666: by horses.
# 1667:
# 1668: The babysitter.
# 1669:
# 1670: The lunch lady.
# 1671:
# 1672: Peeing on my
# 1673: poopy.
# 1674:
# 1675: Not wearing pants. Meatballs,
# 1676: meatballs,
# 1677: meatballs!
# 1678:
# 1679: Finding Waldo.
# 1680:
# 1681: Going around
# 1682: sniffing people’s
# 1683: armpits.
# 1684:
# 1685: The divorce.
# 1686:
# 1687: Diaper beans.
# 1688:
# 1689: Cigarettes.
# 1690:
# 1691: Getting my
# 1692: ponytail stuck
# 1693: in my butt.
# 1694:
# 1695: Looking into
# 1696: people’s windows.
# 1697:
# 1698: Sucking at life.
# 1699:
# 1700: Crossbows.
# 1701:
# 1702: Evil.
# 1703:
# 1704: A big rock.
# 1705:
# 1706: Rubbing lotion on
# 1707: a hairless cat.
# 1708:
# 1709: Goblins.
# 1710:
# 1711: Nasty
# 1712: Cousin Amber.
# 1713:
# 1714: Tongue kissing.
# 1715:
# 1716: Abraham Lincoln.
# 1717:
# 1718: Covering myself
# 1719: with ketchup
# 1720: and mustard
# 1721: because I am
# 1722: hot dog.
# 1723:
# 1724: Hot, fresh doodies.
# 1725:
# 1726: Feet.
# 1727:
# 1728: Sadness.
# 1729:
# 1730: Going beast mode.
# 1731:
# 1732: An owl that
# 1733: hates you.
# 1734:
# 1735: A doll that pees
# 1736: real pee!
# 1737:
# 1738: A naked lady
# 1739: in a painting.
# 1740:
# 1741: Chunks.
# 1742:
# 1743: Some weird guy.
# 1744:
# 1745: Getting a girlfriend.
# 1746:
# 1747: Falling in love with
# 1748: a hot dog.
# 1749:
# 1750: Throwing stuff at
# 1751: other stuff.
# 1752:
# 1753: Hogs.
# 1754:
# 1755: A turd that
# 1756: just won’t flush.
# 1757:
# 1758: The entire state
# 1759: of Texas.
# 1760:
# 1761: Showing everyone
# 1762: my butt.
# 1763:
# 1764: My big donkey
# 1765: brother.
# 1766:
# 1767: The huge,
# 1768: stupid moon.
# 1769:
# 1770: Math.
# 1771:
# 1772: Pee-pee.
# 1773:
# 1774: Dinner.
# 1775:
# 1776: Butthole.
# 1777:
# 1778: Smelling like
# 1779: onions.
# 1780:
# 1781: Being fake.
# 1782:
# 1783: Peer pressure.
# 1784:
# 1785: Peeing in my
# 1786: backpack.
# 1787:
# 1788: Bad parenting.
# 1789:
# 1790: Mom’s butt.
# 1791:
# 1792: One weird lookin’
# 1793: toe.
# 1794:
# 1795: You.
# 1796:
# 1797: Boys.
# 1798:
# 1799: Sitting on a cake.
# 1800:
# 1801: Teaching a chicken
# 1802: to kill.
# 1803:
# 1804: The middle finger.
# 1805:
# 1806: A bra.
# 1807:
# 1808: Being famous
# 1809: on YouTube.
# 1810:
# 1811: Cream.
# 1812:
# 1813: Balls.
# 1814:
# 1815: Having no friends.
# 1816:
# 1817: Peeing into
# 1818: everyone’s mouth.
# 1819:
# 1820: Gluing my butt
# 1821: cheeks together.
# 1822:
# 1823: How school slowly
# 1824: breaks your spirit
# 1825: and drains your
# 1826: will to live.
# 1827:
# 1828: A Pokémon named
# 1829: “Jim.”
# 1830:
# 1831: True love’s kiss.
# 1832:
# 1833: Total crap.
# 1834:
# 1835: Cool sunglasses.
# 1836:
# 1837: Literally dying from
# 1838: the smell of a fart.
# 1839:
# 1840: Snot bubbles.
# 1841:
# 1842: Doing crimes and
# 1843: going to jail.
# 1844:
# 1845: This goat,
# 1846: who is my friend.
# 1847:
# 1848: Aliens.
# 1849:
# 1850: School.
# 1851:
# 1852: A cow.
# 1853:
# 1854: The terrible winter
# 1855: of 1609.
# 1856:
# 1857: Getting sucked
# 1858: into a jet engine.
# 1859:
# 1860: Not breathing.
# 1861:
# 1862: Licking a used
# 1863: band-aid.
# 1864:
# 1865: Braiding my
# 1866: armpit hair.
# 1867:
# 1868: Waking up inside
# 1869: of a spider web.
# 1870:
# 1871: Blasting farts in the
# 1872: powder room.
# 1873:
# 1874: Having to pee
# 1875: so bad.
# 1876:
# 1877:

# %%
if CAHFileName == "CAH_MainGame.txt":
    # Inititalising variables
    AnswerLineStart = 133 # the line number in which the answer cards start
    AnswerLineEnd = 1524 # the line number in which the end of the last answer card is located
    QuestionLineStart = 1524 # the line number in which the question cards start
    QuestionLineEnd = 1919 # the line number in which the end of the last question card is located
elif CAHFileName == "CAH_Family_SmallCards.txt":
    # Inititalising variables
    AnswerLineStart = 551 # the line number in which the answer cards start
    AnswerLineEnd = 1877 # the line number in which the end of the last answer card is located
    QuestionLineStart = 65 # the line number in which the question cards start
    QuestionLineEnd = 551 # the line number in which the end of the last question card is located

# %%
import string # imports tring to be able to access the constant punctuation to be able to strip the answer cards

FinishedQCards = []

# calling functions
ListOfLines = ReadInFile(CAHFileName) # makes ListOfLines equal a list of all the lines of the file
AnswerCards = ReturnCards(AnswerLineStart, AnswerLineEnd, ListOfLines) # makes the AnswerCards equal a list of all the answer cards
QuestionCards = ReturnCards(QuestionLineStart, QuestionLineEnd, ListOfLines) # makes the QuestionCards equal a list of all the question cards

# for loop to go thorugh all the cards and strip all the punctuation such as ? , . ! at the end of the of each card
for index in range(len(AnswerCards) - 1):
    AnswerCards[index] = AnswerCards[index].strip(string.punctuation)
    AnswerCards[index] = AnswerCards[index].strip()

# a for loop to go through all the question cards and change them
for index in range(len(QuestionCards) - 1):
    QCard, NumOfGaps = GapReplace(QuestionCards[index])
    # saves all the cards and number of gaps in a tuples inside the list
    FinishedQCards.append((QCard, NumOfGaps))

# %%
FinishedQCards # prints out the question cards
# Out:
# [('Papa, come quickly! There, in the garden! Do you see {0}? Tell me you see it, Papa!',
#   1),
#  ('Attention students! Principal Butthead is at home recovering from {0}. We hope he’ll be back soon.',
#   1),
#  ('I’m sorry, Jordan, but that’s not an acceptable Science Fair project. That’s just {0}.',
#   1),
#  ('The warm August air was filled with change. Things were different, for Kayla was now {0}.',
#   1),
#  ('This is gonna be the best sleepover ever. Once Mom goes to bed, it’s time for {0}!',
#   1),
#  ('Coming soon! Batman vs. {0}.', 1),
#  ('Class, pay close attention. I will now demonstrate the physics of {0}.', 1),
#  ('Hey Riley, I’ll give you five bucks if you try {0}.', 1),
#  ('Time to put on my favorite t-shirt, the one that says “I heart {0}.”', 1),
#  ('My dad and I enjoy {0} together.', 1),
#  ('Hey, kids. I’m Sensei Todd. Today, I’m gonna teach you how to defend yourself against {0}.',
#   1),
#  ('MY NAME CHUNGO. {0}', 1),
#  ('CHUNGO LOVE {0}.', 1),
#  ('Never fear, Captain {0} is here!', 1),
#  ('Kids, Dad is trying something new this week. It’s called “{0}.”', 1),
#  ('Oh, no thank you, Mrs. Lee. I’ve had plenty of {0} for now.', 1),
#  ('There’s nothing better than a peanut butter and {0} sandwich.', 1),
#  ('And over here is Picasso’s most famous painting, “Portrait of {0}.”', 1),
#  ('The aliens are here. They want {0}.', 1),
#  ('They call me “Mr. {0}.”', 1),
#  ('CHUNGO FEEL SICK. {0}', 1),
#  ('CHUNGO NO LIKE {0} ANYMORE.', 1),
#  ('Mom!? You have to come pick me up! There’s {0} at this party!', 1),
#  ('CNN breaking news! Over half of Americans are now {0}.', 1),
#  ('On the next episode of Dora the Explorer, Dora explores {0}.', 1),
#  ('Alright, which one of you little turds is responsible for {0}?!', 1),
#  ('Ladies and gentlemen, I have discovered something amazing. I have discovered {0}.',
#   1),
#  ('And in the blue corner, weighing in at 280 pounds, it’s Tommy “{0}” Takahashi!',
#   1),
#  ('Outback Steakhouse: No rules. Just {0}.', 1),
#  ('Ew. Grandpa smells like {0}.', 1),
#  ('My name is Peter Parker. I was bitten by a radioactive spider, and now I’m {0}.',
#   1),
#  ('Put on your helmet, strap on your goggles, and get ready for {0}!', 1),
#  ('Attention students! This is Principal Butthead reminding you that we do not allow {0} in the hallway. Thank you.',
#   1),
#  ('What’s about to take this school dance to the next level? {0}', 1),
#  ('Little Miss Muffet Sat on a tuffet Eating her curds and {0}.', 1),
#  ('All I want for Christmas is {0}.', 1),
#  ('Me and my friends don’t play with dolls anymore. We’re into {0} now.', 1),
#  ('We’re not supposed to go in the attic. My parents keep {0} in there.', 1),
#  ('Police! Arrest this man! He’s {0}.', 1),
#  ('My favorite dinosaur is “{0}asaurus.”', 1),
#  ('When I pooped, what came out of my butt? {0}', 1),
#  ('I’m not like the other children. Toys bore me, and I don’t care for sweets. I prefer {0}.',
#   1),
#  ('I’m sorry, Mrs. Sanchez, but I couldn’t finish my homework because of {0}.',
#   1),
#  ('Oh Dark Lord, we show our devotion with a humble offering of {0}!', 1),
#  ('Thanks for watching! If you want to see more vids of {0}, smash that subscribe.',
#   1),
#  ('We’re off to see the wizard, the wonderful wizard of {0}!', 1),
#  ('What’s all fun and games until somebody gets hurt? {0}', 1),
#  ('Young lady, we do not allow {0} at the dinner table.', 1),
#  ('Welcome! We’re glad you’re here. Now sit back, relax, and enjoy {0}.', 1),
#  ('My favorite book is The Amazing Adventures of {0}.', 1),
#  ('Well, look what we have here! A big fancy man walkin’ in like he’s {0}.',
#   1),
#  ('ENOUGH! I will not let {0} tear this family apart!', 1),
#  ('Rub a dub dub, {0} in a tub!', 1),
#  ('Madam President, we’ve run out of time. The only option is {0}.', 1),
#  ('I have invented a new sport. I call it “{0} ball.”', 1),
#  ('Hey, check out my band! We’re called “Rage Against {0}.”', 1),
#  ('Moms love {0}. Where do babies', 1),
#  ('come from? {0}', 1),
#  ('CHUNGO ANGRY.  CHUNGO DESTROY {0}.', 1),
#  ('At school, I’m just Mandy. But at summer camp, I’m “{0} Mandy.”', 1),
#  ('James Bond will return in “No Time for {0}.”', 1),
#  ('It’s BIG. It’s SCARY. It’s {0}!', 1),
#  ('Disney proudly presents: “{0} on Ice.”', 1),
#  ('What really killed the dinosaurs? {0}', 1),
#  ('Beep beep! {0} coming through!', 1),
#  ('Now in bookstores: Nancy Drew and the Mystery of {0}.', 1),
#  ('You don’t love me, Sam. All you care about is {0}.', 1),
#  ('Did you know that Benjamin Franklin invented {0}?', 1),
#  ('One nation, under God, indivisible, with liberty and {0} for all.', 1),
#  ('The easiest way to tell me and my twin apart is that I have a freckle on my cheek and she’s {0}.',
#   1),
#  ('Hey guys. I just want to tell all my followers who are struggling with {0}: it DOES get better.',
#   1),
#  ('I lost my arm in a {0} accident.', 1),
#  ('Whoa there, partner! Looks like {0} spooked my horse.', 1),
#  ('Princess Marigold, the kingdom is in danger! You must stop {0}.', 1),
#  ('Shut up, Becky! At least I’m not {0}.', 1),
#  ('Isn’t this great, honey? Just you, me, the kids, and {0}.', 1),
#  ('Foolish child! Did you think you could escape from {0}?', 1),
#  ('Girls just wanna have {0}.', 1),
#  ('Run, run, as fast as you can. You can’t catch me, I’m {0}!', 1),
#  ('New from Mattel, it’s {0} Barbie!', 1),
#  ('No fair! How come Chloe gets her own phone, and all I get is {0}?', 1),
#  ('Bow before me, for I am the Queen of {0}!', 1),
#  ('New from Hasbro! It’s BUNGO: The Game of {0}.', 1),
#  ('What killed Old Jim? {0}', 1),
#  ('I don’t really know what my mom’s job is, but I think it has something to do with {0}.',
#   1),
#  ('Next from J.K. Rowling: Harry Potter and the Chamber of {0}.', 1),
#  ('Our day at the water park was totally ruined by {0}.', 1),
#  ('Charmander has evolved into {0}!', 1),
#  ('What’s keeping Dad so busy in the garage? {0}', 1),
#  ('Boys? No. {0}? Yes!', 1),
#  ('ME HUNGRY. ME WANT {0}.', 1),
#  ('Oh, that’s my mom’s friend Carl. He comes over and helps her with {0}.', 1),
#  ('Guys, stop it! There’s nothing funny about {0}.', 1),
#  ('Huddle up, Wildcats! They may be bigger. They may be faster. But we’ve got a secret weapon: {0}.',
#   1),
#  ('Coming to theaters this holiday season, “Star Wars: The Rise of {0}.”', 1),
#  ('I do not fight for wealth. I do not fight for glory. I fight for {0}!', 1)]

# %%
AnswerCards # prints out the answer cards
# Out:
# ['A big wet kiss from Great Aunt Sharon',
#  'A cloud that rains diarrhea',
#  'A pirate with two peg arms, two peg legs, and a peg head',
#  'Athena, Goddess of Wisdom',
#  'Baby boomers',
#  'Beautiful Grandma',
#  'Defecating on the neighbor’s lawn',
#  'Eight hours of video games',
#  'Going night-night',
#  'Hanging out with Zendaya',
#  'Kissing Mom on the lips',
#  'Me, your dad',
#  'Playing trumpet for the Mayor',
#  'Ratzilla',
#  'Teeny tiny turds',
#  'That there tarantula',
#  'The way Grandpa smells',
#  'Three glasses of red wine',
#  'Whatever Dad does at work',
#  'Getting shot out of a cannon',
#  'Jesus',
#  'Eating pasta out of my pants',
#  'A burrito smoothie',
#  'A bear',
#  'Old people',
#  'My sister’s stupid boyfriend',
#  'Stuffing my underwear with pancakes',
#  'Stinky Martha, the superhero that nobody likes',
#  'My chainsaw',
#  'Diarrhea',
#  'Boogers',
#  'The police',
#  'Sniffing a dog’s butt',
#  'Horrible allergies',
#  'Your face',
#  'A gerbil named “Gerbil.”',
#  'Fartus Magnimus, God of Beans',
#  'Rated-R stuff',
#  'Blowing up the Moon',
#  'Getting launched into space',
#  'Likes',
#  'A bird pooping on the president’s head',
#  'Chungo, the talking gorilla',
#  'The way I feel when I see Kyle',
#  'Hot gossip',
#  'Forgetting to put on underwear',
#  'Running full speed into a wall',
#  'The Russians',
#  'A black hole',
#  'Putting my butt on stuff',
#  'Racism, sexism, and homophobia',
#  'Making the bees angry',
#  'My strong, terrifying daughter',
#  'A Democrat',
#  'TikTok',
#  'Cheeto fingers',
#  'A huge honkin’ carrot',
#  'The country of Bolivia',
#  'My parents',
#  'Idiots',
#  'Filling my butt with spaghetti',
#  'Putting an apple in a little boy’s mouth and roasting him for dinner',
#  'Thousands of lasagna',
#  'Climbing into a cow’s butt',
#  'War with Canada',
#  'Mashing a banana into your belly button',
#  'China',
#  'Shrek',
#  'Cavities',
#  'Eating people',
#  'Butts of all shapes and sizes',
#  'A 40-piece Chicken McNuggets',
#  'Climate change',
#  'Barf',
#  'A poop as big as Mom',
#  'A couch that eats children',
#  'Going to Hell',
#  'The loose skin at the joint of the elbow known as “the weenus.”',
#  'A horse with no legs',
#  'Fat stacks of cash',
#  'Dora the Explorer',
#  'Illegal drugs',
#  'BULBASAUR',
#  'Dad’s meatloaf',
#  'Extra-warm Pepsi',
#  'Calling 9-1-1',
#  'The old man with the rake who lives down the dark and winding road',
#  'Toe jam',
#  'Hot lava',
#  'Butt surgery',
#  'Spending my parents’ hard-earned money',
#  'Freeing all the animals from the zoo',
#  'A bountiful harvest of squashes and corns',
#  'Bombs',
#  'Boobies',
#  'Respecting personal boundaries',
#  'Having no idea what’s going on',
#  'John Wilkes Booth',
#  'Getting married',
#  'Politics',
#  'Garbage',
#  'Naked people',
#  'This stupid game',
#  'Biting a rich person',
#  'Screaming at birds',
#  'Getting stuck in the toilet',
#  'Getting crushed by a piano',
#  'Huge pants',
#  'Mom’s spaghetti',
#  'An old, dirty cat with bad breath',
#  'A corn dog',
#  'My followers',
#  'Principal Butthead',
#  'A statue of a naked guy',
#  'A tiny detective who solves tiny crimes',
#  'Joining the army',
#  'Witchcraft',
#  'Taking out my eyeballs',
#  'Sacrificing Uncle Tim',
#  'Moving to Ohio',
#  'A hundred screaming monkeys',
#  'A wise old woman with no teeth and cloudy eyes',
#  'Emotions',
#  'Ham',
#  'Clams',
#  'Spider-Man',
#  'Drinking out of the toilet and eating garbage',
#  'Trying to catch that dang raccoon',
#  'Slapping my huge belly',
#  'The doll that watches me sleep',
#  'Money',
#  'LeBron James',
#  'Father’s forbidden chocolates',
#  'Me',
#  'Salmon',
#  'Screaming the F-word',
#  'A whole thing of cottage cheese',
#  'Crab-walking from the toilet to get more toilet paper',
#  'Mayonnaise',
#  'Total world domination',
#  'Failure',
#  'JoJo Siwa',
#  'Getting kicked in the nuts',
#  'Farting and walking away',
#  'Sharks with legs',
#  'Triangles',
#  'Ninjas',
#  'The floor',
#  'The whole family',
#  'Bench pressing a horse',
#  'Spiders',
#  'Uranus',
#  'A Republican',
#  'Giving wedgies to my haters',
#  '14 cheeseburgers, 6 large fries, and a medium Sprite',
#  'Big Randy',
#  'Blasting my math teacher into the sun',
#  'Dreaming about boys',
#  'Taking a dump in the pool',
#  'Crying in the bathroom',
#  'Happiness',
#  'Poison',
#  'My sister’s hair all over the place',
#  'A scoop of tuna',
#  'Doing karate',
#  'Hades, God of the Underworld',
#  'Lil Nas X',
#  'Dad’s famous poops',
#  'Squirty cheese',
#  'My girlfriend, who goes to another school',
#  'Mowing the stupid lawn',
#  'Slapping that butt',
#  'Questioning authority',
#  'Chugging a gallon of milk and then vomiting a gallon of milk',
#  'Farting a lot today',
#  'Going bald',
#  'Germs',
#  'Nuclear war',
#  'Barfing into a popcorn bucket',
#  'A cursed llama with no eyes',
#  'The wettest fart you ever heard',
#  'Shaving Dad’s back',
#  'Overthrowing the government',
#  'Murdering',
#  'Exploding',
#  'Bleeding',
#  'The oppressive system of capitalism',
#  'Supreme Court Justice Ruth Bader Ginsburg',
#  'A long, hot pee',
#  'Throwing up double peace signs with my besties at Starbucks',
#  'A balloon filled with chili',
#  'The dishes',
#  'The freedom of speech',
#  'Egg salad',
#  'Mom’s friend, Donna',
#  'Rich people',
#  'Pirate music',
#  'Being a dinosaur',
#  'A fake kid made out of wood',
#  'Homework',
#  'Batman',
#  'A dead body',
#  'Drinking a whole bottle of ranch',
#  'Destroying the planet',
#  'Living in a pineapple under the sea',
#  'Pizza',
#  'This pumpkin',
#  'Extremely tight underpants',
#  'A nice, warm glass of pee',
#  'Poseidon, Lord of the Sea',
#  'Complaining',
#  'Bursting into flames',
#  'Spawning sheep',
#  'My whole body getting big and strong and beautiful',
#  'Big, juicy pimples',
#  'The humble earthworm',
#  'The garbage man',
#  'A big, and I mean BIG turtle',
#  'Your mom',
#  'The octopus stuck to my face',
#  'Dying of old age',
#  'Smashing the patriarchy',
#  'Screaming into a can of Pringles',
#  'Grandpa',
#  'Shutting up',
#  'Silence',
#  'My annoying brother',
#  'My future husband',
#  'A hot air balloon powered by fart gas',
#  'Sitting on the toilet and going poop',
#  'A screaming soccer dad',
#  'Cocktail weenies',
#  'The British',
#  'Voldemort',
#  'Science',
#  'Picking my nose and eating it',
#  'Having a really big head',
#  'A dead whale',
#  'Fortnite',
#  'The power of the Dark Side',
#  'Big butt cheeks filled with poop',
#  'My friend Steve',
#  'Violence',
#  'Magic: The Gathering',
#  'Eating toenail clippings',
#  'Using balloons as boobies',
#  'My dang kids',
#  'Squeezing a lemon into my eye',
#  'Tombus, the talking rhombus',
#  'Greta Thunberg',
#  'Ellen',
#  'Uncle Bob',
#  'Outback Steakhouse',
#  'Dwayne “The Rock” Johnson',
#  'A baby with a full mustache',
#  'Getting hit in the face with a soccer ball',
#  'Eating a whole roll of toilet paper',
#  'The bacon',
#  'The first female president of the United States',
#  'Falling off a mountain',
#  'Person milk',
#  'Pink eye',
#  'Pork',
#  'The government',
#  'Nunchucks',
#  'Nothing',
#  'GOOOAAALLLL',
#  'Mom’s new haircut',
#  'Happy daddies with happy sandals',
#  'Giggling and farting and slurping milkshakes',
#  'Ice pee',
#  'Obama',
#  'Twerking',
#  'Reading my sister’s diary',
#  'The ice cream man',
#  'Love',
#  'Stank breath',
#  'Living in the dumpster',
#  'Having a baby',
#  'Shoplifting',
#  'My father, who is a walrus',
#  'The dentist',
#  'Aunt Linda',
#  'One tough mama',
#  'Releasing the falcons',
#  'Literally ruining my life',
#  'Flushing myself down the toilet',
#  'Fire farts',
#  'Lice',
#  'A killer clown',
#  'Blossoming into a beautiful young man',
#  'Wiping my butt',
#  'Saying mean stuff and making people feel bad',
#  'Beyoncé',
#  'A truck',
#  'Only beans',
#  'The beautiful potato',
#  'Legs',
#  'The woman I’m going to marry one day',
#  'Unleashing a hell demon that will destroy our world',
#  'Feminism',
#  'Lighting stuff on fire',
#  'Turning 40',
#  'Getting a skull tattoo',
#  'An invisible giant who takes giant, visible poops',
#  'A cowboy who is half boy, half cow',
#  'The longest tongue in the world',
#  'Josh',
#  'Locking Mother in the pantry',
#  'Ariana Grande',
#  'Puberty',
#  'A glorious beard',
#  'All of my teeth falling out',
#  'Floating through the void of space and time',
#  'Farting, barfing, and passing out',
#  'Flamin’ Hot Cheetos',
#  'Snakes',
#  'Free ice cream, yo',
#  'Screaming and screaming and never waking up',
#  'Running away from home',
#  'Using my butt as a microwave',
#  'Glen’s fabulous body',
#  'Gluten',
#  'Wakanda',
#  'Many wolves',
#  'One long hair growing out of a mole',
#  'A butt that eats underwear',
#  'Poo-poo',
#  'Mooing',
#  'Robbing a bank',
#  'Punching everyone',
#  'How much wood a woodchuck would chuck if a woodchuck could chuck wood',
#  'Swords',
#  'Kevin’s mom',
#  'Getting scalded in the face with hot beans',
#  'Chest hair',
#  'My annoying sister',
#  'Getting slapped with a fish',
#  'Harry Potter',
#  'Peeing sand',
#  'Being French, hoh-hoh-hoh',
#  'Guacamole',
#  'Getting naked',
#  'A super angry cat I found outside',
#  'Slappy Spatchy, the game where you slap each other with spatulas. Learn more at www.SlappySpatchy.com',
#  'A pregnant person',
#  'A bunch of dead squirrels on a trampoline',
#  'Grandma panties',
#  'Thick, nasty burps',
#  'Having no bones',
#  'Famous peanut scientist George Washington Carver',
#  'Saving up my boogers for ten years and then building the world’s largest booger',
#  'The president',
#  'A hug',
#  'The Dark Lord',
#  'Being super serious right now',
#  'Freeing a fart from its butt prison',
#  'An order of mozzarella sticks',
#  'Fake news',
#  'The baby',
#  'Like a million alligators',
#  'Big, slappy hands',
#  'Beer',
#  'Spit',
#  'The fifth graders',
#  'Licking a goat',
#  'A flamethrower',
#  'Drama',
#  'Old Jim’s Steamy Butt Sauce',
#  'Going to the emergency room',
#  'Sitting atop a pile of tuna, like some kind of tuna queen',
#  'Girls',
#  'A Pringle',
#  'Never showering',
#  'Naptime',
#  'The gym teacher',
#  'Coming back from the dead',
#  'Burning books',
#  'Falling in love',
#  'Tossed salads and scrambled eggs',
#  'Building a ladder of hot dogs to the moon',
#  'Practicing kissing',
#  'Eating a lightning bug to gain its lightning powers',
#  'Slowly turning into cheese',
#  'Ear wax',
#  'Knives',
#  'Stuff',
#  'Whispering secrets to my best friend, Turkey',
#  'Taking a selfie',
#  'Dancing with my son',
#  'Punching a guy through a wall',
#  'Nipples',
#  'Cat pee',
#  'Dump cake',
#  'Billie Eilish',
#  'Steven Universe',
#  'Elegant party hats',
#  'Santa Claus',
#  'The gluteus maximus',
#  'Baby Yoda',
#  'Peeing in the cat’s litter box',
#  'A big sad dragon with no friends',
#  'A big whiny cry-baby',
#  'Seymour Butts',
#  'The bus driver',
#  'Getting run over by a train',
#  'Spinning and barfing',
#  'Some freakin’ privacy',
#  'Butt hair',
#  'Having many husbands',
#  'Making the bathroom smell',
#  'Coffee',
#  'Anime',
#  'The sweet honking of Karen’s bassoon',
#  'Pooping in a bag and lighting it on fire',
#  'Space lasers',
#  'Being dead',
#  'Pooping barf forever',
#  'FOOOOD FIIIIIIIIIIIIIIIIIGHT',
#  'Wearing high heels',
#  'A long, long snake',
#  'Getting trampled by horses',
#  'The babysitter',
#  'The lunch lady',
#  'Peeing on my poopy',
#  'Not wearing pants. Meatballs, meatballs, meatballs',
#  'Finding Waldo',
#  'Going around sniffing people’s armpits',
#  'The divorce',
#  'Diaper beans',
#  'Cigarettes',
#  'Getting my ponytail stuck in my butt',
#  'Looking into people’s windows',
#  'Sucking at life',
#  'Crossbows',
#  'Evil',
#  'A big rock',
#  'Rubbing lotion on a hairless cat',
#  'Goblins',
#  'Nasty Cousin Amber',
#  'Tongue kissing',
#  'Abraham Lincoln',
#  'Covering myself with ketchup and mustard because I am hot dog',
#  'Hot, fresh doodies',
#  'Feet',
#  'Sadness',
#  'Going beast mode',
#  'An owl that hates you',
#  'A doll that pees real pee',
#  'A naked lady in a painting',
#  'Chunks',
#  'Some weird guy',
#  'Getting a girlfriend',
#  'Falling in love with a hot dog',
#  'Throwing stuff at other stuff',
#  'Hogs',
#  'A turd that just won’t flush',
#  'The entire state of Texas',
#  'Showing everyone my butt',
#  'My big donkey brother',
#  'The huge, stupid moon',
#  'Math',
#  'Pee-pee',
#  'Dinner',
#  'Butthole',
#  'Smelling like onions',
#  'Being fake',
#  'Peer pressure',
#  'Peeing in my backpack',
#  'Bad parenting',
#  'Mom’s butt',
#  'One weird lookin’ toe',
#  'You',
#  'Boys',
#  'Sitting on a cake',
#  'Teaching a chicken to kill',
#  'The middle finger',
#  'A bra',
#  'Being famous on YouTube',
#  'Cream',
#  'Balls',
#  'Having no friends',
#  'Peeing into everyone’s mouth',
#  'Gluing my butt cheeks together',
#  'How school slowly breaks your spirit and drains your will to live',
#  'A Pokémon named “Jim.”',
#  'True love’s kiss',
#  'Total crap',
#  'Cool sunglasses',
#  'Literally dying from the smell of a fart',
#  'Snot bubbles',
#  'Doing crimes and going to jail',
#  'This goat, who is my friend',
#  'Aliens',
#  'School',
#  'A cow',
#  'The terrible winter of 1609',
#  'Getting sucked into a jet engine',
#  'Not breathing',
#  'Licking a used band-aid',
#  'Braiding my armpit hair',
#  'Waking up inside of a spider web',
#  'Blasting farts in the powder room',
#  'Having to pee so bad.']

# %% [markdown]
# ### example of how an answered question card is going to look like

# %%
import random

RandomAnsCards = []

RandomQCard = FinishedQCards[random.randint(0, (len(FinishedQCards)-1))]
for index in range(RandomQCard[1]):
    RandomAnsCards.append(AnswerCards[random.randint(0, (len(AnswerCards) - 1))])
RandomQCard[0].format(*RandomAnsCards)
# Out:
# 'No fair! How come Chloe gets her own phone, and all I get is The dentist?'

# %% [markdown]
# ### Testing the function GapReplace as it was the hardest to code

# %%
s = "i like _____ and ____ because it is good"
GapReplace(s) # should return ('i like {0} and {1} because it is good', 2)
# Out:
# ('i like {0} and {1} because it is good', 2)

# %%
s = "how many years was I here?"
GapReplace(s) # should return ('how many years was I here? {0}', 1)
# Out:
# ('how many years was I here? {0}', 1)

# %%
s = "i like ___ because it is good"
GapReplace(s) # should return ('i like {0} because it is good', 1)
# Out:
# ('i like {0} because it is good', 1)

# %%
s = "______ + __ = ________"
GapReplace(s) # should return ('{0} + {1} = {2}', 3)
# Out:
# ('{0} + {1} = {2}', 3)

# %% [markdown]
# ### Saves the cards in the database

# %%
import sqlite3

con = sqlite3.connect('CAH.db') # connects to the database
cur = con.cursor() # creates a cursor
TypeCard = ""
count = 0

# %%
# checks to see if there is already a table called Cards and if there is it deletes it
try:
    cur.execute("DROP TABLE Cards")
except:
    pass

# creates the table Cards with the properties: id, type (answer or question), card(the actual card), NumGaps (onlyfor question cards and it is the num of gaps in it)
cur.execute("""CREATE TABLE Cards 
                (id int PRIMARY KEY,
                type text,
                card text,
                NumGaps int)""")

# loops through all the question cards and saves them in the table with an id added to it
TypeCard = "Question"
for index in range(len(FinishedQCards) - 1):
    cur.execute(f"""INSERT INTO Cards VALUES ({count}, "{TypeCard}", "{FinishedQCards[index][0]}", {FinishedQCards[index][1]})""")
    count += 1

# loops through all the answer cards and saves them in the table with an id added to it
TypeCard = "Answer"
for index in range(len(AnswerCards) - 1):
    cur.execute(f"""INSERT INTO Cards (id, type, card) VALUES 
                    ({count}, "{TypeCard}", "{AnswerCards[index]}")""")
    count += 1

# commits the table into the database
con.commit()

# %%
# prints out the whole table
for card in cur.execute("SELECT * FROM Cards"):
    print(card)
# Out:
# (0, 'Question', 'Papa, come quickly! There, in the garden! Do you see {0}? Tell me you see it, Papa!', 1)
# (1, 'Question', 'Attention students! Principal Butthead is at home recovering from {0}. We hope he’ll be back soon.', 1)
# (2, 'Question', 'I’m sorry, Jordan, but that’s not an acceptable Science Fair project. That’s just {0}.', 1)
# (3, 'Question', 'The warm August air was filled with change. Things were different, for Kayla was now {0}.', 1)
# (4, 'Question', 'This is gonna be the best sleepover ever. Once Mom goes to bed, it’s time for {0}!', 1)
# (5, 'Question', 'Coming soon! Batman vs. {0}.', 1)
# (6, 'Question', 'Class, pay close attention. I will now demonstrate the physics of {0}.', 1)
# (7, 'Question', 'Hey Riley, I’ll give you five bucks if you try {0}.', 1)
# (8, 'Question', 'Time to put on my favorite t-shirt, the one that says “I heart {0}.”', 1)
# (9, 'Question', 'My dad and I enjoy {0} together.', 1)
# (10, 'Question', 'Hey, kids. I’m Sensei Todd. Today, I’m gonna teach you how to defend yourself against {0}.', 1)
# (11, 'Question', 'MY NAME CHUNGO. {0}', 1)
# (12, 'Question', 'CHUNGO LOVE {0}.', 1)
# (13, 'Question', 'Never fear, Captain {0} is here!', 1)
# (14, 'Question', 'Kids, Dad is trying something new this week. It’s called “{0}.”', 1)
# (15, 'Question', 'Oh, no thank you, Mrs. Lee. I’ve had plenty of {0} for now.', 1)
# (16, 'Question', 'There’s nothing better than a peanut butter and {0} sandwich.', 1)
# (17, 'Question', 'And over here is Picasso’s most famous painting, “Portrait of {0}.”', 1)
# (18, 'Question', 'The aliens are here. They want {0}.', 1)
# (19, 'Question', 'They call me “Mr. {0}.”', 1)
# (20, 'Question', 'CHUNGO FEEL SICK. {0}', 1)
# (21, 'Question', 'CHUNGO NO LIKE {0} ANYMORE.', 1)
# (22, 'Question', 'Mom!? You have to come pick me up! There’s {0} at this party!', 1)
# (23, 'Question', 'CNN breaking news! Over half of Americans are now {0}.', 1)
# (24, 'Question', 'On the next episode of Dora the Explorer, Dora explores {0}.', 1)
# (25, 'Question', 'Alright, which one of you little turds is responsible for {0}?!', 1)
# (26, 'Question', 'Ladies and gentlemen, I have discovered something amazing. I have discovered {0}.', 1)
# (27, 'Question', 'And in the blue corner, weighing in at 280 pounds, it’s Tommy “{0}” Takahashi!', 1)
# (28, 'Question', 'Outback Steakhouse: No rules. Just {0}.', 1)
# (29, 'Question', 'Ew. Grandpa smells like {0}.', 1)
# (30, 'Question', 'My name is Peter Parker. I was bitten by a radioactive spider, and now I’m {0}.', 1)
# (31, 'Question', 'Put on your helmet, strap on your goggles, and get ready for {0}!', 1)
# (32, 'Question', 'Attention students! This is Principal Butthead reminding you that we do not allow {0} in the hallway. Thank you.', 1)
# (33, 'Question', 'What’s about to take this school dance to the next level? {0}', 1)
# (34, 'Question', 'Little Miss Muffet Sat on a tuffet Eating her curds and {0}.', 1)
# (35, 'Question', 'All I want for Christmas is {0}.', 1)
# (36, 'Question', 'Me and my friends don’t play with dolls anymore. We’re into {0} now.', 1)
# (37, 'Question', 'We’re not supposed to go in the attic. My parents keep {0} in there.', 1)
# (38, 'Question', 'Police! Arrest this man! He’s {0}.', 1)
# (39, 'Question', 'My favorite dinosaur is “{0}asaurus.”', 1)
# (40, 'Question', 'When I pooped, what came out of my butt? {0}', 1)
# (41, 'Question', 'I’m not like the other children. Toys bore me, and I don’t care for sweets. I prefer {0}.', 1)
# (42, 'Question', 'I’m sorry, Mrs. Sanchez, but I couldn’t finish my homework because of {0}.', 1)
# (43, 'Question', 'Oh Dark Lord, we show our devotion with a humble offering of {0}!', 1)
# (44, 'Question', 'Thanks for watching! If you want to see more vids of {0}, smash that subscribe.', 1)
# (45, 'Question', 'We’re off to see the wizard, the wonderful wizard of {0}!', 1)
# (46, 'Question', 'What’s all fun and games until somebody gets hurt? {0}', 1)
# (47, 'Question', 'Young lady, we do not allow {0} at the dinner table.', 1)
# (48, 'Question', 'Welcome! We’re glad you’re here. Now sit back, relax, and enjoy {0}.', 1)
# (49, 'Question', 'My favorite book is The Amazing Adventures of {0}.', 1)
# (50, 'Question', 'Well, look what we have here! A big fancy man walkin’ in like he’s {0}.', 1)
# (51, 'Question', 'ENOUGH! I will not let {0} tear this family apart!', 1)
# (52, 'Question', 'Rub a dub dub, {0} in a tub!', 1)
# (53, 'Question', 'Madam President, we’ve run out of time. The only option is {0}.', 1)
# (54, 'Question', 'I have invented a new sport. I call it “{0} ball.”', 1)
# (55, 'Question', 'Hey, check out my band! We’re called “Rage Against {0}.”', 1)
# (56, 'Question', 'Moms love {0}. Where do babies', 1)
# (57, 'Question', 'come from? {0}', 1)
# (58, 'Question', 'CHUNGO ANGRY.  CHUNGO DESTROY {0}.', 1)
# (59, 'Question', 'At school, I’m just Mandy. But at summer camp, I’m “{0} Mandy.”', 1)
# (60, 'Question', 'James Bond will return in “No Time for {0}.”', 1)
# (61, 'Question', 'It’s BIG. It’s SCARY. It’s {0}!', 1)
# (62, 'Question', 'Disney proudly presents: “{0} on Ice.”', 1)
# (63, 'Question', 'What really killed the dinosaurs? {0}', 1)
# (64, 'Question', 'Beep beep! {0} coming through!', 1)
# (65, 'Question', 'Now in bookstores: Nancy Drew and the Mystery of {0}.', 1)
# (66, 'Question', 'You don’t love me, Sam. All you care about is {0}.', 1)
# (67, 'Question', 'Did you know that Benjamin Franklin invented {0}?', 1)
# (68, 'Question', 'One nation, under God, indivisible, with liberty and {0} for all.', 1)
# (69, 'Question', 'The easiest way to tell me and my twin apart is that I have a freckle on my cheek and she’s {0}.', 1)
# (70, 'Question', 'Hey guys. I just want to tell all my followers who are struggling with {0}: it DOES get better.', 1)
# (71, 'Question', 'I lost my arm in a {0} accident.', 1)
# (72, 'Question', 'Whoa there, partner! Looks like {0} spooked my horse.', 1)
# (73, 'Question', 'Princess Marigold, the kingdom is in danger! You must stop {0}.', 1)
# (74, 'Question', 'Shut up, Becky! At least I’m not {0}.', 1)
# (75, 'Question', 'Isn’t this great, honey? Just you, me, the kids, and {0}.', 1)
# (76, 'Question', 'Foolish child! Did you think you could escape from {0}?', 1)
# (77, 'Question', 'Girls just wanna have {0}.', 1)
# (78, 'Question', 'Run, run, as fast as you can. You can’t catch me, I’m {0}!', 1)
# (79, 'Question', 'New from Mattel, it’s {0} Barbie!', 1)
# (80, 'Question', 'No fair! How come Chloe gets her own phone, and all I get is {0}?', 1)
# (81, 'Question', 'Bow before me, for I am the Queen of {0}!', 1)
# (82, 'Question', 'New from Hasbro! It’s BUNGO: The Game of {0}.', 1)
# (83, 'Question', 'What killed Old Jim? {0}', 1)
# (84, 'Question', 'I don’t really know what my mom’s job is, but I think it has something to do with {0}.', 1)
# (85, 'Question', 'Next from J.K. Rowling: Harry Potter and the Chamber of {0}.', 1)
# (86, 'Question', 'Our day at the water park was totally ruined by {0}.', 1)
# (87, 'Question', 'Charmander has evolved into {0}!', 1)
# (88, 'Question', 'What’s keeping Dad so busy in the garage? {0}', 1)
# (89, 'Question', 'Boys? No. {0}? Yes!', 1)
# (90, 'Question', 'ME HUNGRY. ME WANT {0}.', 1)
# (91, 'Question', 'Oh, that’s my mom’s friend Carl. He comes over and helps her with {0}.', 1)
# (92, 'Question', 'Guys, stop it! There’s nothing funny about {0}.', 1)
# (93, 'Question', 'Huddle up, Wildcats! They may be bigger. They may be faster. But we’ve got a secret weapon: {0}.', 1)
# (94, 'Question', 'Coming to theaters this holiday season, “Star Wars: The Rise of {0}.”', 1)
# (95, 'Answer', 'A big wet kiss from Great Aunt Sharon', None)
# (96, 'Answer', 'A cloud that rains diarrhea', None)
# (97, 'Answer', 'A pirate with two peg arms, two peg legs, and a peg head', None)
# (98, 'Answer', 'Athena, Goddess of Wisdom', None)
# (99, 'Answer', 'Baby boomers', None)
# (100, 'Answer', 'Beautiful Grandma', None)
# (101, 'Answer', 'Defecating on the neighbor’s lawn', None)
# (102, 'Answer', 'Eight hours of video games', None)
# (103, 'Answer', 'Going night-night', None)
# (104, 'Answer', 'Hanging out with Zendaya', None)
# (105, 'Answer', 'Kissing Mom on the lips', None)
# (106, 'Answer', 'Me, your dad', None)
# (107, 'Answer', 'Playing trumpet for the Mayor', None)
# (108, 'Answer', 'Ratzilla', None)
# (109, 'Answer', 'Teeny tiny turds', None)
# (110, 'Answer', 'That there tarantula', None)
# (111, 'Answer', 'The way Grandpa smells', None)
# (112, 'Answer', 'Three glasses of red wine', None)
# (113, 'Answer', 'Whatever Dad does at work', None)
# (114, 'Answer', 'Getting shot out of a cannon', None)
# (115, 'Answer', 'Jesus', None)
# (116, 'Answer', 'Eating pasta out of my pants', None)
# (117, 'Answer', 'A burrito smoothie', None)
# (118, 'Answer', 'A bear', None)
# (119, 'Answer', 'Old people', None)
# (120, 'Answer', 'My sister’s stupid boyfriend', None)
# (121, 'Answer', 'Stuffing my underwear with pancakes', None)
# (122, 'Answer', 'Stinky Martha, the superhero that nobody likes', None)
# (123, 'Answer', 'My chainsaw', None)
# (124, 'Answer', 'Diarrhea', None)
# (125, 'Answer', 'Boogers', None)
# (126, 'Answer', 'The police', None)
# (127, 'Answer', 'Sniffing a dog’s butt', None)
# (128, 'Answer', 'Horrible allergies', None)
# (129, 'Answer', 'Your face', None)
# (130, 'Answer', 'A gerbil named “Gerbil.”', None)
# (131, 'Answer', 'Fartus Magnimus, God of Beans', None)
# (132, 'Answer', 'Rated-R stuff', None)
# (133, 'Answer', 'Blowing up the Moon', None)
# (134, 'Answer', 'Getting launched into space', None)
# (135, 'Answer', 'Likes', None)
# (136, 'Answer', 'A bird pooping on the president’s head', None)
# (137, 'Answer', 'Chungo, the talking gorilla', None)
# (138, 'Answer', 'The way I feel when I see Kyle', None)
# (139, 'Answer', 'Hot gossip', None)
# (140, 'Answer', 'Forgetting to put on underwear', None)
# (141, 'Answer', 'Running full speed into a wall', None)
# (142, 'Answer', 'The Russians', None)
# (143, 'Answer', 'A black hole', None)
# (144, 'Answer', 'Putting my butt on stuff', None)
# (145, 'Answer', 'Racism, sexism, and homophobia', None)
# (146, 'Answer', 'Making the bees angry', None)
# (147, 'Answer', 'My strong, terrifying daughter', None)
# (148, 'Answer', 'A Democrat', None)
# (149, 'Answer', 'TikTok', None)
# (150, 'Answer', 'Cheeto fingers', None)
# (151, 'Answer', 'A huge honkin’ carrot', None)
# (152, 'Answer', 'The country of Bolivia', None)
# (153, 'Answer', 'My parents', None)
# (154, 'Answer', 'Idiots', None)
# (155, 'Answer', 'Filling my butt with spaghetti', None)
# (156, 'Answer', 'Putting an apple in a little boy’s mouth and roasting him for dinner', None)
# (157, 'Answer', 'Thousands of lasagna', None)
# (158, 'Answer', 'Climbing into a cow’s butt', None)
# (159, 'Answer', 'War with Canada', None)
# (160, 'Answer', 'Mashing a banana into your belly button', None)
# (161, 'Answer', 'China', None)
# (162, 'Answer', 'Shrek', None)
# (163, 'Answer', 'Cavities', None)
# (164, 'Answer', 'Eating people', None)
# (165, 'Answer', 'Butts of all shapes and sizes', None)
# (166, 'Answer', 'A 40-piece Chicken McNuggets', None)
# (167, 'Answer', 'Climate change', None)
# (168, 'Answer', 'Barf', None)
# (169, 'Answer', 'A poop as big as Mom', None)
# (170, 'Answer', 'A couch that eats children', None)
# (171, 'Answer', 'Going to Hell', None)
# (172, 'Answer', 'The loose skin at the joint of the elbow known as “the weenus.”', None)
# (173, 'Answer', 'A horse with no legs', None)
# (174, 'Answer', 'Fat stacks of cash', None)
# (175, 'Answer', 'Dora the Explorer', None)
# (176, 'Answer', 'Illegal drugs', None)
# (177, 'Answer', 'BULBASAUR', None)
# (178, 'Answer', 'Dad’s meatloaf', None)
# (179, 'Answer', 'Extra-warm Pepsi', None)
# (180, 'Answer', 'Calling 9-1-1', None)
# (181, 'Answer', 'The old man with the rake who lives down the dark and winding road', None)
# (182, 'Answer', 'Toe jam', None)
# (183, 'Answer', 'Hot lava', None)
# (184, 'Answer', 'Butt surgery', None)
# (185, 'Answer', 'Spending my parents’ hard-earned money', None)
# (186, 'Answer', 'Freeing all the animals from the zoo', None)
# (187, 'Answer', 'A bountiful harvest of squashes and corns', None)
# (188, 'Answer', 'Bombs', None)
# (189, 'Answer', 'Boobies', None)
# (190, 'Answer', 'Respecting personal boundaries', None)
# (191, 'Answer', 'Having no idea what’s going on', None)
# (192, 'Answer', 'John Wilkes Booth', None)
# (193, 'Answer', 'Getting married', None)
# (194, 'Answer', 'Politics', None)
# (195, 'Answer', 'Garbage', None)
# (196, 'Answer', 'Naked people', None)
# (197, 'Answer', 'This stupid game', None)
# (198, 'Answer', 'Biting a rich person', None)
# (199, 'Answer', 'Screaming at birds', None)
# (200, 'Answer', 'Getting stuck in the toilet', None)
# (201, 'Answer', 'Getting crushed by a piano', None)
# (202, 'Answer', 'Huge pants', None)
# (203, 'Answer', 'Mom’s spaghetti', None)
# (204, 'Answer', 'An old, dirty cat with bad breath', None)
# (205, 'Answer', 'A corn dog', None)
# (206, 'Answer', 'My followers', None)
# (207, 'Answer', 'Principal Butthead', None)
# (208, 'Answer', 'A statue of a naked guy', None)
# (209, 'Answer', 'A tiny detective who solves tiny crimes', None)
# (210, 'Answer', 'Joining the army', None)
# (211, 'Answer', 'Witchcraft', None)
# (212, 'Answer', 'Taking out my eyeballs', None)
# (213, 'Answer', 'Sacrificing Uncle Tim', None)
# (214, 'Answer', 'Moving to Ohio', None)
# (215, 'Answer', 'A hundred screaming monkeys', None)
# (216, 'Answer', 'A wise old woman with no teeth and cloudy eyes', None)
# (217, 'Answer', 'Emotions', None)
# (218, 'Answer', 'Ham', None)
# (219, 'Answer', 'Clams', None)
# (220, 'Answer', 'Spider-Man', None)
# (221, 'Answer', 'Drinking out of the toilet and eating garbage', None)
# (222, 'Answer', 'Trying to catch that dang raccoon', None)
# (223, 'Answer', 'Slapping my huge belly', None)
# (224, 'Answer', 'The doll that watches me sleep', None)
# (225, 'Answer', 'Money', None)
# (226, 'Answer', 'LeBron James', None)
# (227, 'Answer', 'Father’s forbidden chocolates', None)
# (228, 'Answer', 'Me', None)
# (229, 'Answer', 'Salmon', None)
# (230, 'Answer', 'Screaming the F-word', None)
# (231, 'Answer', 'A whole thing of cottage cheese', None)
# (232, 'Answer', 'Crab-walking from the toilet to get more toilet paper', None)
# (233, 'Answer', 'Mayonnaise', None)
# (234, 'Answer', 'Total world domination', None)
# (235, 'Answer', 'Failure', None)
# (236, 'Answer', 'JoJo Siwa', None)
# (237, 'Answer', 'Getting kicked in the nuts', None)
# (238, 'Answer', 'Farting and walking away', None)
# (239, 'Answer', 'Sharks with legs', None)
# (240, 'Answer', 'Triangles', None)
# (241, 'Answer', 'Ninjas', None)
# (242, 'Answer', 'The floor', None)
# (243, 'Answer', 'The whole family', None)
# (244, 'Answer', 'Bench pressing a horse', None)
# (245, 'Answer', 'Spiders', None)
# (246, 'Answer', 'Uranus', None)
# (247, 'Answer', 'A Republican', None)
# (248, 'Answer', 'Giving wedgies to my haters', None)
# (249, 'Answer', '14 cheeseburgers, 6 large fries, and a medium Sprite', None)
# (250, 'Answer', 'Big Randy', None)
# (251, 'Answer', 'Blasting my math teacher into the sun', None)
# (252, 'Answer', 'Dreaming about boys', None)
# (253, 'Answer', 'Taking a dump in the pool', None)
# (254, 'Answer', 'Crying in the bathroom', None)
# (255, 'Answer', 'Happiness', None)
# (256, 'Answer', 'Poison', None)
# (257, 'Answer', 'My sister’s hair all over the place', None)
# (258, 'Answer', 'A scoop of tuna', None)
# (259, 'Answer', 'Doing karate', None)
# (260, 'Answer', 'Hades, God of the Underworld', None)
# (261, 'Answer', 'Lil Nas X', None)
# (262, 'Answer', 'Dad’s famous poops', None)
# (263, 'Answer', 'Squirty cheese', None)
# (264, 'Answer', 'My girlfriend, who goes to another school', None)
# (265, 'Answer', 'Mowing the stupid lawn', None)
# (266, 'Answer', 'Slapping that butt', None)
# (267, 'Answer', 'Questioning authority', None)
# (268, 'Answer', 'Chugging a gallon of milk and then vomiting a gallon of milk', None)
# (269, 'Answer', 'Farting a lot today', None)
# (270, 'Answer', 'Going bald', None)
# (271, 'Answer', 'Germs', None)
# (272, 'Answer', 'Nuclear war', None)
# (273, 'Answer', 'Barfing into a popcorn bucket', None)
# (274, 'Answer', 'A cursed llama with no eyes', None)
# (275, 'Answer', 'The wettest fart you ever heard', None)
# (276, 'Answer', 'Shaving Dad’s back', None)
# (277, 'Answer', 'Overthrowing the government', None)
# (278, 'Answer', 'Murdering', None)
# (279, 'Answer', 'Exploding', None)
# (280, 'Answer', 'Bleeding', None)
# (281, 'Answer', 'The oppressive system of capitalism', None)
# (282, 'Answer', 'Supreme Court Justice Ruth Bader Ginsburg', None)
# (283, 'Answer', 'A long, hot pee', None)
# (284, 'Answer', 'Throwing up double peace signs with my besties at Starbucks', None)
# (285, 'Answer', 'A balloon filled with chili', None)
# (286, 'Answer', 'The dishes', None)
# (287, 'Answer', 'The freedom of speech', None)
# (288, 'Answer', 'Egg salad', None)
# (289, 'Answer', 'Mom’s friend, Donna', None)
# (290, 'Answer', 'Rich people', None)
# (291, 'Answer', 'Pirate music', None)
# (292, 'Answer', 'Being a dinosaur', None)
# (293, 'Answer', 'A fake kid made out of wood', None)
# (294, 'Answer', 'Homework', None)
# (295, 'Answer', 'Batman', None)
# (296, 'Answer', 'A dead body', None)
# (297, 'Answer', 'Drinking a whole bottle of ranch', None)
# (298, 'Answer', 'Destroying the planet', None)
# (299, 'Answer', 'Living in a pineapple under the sea', None)
# (300, 'Answer', 'Pizza', None)
# (301, 'Answer', 'This pumpkin', None)
# (302, 'Answer', 'Extremely tight underpants', None)
# (303, 'Answer', 'A nice, warm glass of pee', None)
# (304, 'Answer', 'Poseidon, Lord of the Sea', None)
# (305, 'Answer', 'Complaining', None)
# (306, 'Answer', 'Bursting into flames', None)
# (307, 'Answer', 'Spawning sheep', None)
# (308, 'Answer', 'My whole body getting big and strong and beautiful', None)
# (309, 'Answer', 'Big, juicy pimples', None)
# (310, 'Answer', 'The humble earthworm', None)
# (311, 'Answer', 'The garbage man', None)
# (312, 'Answer', 'A big, and I mean BIG turtle', None)
# (313, 'Answer', 'Your mom', None)
# (314, 'Answer', 'The octopus stuck to my face', None)
# (315, 'Answer', 'Dying of old age', None)
# (316, 'Answer', 'Smashing the patriarchy', None)
# (317, 'Answer', 'Screaming into a can of Pringles', None)
# (318, 'Answer', 'Grandpa', None)
# (319, 'Answer', 'Shutting up', None)
# (320, 'Answer', 'Silence', None)
# (321, 'Answer', 'My annoying brother', None)
# (322, 'Answer', 'My future husband', None)
# (323, 'Answer', 'A hot air balloon powered by fart gas', None)
# (324, 'Answer', 'Sitting on the toilet and going poop', None)
# (325, 'Answer', 'A screaming soccer dad', None)
# (326, 'Answer', 'Cocktail weenies', None)
# (327, 'Answer', 'The British', None)
# (328, 'Answer', 'Voldemort', None)
# (329, 'Answer', 'Science', None)
# (330, 'Answer', 'Picking my nose and eating it', None)
# (331, 'Answer', 'Having a really big head', None)
# (332, 'Answer', 'A dead whale', None)
# (333, 'Answer', 'Fortnite', None)
# (334, 'Answer', 'The power of the Dark Side', None)
# (335, 'Answer', 'Big butt cheeks filled with poop', None)
# (336, 'Answer', 'My friend Steve', None)
# (337, 'Answer', 'Violence', None)
# (338, 'Answer', 'Magic: The Gathering', None)
# (339, 'Answer', 'Eating toenail clippings', None)
# (340, 'Answer', 'Using balloons as boobies', None)
# (341, 'Answer', 'My dang kids', None)
# (342, 'Answer', 'Squeezing a lemon into my eye', None)
# (343, 'Answer', 'Tombus, the talking rhombus', None)
# (344, 'Answer', 'Greta Thunberg', None)
# (345, 'Answer', 'Ellen', None)
# (346, 'Answer', 'Uncle Bob', None)
# (347, 'Answer', 'Outback Steakhouse', None)
# (348, 'Answer', 'Dwayne “The Rock” Johnson', None)
# (349, 'Answer', 'A baby with a full mustache', None)
# (350, 'Answer', 'Getting hit in the face with a soccer ball', None)
# (351, 'Answer', 'Eating a whole roll of toilet paper', None)
# (352, 'Answer', 'The bacon', None)
# (353, 'Answer', 'The first female president of the United States', None)
# (354, 'Answer', 'Falling off a mountain', None)
# (355, 'Answer', 'Person milk', None)
# (356, 'Answer', 'Pink eye', None)
# (357, 'Answer', 'Pork', None)
# (358, 'Answer', 'The government', None)
# (359, 'Answer', 'Nunchucks', None)
# (360, 'Answer', 'Nothing', None)
# (361, 'Answer', 'GOOOAAALLLL', None)
# (362, 'Answer', 'Mom’s new haircut', None)
# (363, 'Answer', 'Happy daddies with happy sandals', None)
# (364, 'Answer', 'Giggling and farting and slurping milkshakes', None)
# (365, 'Answer', 'Ice pee', None)
# (366, 'Answer', 'Obama', None)
# (367, 'Answer', 'Twerking', None)
# (368, 'Answer', 'Reading my sister’s diary', None)
# (369, 'Answer', 'The ice cream man', None)
# (370, 'Answer', 'Love', None)
# (371, 'Answer', 'Stank breath', None)
# (372, 'Answer', 'Living in the dumpster', None)
# (373, 'Answer', 'Having a baby', None)
# (374, 'Answer', 'Shoplifting', None)
# (375, 'Answer', 'My father, who is a walrus', None)
# (376, 'Answer', 'The dentist', None)
# (377, 'Answer', 'Aunt Linda', None)
# (378, 'Answer', 'One tough mama', None)
# (379, 'Answer', 'Releasing the falcons', None)
# (380, 'Answer', 'Literally ruining my life', None)
# (381, 'Answer', 'Flushing myself down the toilet', None)
# (382, 'Answer', 'Fire farts', None)
# (383, 'Answer', 'Lice', None)
# (384, 'Answer', 'A killer clown', None)
# (385, 'Answer', 'Blossoming into a beautiful young man', None)
# (386, 'Answer', 'Wiping my butt', None)
# (387, 'Answer', 'Saying mean stuff and making people feel bad', None)
# (388, 'Answer', 'Beyoncé', None)
# (389, 'Answer', 'A truck', None)
# (390, 'Answer', 'Only beans', None)
# (391, 'Answer', 'The beautiful potato', None)
# (392, 'Answer', 'Legs', None)
# (393, 'Answer', 'The woman I’m going to marry one day', None)
# (394, 'Answer', 'Unleashing a hell demon that will destroy our world', None)
# (395, 'Answer', 'Feminism', None)
# (396, 'Answer', 'Lighting stuff on fire', None)
# (397, 'Answer', 'Turning 40', None)
# (398, 'Answer', 'Getting a skull tattoo', None)
# (399, 'Answer', 'An invisible giant who takes giant, visible poops', None)
# (400, 'Answer', 'A cowboy who is half boy, half cow', None)
# (401, 'Answer', 'The longest tongue in the world', None)
# (402, 'Answer', 'Josh', None)
# (403, 'Answer', 'Locking Mother in the pantry', None)
# (404, 'Answer', 'Ariana Grande', None)
# (405, 'Answer', 'Puberty', None)
# (406, 'Answer', 'A glorious beard', None)
# (407, 'Answer', 'All of my teeth falling out', None)
# (408, 'Answer', 'Floating through the void of space and time', None)
# (409, 'Answer', 'Farting, barfing, and passing out', None)
# (410, 'Answer', 'Flamin’ Hot Cheetos', None)
# (411, 'Answer', 'Snakes', None)
# (412, 'Answer', 'Free ice cream, yo', None)
# (413, 'Answer', 'Screaming and screaming and never waking up', None)
# (414, 'Answer', 'Running away from home', None)
# (415, 'Answer', 'Using my butt as a microwave', None)
# (416, 'Answer', 'Glen’s fabulous body', None)
# (417, 'Answer', 'Gluten', None)
# (418, 'Answer', 'Wakanda', None)
# (419, 'Answer', 'Many wolves', None)
# (420, 'Answer', 'One long hair growing out of a mole', None)
# (421, 'Answer', 'A butt that eats underwear', None)
# (422, 'Answer', 'Poo-poo', None)
# (423, 'Answer', 'Mooing', None)
# (424, 'Answer', 'Robbing a bank', None)
# (425, 'Answer', 'Punching everyone', None)
# (426, 'Answer', 'How much wood a woodchuck would chuck if a woodchuck could chuck wood', None)
# (427, 'Answer', 'Swords', None)
# (428, 'Answer', 'Kevin’s mom', None)
# (429, 'Answer', 'Getting scalded in the face with hot beans', None)
# (430, 'Answer', 'Chest hair', None)
# (431, 'Answer', 'My annoying sister', None)
# (432, 'Answer', 'Getting slapped with a fish', None)
# (433, 'Answer', 'Harry Potter', None)
# (434, 'Answer', 'Peeing sand', None)
# (435, 'Answer', 'Being French, hoh-hoh-hoh', None)
# (436, 'Answer', 'Guacamole', None)
# (437, 'Answer', 'Getting naked', None)
# (438, 'Answer', 'A super angry cat I found outside', None)
# (439, 'Answer', 'Slappy Spatchy, the game where you slap each other with spatulas. Learn more at www.SlappySpatchy.com', None)
# (440, 'Answer', 'A pregnant person', None)
# (441, 'Answer', 'A bunch of dead squirrels on a trampoline', None)
# (442, 'Answer', 'Grandma panties', None)
# (443, 'Answer', 'Thick, nasty burps', None)
# (444, 'Answer', 'Having no bones', None)
# (445, 'Answer', 'Famous peanut scientist George Washington Carver', None)
# (446, 'Answer', 'Saving up my boogers for ten years and then building the world’s largest booger', None)
# (447, 'Answer', 'The president', None)
# (448, 'Answer', 'A hug', None)
# (449, 'Answer', 'The Dark Lord', None)
# (450, 'Answer', 'Being super serious right now', None)
# (451, 'Answer', 'Freeing a fart from its butt prison', None)
# (452, 'Answer', 'An order of mozzarella sticks', None)
# (453, 'Answer', 'Fake news', None)
# (454, 'Answer', 'The baby', None)
# (455, 'Answer', 'Like a million alligators', None)
# (456, 'Answer', 'Big, slappy hands', None)
# (457, 'Answer', 'Beer', None)
# (458, 'Answer', 'Spit', None)
# (459, 'Answer', 'The fifth graders', None)
# (460, 'Answer', 'Licking a goat', None)
# (461, 'Answer', 'A flamethrower', None)
# (462, 'Answer', 'Drama', None)
# (463, 'Answer', 'Old Jim’s Steamy Butt Sauce', None)
# (464, 'Answer', 'Going to the emergency room', None)
# (465, 'Answer', 'Sitting atop a pile of tuna, like some kind of tuna queen', None)
# (466, 'Answer', 'Girls', None)
# (467, 'Answer', 'A Pringle', None)
# (468, 'Answer', 'Never showering', None)
# (469, 'Answer', 'Naptime', None)
# (470, 'Answer', 'The gym teacher', None)
# (471, 'Answer', 'Coming back from the dead', None)
# (472, 'Answer', 'Burning books', None)
# (473, 'Answer', 'Falling in love', None)
# (474, 'Answer', 'Tossed salads and scrambled eggs', None)
# (475, 'Answer', 'Building a ladder of hot dogs to the moon', None)
# (476, 'Answer', 'Practicing kissing', None)
# (477, 'Answer', 'Eating a lightning bug to gain its lightning powers', None)
# (478, 'Answer', 'Slowly turning into cheese', None)
# (479, 'Answer', 'Ear wax', None)
# (480, 'Answer', 'Knives', None)
# (481, 'Answer', 'Stuff', None)
# (482, 'Answer', 'Whispering secrets to my best friend, Turkey', None)
# (483, 'Answer', 'Taking a selfie', None)
# (484, 'Answer', 'Dancing with my son', None)
# (485, 'Answer', 'Punching a guy through a wall', None)
# (486, 'Answer', 'Nipples', None)
# (487, 'Answer', 'Cat pee', None)
# (488, 'Answer', 'Dump cake', None)
# (489, 'Answer', 'Billie Eilish', None)
# (490, 'Answer', 'Steven Universe', None)
# (491, 'Answer', 'Elegant party hats', None)
# (492, 'Answer', 'Santa Claus', None)
# (493, 'Answer', 'The gluteus maximus', None)
# (494, 'Answer', 'Baby Yoda', None)
# (495, 'Answer', 'Peeing in the cat’s litter box', None)
# (496, 'Answer', 'A big sad dragon with no friends', None)
# (497, 'Answer', 'A big whiny cry-baby', None)
# (498, 'Answer', 'Seymour Butts', None)
# (499, 'Answer', 'The bus driver', None)
# (500, 'Answer', 'Getting run over by a train', None)
# (501, 'Answer', 'Spinning and barfing', None)
# (502, 'Answer', 'Some freakin’ privacy', None)
# (503, 'Answer', 'Butt hair', None)
# (504, 'Answer', 'Having many husbands', None)
# (505, 'Answer', 'Making the bathroom smell', None)
# (506, 'Answer', 'Coffee', None)
# (507, 'Answer', 'Anime', None)
# (508, 'Answer', 'The sweet honking of Karen’s bassoon', None)
# (509, 'Answer', 'Pooping in a bag and lighting it on fire', None)
# (510, 'Answer', 'Space lasers', None)
# (511, 'Answer', 'Being dead', None)
# (512, 'Answer', 'Pooping barf forever', None)
# (513, 'Answer', 'FOOOOD FIIIIIIIIIIIIIIIIIGHT', None)
# (514, 'Answer', 'Wearing high heels', None)
# (515, 'Answer', 'A long, long snake', None)
# (516, 'Answer', 'Getting trampled by horses', None)
# (517, 'Answer', 'The babysitter', None)
# (518, 'Answer', 'The lunch lady', None)
# (519, 'Answer', 'Peeing on my poopy', None)
# (520, 'Answer', 'Not wearing pants. Meatballs, meatballs, meatballs', None)
# (521, 'Answer', 'Finding Waldo', None)
# (522, 'Answer', 'Going around sniffing people’s armpits', None)
# (523, 'Answer', 'The divorce', None)
# (524, 'Answer', 'Diaper beans', None)
# (525, 'Answer', 'Cigarettes', None)
# (526, 'Answer', 'Getting my ponytail stuck in my butt', None)
# (527, 'Answer', 'Looking into people’s windows', None)
# (528, 'Answer', 'Sucking at life', None)
# (529, 'Answer', 'Crossbows', None)
# (530, 'Answer', 'Evil', None)
# (531, 'Answer', 'A big rock', None)
# (532, 'Answer', 'Rubbing lotion on a hairless cat', None)
# (533, 'Answer', 'Goblins', None)
# (534, 'Answer', 'Nasty Cousin Amber', None)
# (535, 'Answer', 'Tongue kissing', None)
# (536, 'Answer', 'Abraham Lincoln', None)
# (537, 'Answer', 'Covering myself with ketchup and mustard because I am hot dog', None)
# (538, 'Answer', 'Hot, fresh doodies', None)
# (539, 'Answer', 'Feet', None)
# (540, 'Answer', 'Sadness', None)
# (541, 'Answer', 'Going beast mode', None)
# (542, 'Answer', 'An owl that hates you', None)
# (543, 'Answer', 'A doll that pees real pee', None)
# (544, 'Answer', 'A naked lady in a painting', None)
# (545, 'Answer', 'Chunks', None)
# (546, 'Answer', 'Some weird guy', None)
# (547, 'Answer', 'Getting a girlfriend', None)
# (548, 'Answer', 'Falling in love with a hot dog', None)
# (549, 'Answer', 'Throwing stuff at other stuff', None)
# (550, 'Answer', 'Hogs', None)
# (551, 'Answer', 'A turd that just won’t flush', None)
# (552, 'Answer', 'The entire state of Texas', None)
# (553, 'Answer', 'Showing everyone my butt', None)
# (554, 'Answer', 'My big donkey brother', None)
# (555, 'Answer', 'The huge, stupid moon', None)
# (556, 'Answer', 'Math', None)
# (557, 'Answer', 'Pee-pee', None)
# (558, 'Answer', 'Dinner', None)
# (559, 'Answer', 'Butthole', None)
# (560, 'Answer', 'Smelling like onions', None)
# (561, 'Answer', 'Being fake', None)
# (562, 'Answer', 'Peer pressure', None)
# (563, 'Answer', 'Peeing in my backpack', None)
# (564, 'Answer', 'Bad parenting', None)
# (565, 'Answer', 'Mom’s butt', None)
# (566, 'Answer', 'One weird lookin’ toe', None)
# (567, 'Answer', 'You', None)
# (568, 'Answer', 'Boys', None)
# (569, 'Answer', 'Sitting on a cake', None)
# (570, 'Answer', 'Teaching a chicken to kill', None)
# (571, 'Answer', 'The middle finger', None)
# (572, 'Answer', 'A bra', None)
# (573, 'Answer', 'Being famous on YouTube', None)
# (574, 'Answer', 'Cream', None)
# (575, 'Answer', 'Balls', None)
# (576, 'Answer', 'Having no friends', None)
# (577, 'Answer', 'Peeing into everyone’s mouth', None)
# (578, 'Answer', 'Gluing my butt cheeks together', None)
# (579, 'Answer', 'How school slowly breaks your spirit and drains your will to live', None)
# (580, 'Answer', 'A Pokémon named “Jim.”', None)
# (581, 'Answer', 'True love’s kiss', None)
# (582, 'Answer', 'Total crap', None)
# (583, 'Answer', 'Cool sunglasses', None)
# (584, 'Answer', 'Literally dying from the smell of a fart', None)
# (585, 'Answer', 'Snot bubbles', None)
# (586, 'Answer', 'Doing crimes and going to jail', None)
# (587, 'Answer', 'This goat, who is my friend', None)
# (588, 'Answer', 'Aliens', None)
# (589, 'Answer', 'School', None)
# (590, 'Answer', 'A cow', None)
# (591, 'Answer', 'The terrible winter of 1609', None)
# (592, 'Answer', 'Getting sucked into a jet engine', None)
# (593, 'Answer', 'Not breathing', None)
# (594, 'Answer', 'Licking a used band-aid', None)
# (595, 'Answer', 'Braiding my armpit hair', None)
# (596, 'Answer', 'Waking up inside of a spider web', None)
# (597, 'Answer', 'Blasting farts in the powder room', None)

# %%
con.close() # closes the database and saves it

# %% [markdown]
# ### TO DO LIST:

# %% [markdown]
# 1. Check and see if the num of ans and quest cards are correct. if not check and see if all the cards are correct
#
# 2. Find out how to do auto increment for id
#
# 3. Different table for the different type of games (family friendly or x rated)
